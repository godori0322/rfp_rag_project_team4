# %% [markdown]
# ### 데이터 확인 및 불러오기
#
# - 데이터는 구글 드라이브 > 프로젝트 > 중급 프로젝트 > 원본데이터에 있어요.
# - 제공된 문서 파일들과 `data_list.csv` 파일에 담긴 메타데이터를 확인합니다.
# - 문서 파일을 불러옵니다. `hwp`와 `pdf` 두 가지 포맷에 대응할 수 있어야 해요.
# - 유용한 메타데이터가 무엇일지 판단하여 함께 활용해 보세요.
#
# ### 문서 청킹
#
# - 청크 크기, 그리고 청크 간 중첩 크기를 잘 설정하여 문서를 청킹합니다.
# - (심화) 제안서 포맷을 활용해 의미 단위까지 고려하여 문서를 청킹해 보고 성능을 확인해 보세요.
#
# ### 임베딩 생성
#
# - 임베딩 성능과 비용을 고려해 적절한 임베딩 모델을 선정합니다.
# - 사용의 편의성과 검색 기능을 고려해 적절한 Vector DB를 선정합니다.
#
# ### Retrieval 기능 구현
#
# - 먼저 naive한 retrieval을 구현해 베이스라인으로 삼으면 좋습니다. 베이스라인을 기반으로 점점 더 retrieval 기능을 고도화해 나가면 됩니다.
# - 데이터 소스 문서가 하나가 아니라 여러 개이기 때문에, 타깃 문서를 정확히 찾기 위해 메타데이터 필터링을 활용할 수 있습니다. 이때 사용자가 발주 기관이나 사업명 같은 정보를 비슷하지만 정확하지는 않게 입력하는 케이스도 고려하는 게 좋아요.
# - (심화) Retrieval과 관련해 다양한 옵션과 기법을 실험하면서 성능을 확인해 보세요.
#     - Retrieval을 위한 프롬프트 엔지니어링
#     - Top-k 검색에서 k 값 설정
#     - 단순 유사도 기반 검색 / MMR(Maximum Marginal Relevance) / Hybrid Search
#     - Multi-Query, Re-Ranking 등 심화 기법
#
# ### Generation 기능 구현
#
# - 텍스트 생성 능력과 비용을 고려해 적절한 언어 모델을 선정합니다.
# - 원하는 답변 양상과 분량에 따라서 temperature, top_p, max tokens 등 텍스트 생성과 관련된 옵션도 적절하게 설정해 주세요.
# - 답변 생성을 위한 최적의 프롬프트를 작성합니다.
#     - Retrieval 과정에서 찾은 컨텍스트를 충실히 반영해야 합니다.
#     - 불필요한 내용이 답변에 포함되지 않도록 합니다.
#     - 응답의 톤이나 스타일을 조정합니다.
#     - 비용을 고려해 토큰 사용량도 최적화해 보세요.
# - RAG 시스템이 대화 맥락을 유지하여 사용자와 대화를 이어 갈 수 있도록 해 주세요.
#
# ### 성능 평가
#
# - 답변의 품질을 평가할 때는 다음과 같은 기준을 사용할 수 있습니다.
#     - 사용자가 요청한 내용을 단일 문서에서 정확하게 뽑아내 답변하는지
#     - 사용자가 여러 문서에 대해 요청한 내용을 잘 종합해서 답변하는지
#     - 후속 질문의 맥락을 잘 이해하고 답변하는지
#     - 문서에 포함되어 있지 않은 내용에 대해서는 모른다고 답변하는지
# - 위와 같은 기준을 어떤 방식으로 평가하고 어떤 지표로 나타낼지 선정해 보세요.
# - 주어진 문서 데이터에 맞게 다양한 질문 세트를 준비하여 성능 평가에 활용해 보세요.
#     - 질문 예시
#         - 국민연금공단이 발주한 이러닝시스템 관련 사업 요구사항을 정리해 줘.
#             - 콘텐츠 개발 관리 요구 사항에 대해서 더 자세히 알려 줘.
#             - 교육이나 학습 관련해서 다른 기관이 발주한 사업은 없나?
#         - 기초과학연구원 극저온시스템 사업 요구에서 AI 기반 예측에 대한 요구사항이 있나?
#             - 그럼 모니터링 업무에 대한 요청사항이 있는지 찾아보고 알려 줘.
#         - 한국 원자력 연구원에서 선량 평가 시스템 고도화 사업을 발주했는데, 이 사업이 왜 추진되는지 목적을 알려 줘.
#         - 고려대학교 차세대 포털 시스템 사업이랑 광주과학기술원의 학사 시스템 기능개선 사업을 비교해 줄래?
#             - 고려대학교랑 광주과학기술원 각각 응답 시간에 대한 요구사항이 있나? 문서를 기반으로 정확하게 답변해 줘.
# - 품질 좋은 답변도 중요하지만 응답 속도가 너무 느려져서도 안 됩니다.

# %%
# Google Drive Mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

data_dir = '/content/drive/MyDrive/Data' # Updated path
print(f"Listing contents of directory: {data_dir}")
try:
    for item in os.listdir(data_dir):
        print(item)
except FileNotFoundError:
    print(f"Directory not found: {data_dir}")
except Exception as e:
    print(f"An error occurred while listing directory contents: {e}")
# Out:
# Listing contents of directory: /content/drive/MyDrive/Data
# files
# data_list.csv
# data_list.gsheet

# %% [markdown]
# # Install Packages

# %%
# !pip install langchain langchain-openai easyocr pyhwp hwp-extract pymupdf pymupdf4llm faiss-cpu langchain-community
# Out:
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/pyhwp-0.1b16.dev0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.12/dist-packages (0.3.33)
# Requirement already satisfied: easyocr in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: pyhwp in /usr/local/lib/python3.12/dist-packages/pyhwp-0.1b16.dev0-py3.12.egg (0.1b16.dev0)
# Requirement already satisfied: hwp-extract in /usr/local/lib/python3.12/dist-packages (0.1.0)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: pymupdf4llm in /usr/local/lib/python3.12/dist-packages (0.0.27)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.3.29)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.4.27)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (1.107.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.11.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.23.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from easyocr) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.6.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.1.1)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.13.0)
# Requirement already satisfied: cryptography>=40.0.1 in /usr/local/lib/python3.12/dist-packages (from pyhwp) (43.0.3)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from pyhwp) (5.4.0)
# Requirement already satisfied: olefile>=0.43 in /usr/local/lib/python3.12/dist-packages (from pyhwp) (0.47)
# Requirement already satisfied: pycryptodome~=3.0 in /usr/local/lib/python3.12/dist-packages (from hwp-extract) (3.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=40.0.1->pyhwp) (2.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.4.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2025.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=40.0.1->pyhwp) (2.23)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->easyocr) (3.0.2)

# %%
# 필수 빌드 도구 & 라이브러리 설치
# !apt-get update
# !apt-get install -y build-essential libgsf-1-dev libxml2-dev libglib2.0-dev libiconv-hook-dev

# 소스코드 clone
# !git clone https://github.com/mete0r/pyhwp.git
# %cd pyhwp

# 설치
# !python setup.py install

# %cd ..
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# libiconv-hook-dev is already the newest version (0.0.20021209-12).
# libglib2.0-dev is already the newest version (2.72.4-0ubuntu2.6).
# libgsf-1-dev is already the newest version (1.14.47-1ubuntu0.1).
# libxml2-dev is already the newest version (2.9.13+dfsg-1ubuntu0.9).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# fatal: destination path 'pyhwp' already exists and is not an empty directory.
# /content/pyhwp
# /usr/local/lib/python3.12/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running install
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.12/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# writing src/pyhwp.egg-info/PKG-INFO
# writing dependency_links to src/pyhwp.egg-info/dependency_links.txt
# writing entry points to src/pyhwp.egg-info/entry_points.txt
# writing requirements to src/pyhwp.egg-info/requires.txt
# writing top-level names to src/pyhwp.egg-info/top_level.txt
# reading manifest file 'src/pyhwp.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files found matching 'notebooks'
# warning: no previously-included files found matching 'samples'
# no previously-included directories found matching 'buildouts'
# no previously-included directories found matching 'docs'
# no previously-included directories found matching 'etc'
# no previously-included directories found matching 'misc'
# no previously-included directories found matching 'oxt'
# no previously-included directories found matching 'release-hooks'
# no previously-included directories found matching 'tests'
# no previously-included directories found matching 'tools'
# no previously-included directories found matching 'unokit'
# no previously-included directories found matching 'pyhwp_uno'
# adding license file 'LICENSE'
# adding license file 'COPYING'
# writing manifest file 'src/pyhwp.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying src/hwp5/cli.py -> build/lib/hwp5
# copying src/hwp5/hwp5txt.py -> build/lib/hwp5
# copying src/hwp5/xmlformat.py -> build/lib/hwp5
# copying src/hwp5/tagids.py -> build/lib/hwp5
# copying src/hwp5/xmldump_flat.py -> build/lib/hwp5
# copying src/hwp5/__init__.py -> build/lib/hwp5
# copying src/hwp5/binspec.py -> build/lib/hwp5
# copying src/hwp5/hwp5view.py -> build/lib/hwp5
# copying src/hwp5/treeop.py -> build/lib/hwp5
# copying src/hwp5/compressed.py -> build/lib/hwp5
# copying src/hwp5/importhelper.py -> build/lib/hwp5
# copying src/hwp5/recordstream.py -> build/lib/hwp5
# copying src/hwp5/hwp5odt.py -> build/lib/hwp5
# copying src/hwp5/bintype.py -> build/lib/hwp5
# copying src/hwp5/filestructure.py -> build/lib/hwp5
# copying src/hwp5/msoleprops.py -> build/lib/hwp5
# copying src/hwp5/distdoc.py -> build/lib/hwp5
# copying src/hwp5/charsets.py -> build/lib/hwp5
# copying src/hwp5/summaryinfo.py -> build/lib/hwp5
# copying src/hwp5/utils.py -> build/lib/hwp5
# copying src/hwp5/errors.py -> build/lib/hwp5
# copying src/hwp5/xmlmodel.py -> build/lib/hwp5
# copying src/hwp5/hwp5html.py -> build/lib/hwp5
# copying src/hwp5/hwp5proc.py -> build/lib/hwp5
# copying src/hwp5/zlib_raw_codec.py -> build/lib/hwp5
# copying src/hwp5/dataio.py -> build/lib/hwp5
# copying src/hwp5/binmodel/_shared.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid28_distribute_doc_data.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid67_shape_component_curve.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid51_para_text.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid52_para_char_shape.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid22_tab_def.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/controlchar.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid71_ctrl_data.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid54_para_range_tag.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid32_unknown.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid99_shape_component_unknown.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/__init__.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid64_shape_component_ellipse.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid62_shape_component_line.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid55_ctrl_header.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid24_bullet.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid20_border_fill.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid31_layout_compatibility.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid25_para_shape.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid57_page_def.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid58_footnote_shape.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid59_page_border_fill.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid75_form_object.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid26_style.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid68_shape_component_ole.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid76_memo_shape.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid60_shape_component.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid74_shape_component_textart.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid50_para_header.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid16_document_properties.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid65_shape_component_arc.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid30_compatible_document.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid77_memo_list.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid19_face_name.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid27_doc_data.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid23_numbering.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid18_bin_data.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid72_ctrl_eqedit.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid56_list_header.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid66_shape_component_polygon.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid79_chart_data.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid53_para_line_seg.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid17_id_mappings.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid63_shape_component_rectangle.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid61_table.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid78_forbidden_char.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid21_char_shape.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid70_shape_component_container.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/tagid69_shape_component_picture.py -> build/lib/hwp5/binmodel
# copying src/hwp5/binmodel/controls/_shared.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/numbering.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/page_number_position.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/hidden_comment.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/section_def.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/tcps_control.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/__init__.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/table_control.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/page_odd_even.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/columns_def.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/header_footer.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/index_marker.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/dutmal.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/bookmark_control.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/common_controls.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/field.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/note.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/page_hide.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/binmodel/controls/gshape_object_control.py -> build/lib/hwp5/binmodel/controls
# copying src/hwp5/plat/__init__.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/olefileio.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/xsltproc.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/gir_gsf.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/xmllint.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/javax_transform.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/jython_poifs.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/_lxml.py -> build/lib/hwp5/plat
# copying src/hwp5/plat/_uno/__init__.py -> build/lib/hwp5/plat/_uno
# copying src/hwp5/plat/_uno/ucb.py -> build/lib/hwp5/plat/_uno
# copying src/hwp5/plat/_uno/adapters.py -> build/lib/hwp5/plat/_uno
# copying src/hwp5/plat/_uno/services.py -> build/lib/hwp5/plat/_uno
# copying src/hwp5/proc/diststream.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/models.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/rawunz.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/unpack.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/__init__.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/find.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/records.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/xml.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/header.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/version.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/summaryinfo.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/cat.py -> build/lib/hwp5/proc
# copying src/hwp5/proc/ls.py -> build/lib/hwp5/proc
# copying src/hwp5/storage/__init__.py -> build/lib/hwp5/storage
# copying src/hwp5/storage/fs.py -> build/lib/hwp5/storage
# copying src/hwp5/storage/ole.py -> build/lib/hwp5/storage
# copying src/hwp5/transforms/__init__.py -> build/lib/hwp5/transforms
# copying src/hwp5/README -> build/lib/hwp5
# copying src/hwp5/COPYING -> build/lib/hwp5
# copying src/hwp5/VERSION.txt -> build/lib/hwp5
# copying src/hwp5/xsl/hwp5fodt.xsl -> build/lib/hwp5/xsl
# copying src/hwp5/xsl/hwp5css-common.xsl -> build/lib/hwp5/xsl
# copying src/hwp5/xsl/hwp5html.xsl -> build/lib/hwp5/xsl
# copying src/hwp5/xsl/binspec2html.xsl -> build/lib/hwp5/xsl
# copying src/hwp5/xsl/hwp5css.xsl -> build/lib/hwp5/xsl
# copying src/hwp5/xsl/plaintext.xsl -> build/lib/hwp5/xsl
# copying src/hwp5/xsl/odt/common.xsl -> build/lib/hwp5/xsl/odt
# copying src/hwp5/xsl/odt/document.xsl -> build/lib/hwp5/xsl/odt
# copying src/hwp5/xsl/odt/content.xsl -> build/lib/hwp5/xsl/odt
# copying src/hwp5/xsl/odt/styles.xsl -> build/lib/hwp5/xsl/odt
# copying src/hwp5/odf-relaxng/OpenDocument-v1.2-os-manifest-schema.rng -> build/lib/hwp5/odf-relaxng
# copying src/hwp5/odf-relaxng/OpenDocument-v1.2-os-schema.rng -> build/lib/hwp5/odf-relaxng
# copying src/hwp5/odf-relaxng/OpenDocument-v1.2-os-dsig-schema.rng -> build/lib/hwp5/odf-relaxng
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/cli.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/hwp5txt.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/xmlformat.py -> build/bdist.linux-x86_64/egg/hwp5
# creating build/bdist.linux-x86_64/egg/hwp5/plat
# creating build/bdist.linux-x86_64/egg/hwp5/plat/_uno
# copying build/lib/hwp5/plat/_uno/__init__.py -> build/bdist.linux-x86_64/egg/hwp5/plat/_uno
# copying build/lib/hwp5/plat/_uno/ucb.py -> build/bdist.linux-x86_64/egg/hwp5/plat/_uno
# copying build/lib/hwp5/plat/_uno/adapters.py -> build/bdist.linux-x86_64/egg/hwp5/plat/_uno
# copying build/lib/hwp5/plat/_uno/services.py -> build/bdist.linux-x86_64/egg/hwp5/plat/_uno
# copying build/lib/hwp5/plat/__init__.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/plat/olefileio.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/plat/xsltproc.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/plat/gir_gsf.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/plat/xmllint.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/plat/javax_transform.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/plat/jython_poifs.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/plat/_lxml.py -> build/bdist.linux-x86_64/egg/hwp5/plat
# copying build/lib/hwp5/tagids.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/xmldump_flat.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/README -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/VERSION.txt -> build/bdist.linux-x86_64/egg/hwp5
# creating build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/_shared.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid28_distribute_doc_data.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid67_shape_component_curve.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid51_para_text.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid52_para_char_shape.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid22_tab_def.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/controlchar.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid71_ctrl_data.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid54_para_range_tag.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid32_unknown.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid99_shape_component_unknown.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/__init__.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid64_shape_component_ellipse.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid62_shape_component_line.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid55_ctrl_header.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid24_bullet.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid20_border_fill.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid31_layout_compatibility.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid25_para_shape.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid57_page_def.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid58_footnote_shape.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid59_page_border_fill.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid75_form_object.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid26_style.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid68_shape_component_ole.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid76_memo_shape.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid60_shape_component.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid74_shape_component_textart.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid50_para_header.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid16_document_properties.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid65_shape_component_arc.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid30_compatible_document.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid77_memo_list.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid19_face_name.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid27_doc_data.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid23_numbering.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid18_bin_data.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid72_ctrl_eqedit.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid56_list_header.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid66_shape_component_polygon.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid79_chart_data.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid53_para_line_seg.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid17_id_mappings.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid63_shape_component_rectangle.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid61_table.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid78_forbidden_char.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid21_char_shape.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid70_shape_component_container.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# copying build/lib/hwp5/binmodel/tagid69_shape_component_picture.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel
# creating build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/_shared.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/numbering.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/page_number_position.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/hidden_comment.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/section_def.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/tcps_control.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/__init__.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/table_control.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/page_odd_even.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/columns_def.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/header_footer.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/index_marker.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/dutmal.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/bookmark_control.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/common_controls.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/field.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/note.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/page_hide.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/binmodel/controls/gshape_object_control.py -> build/bdist.linux-x86_64/egg/hwp5/binmodel/controls
# copying build/lib/hwp5/__init__.py -> build/bdist.linux-x86_64/egg/hwp5
# creating build/bdist.linux-x86_64/egg/hwp5/xsl
# copying build/lib/hwp5/xsl/hwp5fodt.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl
# copying build/lib/hwp5/xsl/hwp5css-common.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl
# copying build/lib/hwp5/xsl/hwp5html.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl
# copying build/lib/hwp5/xsl/binspec2html.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl
# copying build/lib/hwp5/xsl/hwp5css.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl
# copying build/lib/hwp5/xsl/plaintext.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl
# creating build/bdist.linux-x86_64/egg/hwp5/xsl/odt
# copying build/lib/hwp5/xsl/odt/common.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl/odt
# copying build/lib/hwp5/xsl/odt/document.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl/odt
# copying build/lib/hwp5/xsl/odt/content.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl/odt
# copying build/lib/hwp5/xsl/odt/styles.xsl -> build/bdist.linux-x86_64/egg/hwp5/xsl/odt
# copying build/lib/hwp5/binspec.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/hwp5view.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/treeop.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/compressed.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/importhelper.py -> build/bdist.linux-x86_64/egg/hwp5
# creating build/bdist.linux-x86_64/egg/hwp5/odf-relaxng
# copying build/lib/hwp5/odf-relaxng/OpenDocument-v1.2-os-manifest-schema.rng -> build/bdist.linux-x86_64/egg/hwp5/odf-relaxng
# copying build/lib/hwp5/odf-relaxng/OpenDocument-v1.2-os-schema.rng -> build/bdist.linux-x86_64/egg/hwp5/odf-relaxng
# copying build/lib/hwp5/odf-relaxng/OpenDocument-v1.2-os-dsig-schema.rng -> build/bdist.linux-x86_64/egg/hwp5/odf-relaxng
# copying build/lib/hwp5/recordstream.py -> build/bdist.linux-x86_64/egg/hwp5
# creating build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/diststream.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/models.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/rawunz.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/unpack.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/__init__.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/find.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/records.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/xml.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/header.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/version.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/summaryinfo.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/cat.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# copying build/lib/hwp5/proc/ls.py -> build/bdist.linux-x86_64/egg/hwp5/proc
# creating build/bdist.linux-x86_64/egg/hwp5/transforms
# copying build/lib/hwp5/transforms/__init__.py -> build/bdist.linux-x86_64/egg/hwp5/transforms
# copying build/lib/hwp5/hwp5odt.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/bintype.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/COPYING -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/filestructure.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/msoleprops.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/distdoc.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/charsets.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/summaryinfo.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/utils.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/errors.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/xmlmodel.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/hwp5html.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/hwp5proc.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/zlib_raw_codec.py -> build/bdist.linux-x86_64/egg/hwp5
# copying build/lib/hwp5/dataio.py -> build/bdist.linux-x86_64/egg/hwp5
# creating build/bdist.linux-x86_64/egg/hwp5/storage
# copying build/lib/hwp5/storage/__init__.py -> build/bdist.linux-x86_64/egg/hwp5/storage
# copying build/lib/hwp5/storage/fs.py -> build/bdist.linux-x86_64/egg/hwp5/storage
# copying build/lib/hwp5/storage/ole.py -> build/bdist.linux-x86_64/egg/hwp5/storage
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/cli.py to cli.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/hwp5txt.py to hwp5txt.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/xmlformat.py to xmlformat.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/_uno/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/_uno/ucb.py to ucb.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/_uno/adapters.py to adapters.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/_uno/services.py to services.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/olefileio.py to olefileio.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/xsltproc.py to xsltproc.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/gir_gsf.py to gir_gsf.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/xmllint.py to xmllint.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/javax_transform.py to javax_transform.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/jython_poifs.py to jython_poifs.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/plat/_lxml.py to _lxml.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/tagids.py to tagids.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/xmldump_flat.py to xmldump_flat.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/_shared.py to _shared.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid28_distribute_doc_data.py to tagid28_distribute_doc_data.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid67_shape_component_curve.py to tagid67_shape_component_curve.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid51_para_text.py to tagid51_para_text.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid52_para_char_shape.py to tagid52_para_char_shape.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid22_tab_def.py to tagid22_tab_def.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controlchar.py to controlchar.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid71_ctrl_data.py to tagid71_ctrl_data.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid54_para_range_tag.py to tagid54_para_range_tag.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid32_unknown.py to tagid32_unknown.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid99_shape_component_unknown.py to tagid99_shape_component_unknown.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid64_shape_component_ellipse.py to tagid64_shape_component_ellipse.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid62_shape_component_line.py to tagid62_shape_component_line.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid55_ctrl_header.py to tagid55_ctrl_header.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid24_bullet.py to tagid24_bullet.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid20_border_fill.py to tagid20_border_fill.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid31_layout_compatibility.py to tagid31_layout_compatibility.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid25_para_shape.py to tagid25_para_shape.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid57_page_def.py to tagid57_page_def.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid58_footnote_shape.py to tagid58_footnote_shape.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid59_page_border_fill.py to tagid59_page_border_fill.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid75_form_object.py to tagid75_form_object.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid26_style.py to tagid26_style.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid68_shape_component_ole.py to tagid68_shape_component_ole.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid76_memo_shape.py to tagid76_memo_shape.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid60_shape_component.py to tagid60_shape_component.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid74_shape_component_textart.py to tagid74_shape_component_textart.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid50_para_header.py to tagid50_para_header.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid16_document_properties.py to tagid16_document_properties.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid65_shape_component_arc.py to tagid65_shape_component_arc.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid30_compatible_document.py to tagid30_compatible_document.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid77_memo_list.py to tagid77_memo_list.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid19_face_name.py to tagid19_face_name.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid27_doc_data.py to tagid27_doc_data.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid23_numbering.py to tagid23_numbering.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid18_bin_data.py to tagid18_bin_data.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid72_ctrl_eqedit.py to tagid72_ctrl_eqedit.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid56_list_header.py to tagid56_list_header.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid66_shape_component_polygon.py to tagid66_shape_component_polygon.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid79_chart_data.py to tagid79_chart_data.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid53_para_line_seg.py to tagid53_para_line_seg.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid17_id_mappings.py to tagid17_id_mappings.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid63_shape_component_rectangle.py to tagid63_shape_component_rectangle.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid61_table.py to tagid61_table.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid78_forbidden_char.py to tagid78_forbidden_char.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid21_char_shape.py to tagid21_char_shape.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid70_shape_component_container.py to tagid70_shape_component_container.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/tagid69_shape_component_picture.py to tagid69_shape_component_picture.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/_shared.py to _shared.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/numbering.py to numbering.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/page_number_position.py to page_number_position.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/hidden_comment.py to hidden_comment.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/section_def.py to section_def.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/tcps_control.py to tcps_control.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/table_control.py to table_control.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/page_odd_even.py to page_odd_even.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/columns_def.py to columns_def.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/header_footer.py to header_footer.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/index_marker.py to index_marker.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/dutmal.py to dutmal.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/bookmark_control.py to bookmark_control.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/common_controls.py to common_controls.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/field.py to field.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/note.py to note.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/page_hide.py to page_hide.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binmodel/controls/gshape_object_control.py to gshape_object_control.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/binspec.py to binspec.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/hwp5view.py to hwp5view.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/treeop.py to treeop.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/compressed.py to compressed.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/importhelper.py to importhelper.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/recordstream.py to recordstream.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/diststream.py to diststream.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/models.py to models.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/rawunz.py to rawunz.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/unpack.py to unpack.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/find.py to find.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/records.py to records.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/xml.py to xml.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/header.py to header.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/version.py to version.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/summaryinfo.py to summaryinfo.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/cat.py to cat.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/proc/ls.py to ls.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/transforms/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/hwp5odt.py to hwp5odt.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/bintype.py to bintype.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/filestructure.py to filestructure.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/msoleprops.py to msoleprops.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/distdoc.py to distdoc.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/charsets.py to charsets.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/summaryinfo.py to summaryinfo.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/utils.py to utils.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/errors.py to errors.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/xmlmodel.py to xmlmodel.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/hwp5html.py to hwp5html.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/hwp5proc.py to hwp5proc.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/zlib_raw_codec.py to zlib_raw_codec.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/dataio.py to dataio.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/storage/__init__.py to __init__.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/storage/fs.py to fs.cpython-312.pyc
# byte-compiling build/bdist.linux-x86_64/egg/hwp5/storage/ole.py to ole.cpython-312.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/pyhwp.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/pyhwp.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/pyhwp.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/pyhwp.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/pyhwp.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/pyhwp.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying src/pyhwp.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/pyhwp-0.1b16.dev0-py3.12.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing pyhwp-0.1b16.dev0-py3.12.egg
# removing '/usr/local/lib/python3.12/dist-packages/pyhwp-0.1b16.dev0-py3.12.egg' (and everything under it)
# creating /usr/local/lib/python3.12/dist-packages/pyhwp-0.1b16.dev0-py3.12.egg
# Extracting pyhwp-0.1b16.dev0-py3.12.egg to /usr/local/lib/python3.12/dist-packages
# Adding pyhwp 0.1b16.dev0 to easy-install.pth file
# Installing hwp5html script to /usr/local/bin
# Installing hwp5odt script to /usr/local/bin
# Installing hwp5proc script to /usr/local/bin
# Installing hwp5spec script to /usr/local/bin
# Installing hwp5txt script to /usr/local/bin
# Installing hwp5view script to /usr/local/bin
#
# Installed /usr/local/lib/python3.12/dist-packages/pyhwp-0.1b16.dev0-py3.12.egg
# Processing dependencies for pyhwp==0.1b16.dev0
# Searching for olefile==0.47
# Best match: olefile 0.47
# Adding olefile 0.47 to easy-install.pth file
#
# Using /usr/local/lib/python3.12/dist-packages
# Searching for lxml==5.4.0
# Best match: lxml 5.4.0
# Adding lxml 5.4.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.12/dist-packages
# Searching for cryptography==43.0.3
# Best match: cryptography 43.0.3
# Adding cryptography 43.0.3 to easy-install.pth file
#
# Using /usr/local/lib/python3.12/dist-packages
# Searching for cffi==2.0.0
# Best match: cffi 2.0.0
# Adding cffi 2.0.0 to easy-install.pth file
#
# Using /usr/local/lib/python3.12/dist-packages
# Searching for pycparser==2.23
# Best match: pycparser 2.23
# Adding pycparser 2.23 to easy-install.pth file
#
# Using /usr/local/lib/python3.12/dist-packages
# Finished processing dependencies for pyhwp==0.1b16.dev0
# /content

# %%
# !apt-get update && apt-get install -y libreoffice
# !pip install easyocr pymupdf pillow numpy
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libreoffice is already the newest version (1:7.3.7-0ubuntu0.22.04.10).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# DEPRECATION: Loading egg at /usr/local/lib/python3.12/dist-packages/pyhwp-0.1b16.dev0-py3.12.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: easyocr in /usr/local/lib/python3.12/dist-packages (1.7.2)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.23.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.16.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.25.2)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.6.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from easyocr) (6.0.2)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.1.1)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.3.0.post6)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.4.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2025.8.28)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->easyocr) (3.0.2)

# %% [markdown]
# ## Load data_list.csv and find NaN values

# %%
import pandas as pd
import os

data_dir_path = '/content/drive/MyDrive/Data' # Updated path
csv_path = os.path.join(data_dir_path, 'data_list.csv')

try:
    # Load the CSV file into a pandas DataFrame
    data_list_df = pd.read_csv(csv_path)

    # Display the first few rows of the DataFrame
    print("First 5 rows of data_list.csv:")
    display(data_list_df.head())

    # Check for NaN values in each column
    print("\nChecking for NaN values:")
    nan_counts = data_list_df.isnull().sum()

    # Display the count of NaN values per column
    print("Number of NaN values per column:")
    print(nan_counts)

except FileNotFoundError:
    print(f"Error: The file {csv_path} was not found.")
except Exception as e:
    print(f"An error occurred while reading the CSV file or checking for NaN values: {e}")
# Out:
# First 5 rows of data_list.csv:
#          공고 번호  공고 차수                                       사업명        사업 금액  \
# 0  20241001798    0.0  한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화  130000000.0
# 1  20241002912    0.0        2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선  129300000.0
# 2  20240827859    0.0                EIP3.0 고압가스 안전관리 시스템 구축 용역   40000000.0
# 3  20240430918    0.0                      도시계획위원회 통합관리시스템 구축용역  150000000.0
# 4  20240430896    0.0              봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)  900000000.0
#
#        발주 기관                공개 일자            입찰 참여 시작일            입찰 참여 마감일  \
# 0       한영대학  2024-10-04 13:51:23                  NaN  2024-10-15 17:00:00
# 1     한국연구재단  2024-10-04 15:01:52  2024-10-14 10:00:00  2024-10-16 14:00:00
# 2  한국생산기술연구원  2024-08-28 11:31:02  2024-08-29 09:00:00  2024-09-09 10:00:00
# 3      인천광역시  2024-04-18 16:26:32  2024-05-02 10:00:00  2024-05-09 16:00:00
# 4   경상북도 봉화군  2024-04-18 16:33:28  2024-04-26 09:00:00  2024-04-30 17:00:00
#
#                                                사업 요약 파일형식  \
# 0  - 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한...  hwp
# 1  - 사업 개요: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선\n...  hwp
# 2  - 사업 개요: EIP3.0 고압가스 안전관리 시스템 구축 용역\n- 추진배경: 안...  hwp
# 3  - 사업명: 도시계획위원회 통합관리시스템 구축 용역\n- 용역개요: 도시계획위원회와...  hwp
# 4  - 사업명: 봉화군 재난통합관리시스템 고도화 사업\n- 사업개요: 공동수급(공동이행...  hwp
#
#                                              파일명  \
# 0     한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp
# 1  한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp
# 2       한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp
# 3                 인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp
# 4      경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).hwp
#
#                                                  텍스트
# 0      \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 ...
# 1    \r\n \r\n \r\n  \r\n제 안 요 청 서\r\n[ 2024년 대학 ...
# 2      \r\n    \r\nEIP3.0 고압가스 안전관리\r\n시스템 구축 용역\...
# 3    \r\n  \r\n \r\n도시계획위원회 통합관리시스템 구축\r\n제 안 요 청...
# 4        \r\n  \r\n \r\n제안요청서\r\n \r\n사 업 명\r\n봉화...
# Checking for NaN values:
# Number of NaN values per column:
# 공고 번호        18
# 공고 차수        18
# 사업명           0
# 사업 금액         1
# 발주 기관         0
# 공개 일자         0
# 입찰 참여 시작일    26
# 입찰 참여 마감일     8
# 사업 요약         0
# 파일형식          0
# 파일명           0
# 텍스트           0
# dtype: int64

# %% [markdown]
# # Load and Process Documents (using Langchain)

# %%
import os
import sys
import fitz  # PyMuPDF
import easyocr
import numpy as np
from PIL import Image
import subprocess
from langchain.schema import Document
import pyhwp
import pandas as pd
import re
import json # Import json to parse block metadata
import tempfile # Import tempfile for creating temporary files/directories
from datetime import datetime # Import datetime for date parsing

# Define a flag to indicate if `load_hwp_text_blocks` is available
# This should be set to True if the user has defined a working version of this function
LOAD_HWP_TEXT_BLOCKS_AVAILABLE = 'load_hwp_text_blocks' in globals()


def find_executable(executable_name):
    """Finds the full path to an executable within the environment's PATH or script directories."""
    # Check in PATH first
    for path in os.environ["PATH"].split(os.pathsep):
        exe_path = os.path.join(path, executable_name)
        if os.path.isfile(exe_path) and os.access(exe_path, os.X_OK):
            return exe_path

    # Check in common script directories relative to sys.executable
    script_dirs = [
        os.path.join(os.path.dirname(sys.executable), 'bin'), # Linux/macOS
        os.path.join(os.path.dirname(sys.executable), 'Scripts') # Windows
    ]
    for script_dir in script_dirs:
        exe_path = os.path.join(script_dir, executable_name)
        if os.path.isfile(exe_path) and os.access(exe_path, os.X_OK):
            return exe_path

    return None


def clean_text(text: str) -> str:
    """
    Normalize whitespace and remove obvious noise while preserving Hangul.
    - Keep Hangul (U+AC00–U+D7A3), ASCII letters/digits, common punctuation.
    - Avoid aggressive regex that nukes Korean.
    """
    # Normalize line breaks → spaces
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove a few known noise markers (tune cautiously)
    text = text.replace('·', '')  # common dot
    text = text.replace("<표>", "").replace("<그림>", "")

    # Collapse long runs of punctuation but KEEP Korean & numbers
    # Allow: Hangul, ASCII letters, digits, whitespace, basic punctuation
    text = re.sub(r'[^\uAC00-\uD7A3a-zA-Z0-9\s.,:;%()\[\]/\-–—+&~!?\'"°]', ' ', text)
    text = re.sub(r'\s{2,}', ' ', text).strip()
    return text


def _run_and_decode(cmd):
    """Runs a command and decodes output robustly."""
    p = subprocess.run(cmd, capture_output=True)
    out = p.stdout
    err = p.stderr
    if p.returncode != 0:
        return p.returncode, None, err.decode(errors='ignore')
    # Try utf-8 first, fallback to cp949
    try:
        txt = out.decode('utf-8')
    except UnicodeDecodeError:
        txt = out.decode('cp949', errors='ignore')
    return 0, txt, err.decode(errors='ignore')

def _find_hwp_txt():
    """Finds the path to pyhwp's hwp5txt or pyhwp5txt executable."""
    for name in ('pyhwp5txt', 'hwp5txt'):
        path = find_executable(name)
        if path:
            return path
    return None

def extract_text_from_pdf_easyocr(pdf_path, ocr_langs=["ko", "en"]):
    """
    Extracts text from a PDF file page by page using easyOCR with improved fidelity.

    Args:
        pdf_path (str): The path to the PDF file.
        ocr_langs (list, optional): List of languages for OCR. Defaults to ["ko", "en"].

    Returns:
        list: A list of dictionaries, each containing 'text', 'method', 'page', and 'extra'.
    """
    blocks = []
    try:
        # Initialize easyocr reader
        # This might take time on the first run due to model downloads
        reader = easyocr.Reader(ocr_langs)
        pdf_document = fitz.open(pdf_path)

        for page_num in range(pdf_document.page_count):
            page = pdf_document.load_page(page_num)

            # Render at 300 DPI for better OCR fidelity (tables/numbers)
            pixmap = page.get_pixmap(dpi=300)
            img = Image.frombytes("RGB", [pixmap.width, pixmap.height], pixmap.samples)
            img_np = np.array(img)

            # Use easyOCR to read text from the image with paragraph=True
            result = reader.readtext(img_np, detail=0, paragraph=True) # paragraph=True groups lines
            page_text = " ".join(result).strip()

            if page_text:
                blocks.append({"text": clean_text(page_text), "method": "pdf_ocr", "page": page_num + 1, "extra": {}})
                print(f"Extracted text from {pdf_path} page {page_num + 1} using easyOCR.")
            else:
                 print(f"No text extracted from {pdf_path} page {page_num + 1} using easyOCR.")


        pdf_document.close()
    except Exception as e:
        print(f"Error processing PDF {pdf_path} with easyOCR: {e}")
        # Return empty list in case of processing error for this file
        return []

    return blocks


# Integrated HWP Extraction function with fallbacks
def extract_text_from_hwp(hwp_path, hwpx_jar=None, soffice_cmd=None, ocr_langs=["ko","en"]):
    """
    Extracts text from an HWP file using pyhwp with fallbacks to load_hwp_text_blocks or PDF+OCR.

    Args:
        hwp_path (str): The path to the HWP file.
        hwpx_jar (str, optional): Path to the hwp2hwpx.jar file. Defaults to None.
        soffice_cmd (str, optional): Path to the LibreOffice executable. Defaults to None.
        ocr_langs (list, optional): List of languages for OCR. Defaults to ["ko","en"].


    Returns:
        list: A list of dictionaries, each containing 'text', 'method', 'page', and 'extra'.
              Returns an empty list if extraction fails completely.
    """
    blocks = []

    # 1. Try pyhwp (hwp5txt/pyhwp5txt)
    hwp_txt_path = _find_hwp_txt()
    if hwp_txt_path:
        try:
            code, stdout_txt, stderr_txt = _run_and_decode([hwp_txt_path, hwp_path])
            if code == 0 and stdout_txt and stdout_txt.strip():
                text = clean_text(stdout_txt)
                if text:
                    # pyhwp extracts the whole document, so treat as a single block
                    blocks.append({"text": text, "method": "pyhwp", "page": None, "extra": {}})
                    print(f"Extracted text from {hwp_path} using pyhwp.")
                    return blocks # Return immediately if successful
                else:
                     print(f"Warning: pyhwp extracted empty text from {hwp_path}.")
            else:
                print(f"Warning: {hwp_txt_path} failed for {hwp_path}: {stderr_txt}")
        except Exception as e:
            print(f"Warning: Error running pyhwp for {hwp_path}: {e}")
    else:
        print("Warning: pyhwp CLI not found (looked for 'pyhwp5txt'/'hwp5txt').")


    # 2. Fallback: Try load_hwp_text_blocks if available (Handles HWPX and potentially PDF+OCR)
    # This requires the user to have defined a working `load_hwp_text_blocks` function.
    if LOAD_HWP_TEXT_BLOCKS_AVAILABLE:
        print(f"Attempting fallback for {hwp_path} using load_hwp_text_blocks...")
        try:
            # Assuming load_hwp_text_blocks takes path, hwpx_jar, soffice_cmd, ocr_langs and returns blocks
            blocks = load_hwp_text_blocks(hwp_path, hwpx_jar=hwpx_jar, soffice_cmd=soffice_cmd, ocr_langs=ocr_langs)
            if blocks:
                print(f"Extracted text from {hwp_path} using load_hwp_text_blocks.")
                return blocks
            else:
                print(f"Warning: load_hwp_text_blocks returned no blocks for {hwp_path}.")
        except Exception as e:
            print(f"Warning: Error running load_hwp_text_blocks for {hwp_path}: {e}")
    else:
         print("Warning: load_hwp_text_blocks function not available. Skipping this fallback.")


    # 3. Minimal Internal PDF OCR Fallback if soffice is available and load_hwp_text_blocks wasn't used
    # This directly converts HWP to PDF and then uses the defined PDF OCR function.
    soffice_bin = find_executable('soffice') if not soffice_cmd else soffice_cmd
    if soffice_bin:
        print(f"Attempting minimal PDF+OCR fallback for {hwp_path} using soffice...")
        try:
            # Convert HWP→PDF
            with tempfile.TemporaryDirectory() as td:
                output_pdf_path = os.path.join(td, os.path.splitext(os.path.basename(hwp_path))[0] + '.pdf')
                print(f"Converting {hwp_path} to PDF at {output_pdf_path} using soffice...")
                code = subprocess.run([soffice_bin, '--headless', '--convert-to', 'pdf', '--outdir', td, hwp_path],
                                      capture_output=True).returncode
                if code == 0 and os.path.exists(output_pdf_path):
                    print(f"Successfully converted {hwp_path} to PDF.")
                    blocks = extract_text_from_pdf_easyocr(output_pdf_path, ocr_langs=ocr_langs)
                    if blocks:
                        print(f"Extracted text from {hwp_path} via PDF→OCR.")
                        return blocks
                    else:
                         print(f"Warning: PDF→OCR extraction returned no blocks for {hwp_path}.")
                else:
                    print(f"Warning: soffice conversion failed for {hwp_path}. Return code: {code}")
        except Exception as e:
            print(f"Warning: Error during PDF+OCR fallback for {hwp_path}: {e}")
    else:
        print("Warning: soffice command not found. Skipping PDF+OCR fallback.")


    # If all methods failed
    print(f"Error: Failed to extract text from HWP file {hwp_path} after trying all methods.")
    return []

def normalize_metadata(metadata: dict) -> dict:
    """
    Normalizes metadata keys and values, including currency and dates.
    """
    normalized = {}
    for key, value in metadata.items():
        # Normalize key names (e.g., remove spaces, convert to lowercase or snake_case)
        # For now, let's keep the original keys but clean up values
        cleaned_key = key.strip() # Simple cleaning

        # Normalize currency (assuming '사업 금액')
        if cleaned_key == '사업 금액' and pd.notna(value):
            try:
                # Remove non-digit characters except period and handle potential commas
                cleaned_value = str(value).replace(',', '').strip()
                # Convert to float, then to integer if it seems like a whole number
                normalized_value = float(cleaned_value)
                if normalized_value.is_integer():
                    normalized_value = int(normalized_value)
                normalized[cleaned_key] = normalized_value
            except (ValueError, TypeError):
                normalized[cleaned_key] = str(value).strip() # Keep as string if conversion fails
        # Normalize dates (assuming '공개 일자', '입찰 참여 시작일', '입찰 참여 마감일')
        elif cleaned_key in ['공개 일자', '입찰 참여 시작일', '입찰 참여 마감일'] and pd.notna(value):
             try:
                 # Attempt to parse various date formats
                 # Prioritize formats with time, then date only
                 if isinstance(value, str):
                     try:
                         normalized_value = datetime.fromisoformat(value.replace('Z', '+00:00')).isoformat()
                     except ValueError:
                         try:
                             normalized_value = datetime.strptime(value, '%Y-%m-%d %H:%M:%S').isoformat()
                         except ValueError:
                             try:
                                 normalized_value = datetime.strptime(value, '%Y-%m-%d').date().isoformat()
                             except ValueError:
                                  normalized_value = str(value).strip() # Keep as string if parsing fails
                 else:
                      normalized_value = str(value).strip() # Keep as string if not string
                 normalized[cleaned_key] = normalized_value
             except Exception:
                 normalized[cleaned_key] = str(value).strip() # Keep as string on any parsing error

        # Handle other metadata values (clean whitespace)
        elif pd.notna(value):
            normalized[cleaned_key] = str(value).strip()
        else:
             normalized[cleaned_key] = None # Keep NaN as None

    return normalized


# Initialize easyocr reader here to avoid re-initialization in PDF function
# This might take time on the first run due to model downloads
try:
    # reader = easyocr.Reader(["ko", "en"]) # Initialize with required languages
     pass # Initialize inside function to avoid global variable issues and allow language specification
except Exception as e:
    print(f"Error initializing easyocr reader: {e}")
    # Handle this error appropriately, perhaps by exiting or setting a flag


data_dir = '/content/drive/MyDrive/Data/files' # Updated path
csv_path = '/content/drive/MyDrive/Data/data_list.csv' # Path to data_list.csv

try:
    # Load data_list.csv into a pandas DataFrame
    data_list_df = pd.read_csv(csv_path)
except FileNotFoundError:
    print(f"Error: data_list.csv not found at {csv_path}")
    data_list_df = pd.DataFrame() # Create an empty DataFrame if file not found
except Exception as e:
    print(f"An error occurred while loading data_list.csv: {e}")
    data_list_df = pd.DataFrame() # Create an empty DataFrame on error


processed_documents = []
failed_files = [] # List to store files that failed processing

# Specify the files to process - based on previous examples and user request for top 4 HWP and top 1 PDF
# This assumes the order in data_list_df reflects the "top" files the user wants to process.
if not data_list_df.empty:
    hwp_files_to_process = data_list_df[data_list_df['파일형식'] == 'hwp']['파일명'].tolist()[:4]
    pdf_files_to_process = data_list_df[data_list_df['파일형식'] == 'pdf']['파일명'].tolist()[:1]
    files_to_process = hwp_files_to_process + pdf_files_to_process
else:
    files_to_process = []
    print("Cannot determine files to process as data_list.csv was not loaded.")


print(f"Attempting to process specified files from directory: {data_dir}")
print(f"Files selected for processing: {files_to_process}")

if not os.path.isdir(data_dir):
    print(f"Error: Directory not found at {data_dir}")
else:
    for filename in files_to_process:
        file_path = os.path.join(data_dir, filename)
        if os.path.isfile(file_path):
            # Get metadata for the current file and normalize it
            file_metadata = data_list_df[data_list_df['파일명'] == filename].iloc[0].to_dict() if filename in data_list_df['파일명'].values else {}
            normalized_metadata = normalize_metadata(file_metadata)

            extracted_blocks = []
            if filename.lower().endswith('.pdf'):
                try:
                    # Use the updated PDF extraction that returns blocks
                    extracted_blocks = extract_text_from_pdf_easyocr(file_path, ocr_langs=["ko", "en"]) # Specify languages
                except Exception as e:
                    print(f"Failed to process PDF {filename} with easyOCR: {e}")
                    failed_files.append(filename)

            elif filename.lower().endswith('.hwp'):
                try:
                    # Use the updated HWP extraction that returns blocks with fallbacks
                    extracted_blocks = extract_text_from_hwp(file_path, soffice_cmd=find_executable('soffice'), ocr_langs=["ko", "en"]) # Specify soffice and languages
                except Exception as e:
                    print(f"Failed to process HWP {filename}: {e}") # Update message
                    failed_files.append(filename)
            else:
                print(f"Skipping unsupported file type: {filename}")
                failed_files.append(filename) # Mark as failed due to unsupported type

            if extracted_blocks:
                for block in extracted_blocks:
                     # Add normalized metadata to the Document object
                    doc_metadata = {
                        "source": file_path,
                        "method": block.get("method", "unknown"),
                        "page": block.get("page", None),
                        **normalized_metadata # Merge normalized file metadata
                    }
                    processed_documents.append(Document(page_content=block["text"], metadata=doc_metadata))
                print(f"Successfully processed file: {filename}")
            else:
                print(f"No text blocks extracted from file: {filename}")
                if filename not in failed_files: # Avoid double-adding if already marked failed
                    failed_files.append(filename)


        else:
            print(f"Warning: Specified file not found: {filename}")
            failed_files.append(filename)


print("\nDocument processing complete.")
print(f"Total documents processed: {len(processed_documents)}")
if failed_files:
    print(f"Failed to process the following files: {failed_files}")


# Display one HWP and one PDF example with metadata if available
print("\nExamples of processed documents with metadata:")
hwp_example = next((doc for doc in processed_documents if doc.metadata.get('파일형식') == 'hwp'), None)
pdf_example = next((doc for doc in processed_documents if doc.metadata.get('파일형식') == 'pdf'), None)

if hwp_example:
    print("--- HWP Document Example ---")
    print(f"Content snippet: {hwp_example.page_content[:500]}...")
    print(f"Metadata: {hwp_example.metadata}")
else:
    print("No HWP documents were successfully processed with metadata.")

if pdf_example:
    print("\n--- PDF Document Example ---")
    print(f"Content snippet: {pdf_example.page_content[:500]}...")
    print(f"Metadata: {pdf_example.metadata}")
else:
    print("\nNo PDF documents were successfully processed with metadata.")
# Out:
# Attempting to process specified files from directory: /content/drive/MyDrive/Data/files
# Files selected for processing: ['한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp', '한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp', '인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp', '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf']
# Extracted text from /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp using pyhwp.
# Successfully processed file: 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp
# Extracted text from /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp using pyhwp.
# Successfully processed file: 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp
# Extracted text from /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp using pyhwp.
# Successfully processed file: 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp
# Extracted text from /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp using pyhwp.
# Successfully processed file: 인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 1 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 2 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 3 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 4 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 5 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 6 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 7 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 8 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 9 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 10 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 11 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 12 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 13 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 14 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 15 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 16 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 17 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 18 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 19 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 20 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 21 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 22 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 23 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 24 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 25 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 26 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 27 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 28 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 29 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 30 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 31 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 32 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 33 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 34 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 35 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 36 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 37 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 38 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 39 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 40 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 41 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 42 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 43 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 44 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 45 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 46 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 47 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 48 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 49 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 50 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 51 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 52 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 53 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 54 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 55 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 56 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 57 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 58 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 59 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 60 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 61 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 62 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 63 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 64 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 65 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 66 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 67 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 68 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 69 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 70 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 71 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 72 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 73 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 74 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 75 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 76 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 77 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 78 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 79 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 80 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 81 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 82 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 83 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 84 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 85 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 86 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 87 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 88 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 89 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 90 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 91 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 92 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 93 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 94 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 95 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 96 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 97 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 98 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 99 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 100 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 101 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 102 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 103 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 104 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 105 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 106 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 107 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 108 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 109 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 110 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 111 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 112 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 113 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 114 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 115 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 116 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 117 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 118 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 119 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 120 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 121 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 122 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 123 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 124 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 125 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 126 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 127 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 128 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 129 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 130 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 131 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 132 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 133 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 134 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 135 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 136 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 137 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 138 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 139 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 140 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 141 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 142 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 143 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 144 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 145 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 146 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 147 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 148 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 149 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 150 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 151 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 152 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 153 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 154 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 155 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 156 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 157 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 158 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 159 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 160 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 161 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 162 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 163 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 164 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 165 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 166 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 167 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 168 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 169 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 170 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 171 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 172 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 173 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 174 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 175 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 176 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 177 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 178 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 179 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 180 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 181 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 182 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 183 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 184 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 185 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 186 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 187 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 188 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 189 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 190 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 191 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 192 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 193 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 194 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 195 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 196 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 197 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 198 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 199 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 200 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 201 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 202 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 203 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 204 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 205 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 206 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 207 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 208 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 209 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 210 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 211 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 212 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 213 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 214 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 215 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 216 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 217 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 218 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 219 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 220 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 221 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 222 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 223 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 224 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 225 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 226 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 227 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 228 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 229 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 230 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 231 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 232 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 233 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 234 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 235 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 236 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 237 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 238 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 239 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 240 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 241 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 242 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 243 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 244 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 245 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 246 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 247 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 248 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 249 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 250 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 251 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 252 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 253 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 254 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 255 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 256 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 257 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 258 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 259 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 260 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 261 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 262 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 263 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 264 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 265 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 266 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 267 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 268 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 269 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 270 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 271 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 272 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 273 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 274 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 275 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 276 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 277 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 278 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 279 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 280 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 281 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 282 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 283 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 284 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 285 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 286 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 287 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 288 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 289 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 290 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 291 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 292 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 293 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 294 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 295 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 296 using easyOCR.
# Extracted text from /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf page 297 using easyOCR.
# Successfully processed file: 고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf
#
# Document processing complete.
# Total documents processed: 301
#
# Examples of processed documents with metadata:
# --- HWP Document Example ---
# Content snippet: 2024. 10. 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 사업예산 : 130,000,000원 범위 내 (VAT 포함) 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결) 학사제도 제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화 산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원 교수자학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현 학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립 트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
#
# --- PDF Document Example ---
# Content snippet: 콤W 보롬 고려대학교 KOREA UHIVERsITT 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024 7. 01 KOREA UICKSI 고려대학교 KOREA UNIVERSITY X 본 자료는 제안내용의 설명올 위한 배포자로로, 이외 목적으로 무단부제 , 전달 및 사용하는 행위틀 금함...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 1, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}

# %%
# Inspect the extracted text from HWP files before chunking
print("--- Inspecting Extracted HWP Content ---")
hwp_documents = [doc for doc in processed_documents if doc.metadata.get('파일형식') == 'hwp']

if hwp_documents:
    print(f"Found {len(hwp_documents)} HWP documents.")
    for i, doc in enumerate(hwp_documents):
        print(f"\n--- HWP Document {i+1}: {doc.metadata.get('파일명', 'N/A')} ---")
        print(f"Metadata: {doc.metadata}")
        # Print the full content or a substantial part of it
        print("\nContent:")
        print(doc.page_content[:2000]) # Print up to the first 2000 characters to inspect
        print("...") # Indicate truncated content if any
else:
    print("No HWP documents found in processed_documents.")

print("\n--- Inspection Complete ---")
# Out:
# --- Inspecting Extracted HWP Content ---
# Found 4 HWP documents.
#
# --- HWP Document 1: 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
#
# Content:
# 2024. 10. 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 사업예산 : 130,000,000원 범위 내 (VAT 포함) 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결) 학사제도 제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화 산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원 교수자학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현 학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립 트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현 (교과과정 개발에서 성적 이수까지) 트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화 (교육과정 / 수강신청 / 성적 / 학적관리 외) 확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함. 다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려 구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) 추진일정은 발주기관 와 계약상대자 의 상호협의를 통해 변경할 수 있음. 트랙제 교육과정 운영프로그램 개발 트랙제 기반 교육과정 운영 - 트랙제 기반 교육과정 운영 단계의 관리 절차에 대한 개선사항 도출 및 구현 트랙제 기반 교육과정 평가 및 통계관리- 트랙 교육과정 운영에 대한 통계현황 조회 및 출력 기능 구현 - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 학사 정보시스템 고도화 기 구축된 학사운영시스템 에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 정보기술 활용 전략 향후 우리대학 학사정보시스템의 환경 변화에 대비하여 상용 DBMS(Oracle, MS SQL Server)를 적용할 수 있도록 구현하여야 함 데이터의 정합성과 무결성 확보를 위한 데이터베이스 재설계 및 통합 구축 최신 IT기술을 활용하여 사용성과 편의성, 생산성을 극대화 유지보수의 용이성 및 기술적 안정성이 높은 개발환경 제공 향후 변화하는 발주기관의 특성을 고려하여 능동적이고 효율적인 시스템으로 구성하여야 한다. 시스템은 향후 확장성을 충분히 고려하여 설계적용되어야 한다. 안정적, 효율적, 확장 가능한 최적 시스템으로 구축하며 사용자의 다양한 요구에 부흥하도록 구성하여야 한다. 수작업을 최소화하고, 가능한 전산으로 모든 업무를 처리할 수 있도록 시스템을 구성하여야 한다. 사용자의 편의성을 고려한 Work Flow 중심의 트랙 교육과정 개발 및 운영이 이뤄질 수 있도록 구성하여야 한다. 트랙기반 교육과정 운영체제 구축에 따른 한영대학교 종합정보시스템 기능을 연계하여야 한다. 현재 구축되어 있는 한영대학교 종합정보시스템 구축 환경을 고려하여 시스템을 구현하여야 한다. 개발대상 업무의 범위는 업무분석 결과 및 추가요청 등에 따라 변동 될 수 있음 개인정보보호를 고려하여 시스템 설계를 하여야 한다. 제안되는 모든 S/W는 기존 환경을 고려하여 개발 되어야하며, 기능상의 제한 등으로 인하여 불가피한 경우에는 그 사유 및 대안을 제시하여야 한다. Reporting 전용 툴을 사용하여 출력물을 설계하되, 기능면에서 제한사항이 있으면 이에 대한 사유를 명시하고 대안을 제시하여야 한다. 통계보고서의 정형화 및 대학 전체가 공통된 내용의 업무지표 사용과 조회자료의 편리한 Export 지원(Excel 등)이 되어야 한다. 구성원별(교수/직원/조교 등), 소속부
# ...
#
# --- HWP Document 2: 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241002912', '공고 차수': '0.0', '사업명': '2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선', '사업 금액': 129300000, '발주 기관': '한국연구재단', '공개 일자': '2024-10-04T15:01:52', '입찰 참여 시작일': '2024-10-14T10:00:00', '입찰 참여 마감일': '2024-10-16T14:00:00', '사업 요약': '- 사업 개요: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선\n- 추진배경: 대학 산학협력활동 실태조사를 안정적으로 운영하고 사용자 편의성을 개선하기 위해 필요\n- 사업범위: UICC 시스템 기능개선 및 운영지원, 대학정보공시 연계 기능 개선\n- 기대효과: 실태조사를 안정적으로 운영하고 사용자 편의성을 개선하여 대학 산학협력활동을 효율적으로 추진\n- 추진목표: UICC 시스템 기능개선을 통한 이용 편의성 개선, UICC 시스템 운영 지원을 통한 안정적인 실태조사 추진', '파일형식': 'hwp', '파일명': '한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp', '텍스트': '제 안 요 청 서\r\n[ 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선 ]\r\n2024.  10.\r\n \r\n담 당\r\n부  서  명\r\n성  명\r\n전    화\r\n사업관련\r\n학술데이터분석팀\r\n한민아\r\n042-869-6672\r\n계약관련\r\n운영지원팀\r\n이현우\r\n042-869-6232\r\n \r\n \r\n이 자료는 한국연구재단 제안서 작성 이외의 목적으로 복제, 전달 및 사용을 금함\r\n \r\n순    서\r\n목차\r\nⅠ. 사업개요\t  -   \t3\r\nⅡ. 추진방안\t  -   \t5\r\nIII. 시스템 운영현황\t  -   \t7\r\nIV. 제안요청내용\t  -   \t8\r\nⅤ. 제안안내\t  -   \t58\r\nⅥ. 제안서 작성요령\t  -   \t75\r\n[제안서 작성 참고자료] 표준화 방안\t  -   \t79\r\n[붙임1] 기술적용계획표\t  -   \t81\r\n[붙임2] 정량평가 관련 세부기준\t  -   \t89\r\n첨부서식\t  -   \t92\r\n  \r\n \r\n \r\n 제안요청서\r\nⅠ\r\n사업 개요\r\n1. 사업명: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선\r\n2. 추진배경 및 필요성\r\n   한국연구재단법 제5조, 산업교육진흥 및 산학연협력촉진에 관한 법률 제39조의2 및 제43조에 따라 실시하는 대학 산학협력활동 실태조사를 안정적으로 운영 필요 \r\n   항목 지침 변경사항 등 변화에 신속하고 정확하게 대응하며, 기능개선에 대한 사용자 요구를 반영하여 사용자 편의성 강화 필요\r\n   UICC의 효율적인 관리와 운영을 위한 지원 체계 및 각종 기관 요구사항에 대응 필요\r\n3. 주관기관 : 한국연구재단\r\n4. 사업기간 및 사업비\r\n   사업기간 : 계약일로부터 210일\r\n   사업금액 : 129,300,000원(부가세 포함)\r\n  ㅇ 예산 세부내역 \r\n \r\n구분\r\n금액\r\n비고\r\n SW 개발비\r\n92,300,000원 이내\r\n- 실태조사 시스템 기능 개선\r\n운영지원 및 \r\n데이터 점검\r\n37,000,000원 이내\r\n- 실태조사 시스템 운영지원\r\n- 실태조사 데이터 검증 및 보정\r\n5. 사업 내용\r\n   UICC 시스템 기능개선   ※ 세부 내용은 “Ⅳ. 제안요청사항” 참고\r\n  ㅇ (데이터 입력 기능) 데이터 입력 오류 개선 및 정확성 제고\r\n    - KRI 데이터 연계, 오류 알림 인터페이스, 엑셀 다운로드 기능 개선 등\r\n  ㅇ (실태조사 항목 지침 변경사항 반영) 2024년 실태조사 변경사항 반영 \r\n   관리자 활용도 제고를 위한 기능 개선\r\n  ㅇ (시스템 관리자 기능) 학교-학과 코드 관리 방식, 메일 전송 기능 개선\r\n  ㅇ (시스템 데이터 관리) 대학별 및 기간별 접속 현황 등 시스템 데이터 관리 기능 개선\r\n  ㅇ (대학정보공시 연계)대학정보공시 연계 데이터 전송 속도 개선 및 연계 플랫폼과의 데이터 점검 기능 강화\r\n   UICC 시스템 운영 지원\r\n  ㅇ 실태조사 기간 중 발생하는 시스템 오류 개선\r\n  ㅇ 사용자가 원활하게 시스템을 이용할 수 있도록 운영 지원\r\n  ㅇ 클라우드 서버 운영 및 발생 가능한 장애 사전 차단\r\n  ㅇ 실태조사 데이터 오류 점검 및 대학 정보공시 연계 지원\r\n6. 기대 효과\r\n   UICC의 효율적 관리 체계를 구축하여 실태조사를 안정적으로 운영\r\n   실태조사 항목 지침 변경사항을 반영하고 시스템 기능을 개선하여 \n사용자 편의성 도모 \r\n  \r\n \r\n \r\n 제안요청서\r\nⅡ\r\n추진방안\r\n1. 추진목표\r\n   UICC 시스템 기능개선을 통해 이용 편의성 개선\r\n   UICC 시스템 운영 지원을 통해 안정적으로 실태조사 추진\r\n2. 추진전략\r\n   능력과 경험이 풍부한 전문사업자를 주관사업자로 선정\r\n  ㅇ 시스템 구축에 대한 경험이 풍부하고 인력관리, 품질관리 및 유지관리 능력이 우수한 업체를 주관사업자로 선정하여 사업 진행\r\n  ㅇ 재단-대학과의 원활한 소통을 바탕으로 효율적 협력체계 마련\r\n   정보기술 활용전략\r\n  ㅇ 한국연구재단에서 운영하는 기존 정보시스템과 연계 호환성 유지\r\n  ㅇ 한국연구재단의 보안, 네트워크 등의 기반 인프라를 최대한 활용하여 비용 대비 최대의 효율을 낼 수 있는 정보시스템 구축\r\n   표준화 전략\r\n  ㅇ 프로젝트 수행 표준안을 제정하고 이를 준수하여 향후 운영-유지보수의 편이성 확보\r\n  ㅇ 행정안전부의  행정기관 및 공공기관 정보시스템 구축-운영 지침  준수\r\n   보안 전략\r\n  ㅇ 정부-재단의 각종 테스트, 보안지침을 준수하여 시스템 운영 및 유지관리 업무수행\r\n3. 추진체계\r\n \r\n사업총괄책임자\r\n한국연구재단 데이터정보센터장\r\n사업관리 총괄\r\n한국연구재단 학술데이터분석팀\r\n시스템 구축 지원\r\n 시스템 개발\r\n대학 정보공시 연계 협업\r\n한국연구재단 정보시스템지원팀, 정보보안팀\r\n시스템구축 사업자(외주업체)\r\n한국연구재단 정보시스템지원팀, 정보보안팀\r\n한국대학교육협의회\r\n4. 추진일정\r\n   사업기간 : 계약일로부터 210일\r\n   추진일정표\r\n \r\n주요내용\r\n개월\r\nM\r\nM+1\r\nM+2\r\nM+3\r\nM+4\r\nM+5\r\nM+6\r\n계약 및 사업준비\r\n시스템 기능개선\r\n착수\r\n분석\r\n설계\r\n구현\r\n테스트\r\n시스템 안정화\r\n시스템 운영지원\r\n클라우드 서버 운영\r\n데이터 점검 및 \r\n대학 정보공시 연계 지원\r\n최종완료보고\r\n  \r\n \r\n \r\n 제안요청서\r\nⅢ\r\n시스템 운영현황\r\n1. UICC 시스템 현황  \r\n   클라우드 및 소프트웨어 구성도\r\n \r\n“필요시 열람 허용”\r\n   정보시스템 클라우드 상세내역\r\n \r\n구분\r\n품목(용도)\r\nOS 종류\r\n미들웨어 라이센스 종류(수)\r\n수량(EA)\r\n비고\r\n클라우드\r\nUICC WAS\r\nRHEL\r\nLENA WEB(4)\r\n1\r\n클라우드\r\nUICC WEB\r\nRHEL\r\nLENA WAS(4)\r\n2\r\n클라우드'}
#
# Content:
# 2024. 10. 1. 사업명: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선 2. 추진배경 및 필요성 한국연구재단법 제5조, 산업교육진흥 및 산학연협력촉진에 관한 법률 제39조의2 및 제43조에 따라 실시하는 대학 산학협력활동 실태조사를 안정적으로 운영 필요 항목 지침 변경사항 등 변화에 신속하고 정확하게 대응하며, 기능개선에 대한 사용자 요구를 반영하여 사용자 편의성 강화 필요 UICC의 효율적인 관리와 운영을 위한 지원 체계 및 각종 기관 요구사항에 대응 필요 3. 주관기관 : 한국연구재단 4. 사업기간 및 사업비 사업기간 : 계약일로부터 210일 사업금액 : 129,300,000원(부가세 포함) 예산 세부내역 5. 사업 내용 UICC 시스템 기능개선 세부 내용은 . 제안요청사항 참고 (데이터 입력 기능) 데이터 입력 오류 개선 및 정확성 제고 - KRI 데이터 연계, 오류 알림 인터페이스, 엑셀 다운로드 기능 개선 등 (실태조사 항목 지침 변경사항 반영) 2024년 실태조사 변경사항 반영 관리자 활용도 제고를 위한 기능 개선 (시스템 관리자 기능) 학교학과 코드 관리 방식, 메일 전송 기능 개선 (시스템 데이터 관리) 대학별 및 기간별 접속 현황 등 시스템 데이터 관리 기능 개선 (대학정보공시 연계)대학정보공시 연계 데이터 전송 속도 개선 및 연계 플랫폼과의 데이터 점검 기능 강화 UICC 시스템 운영 지원 실태조사 기간 중 발생하는 시스템 오류 개선 사용자가 원활하게 시스템을 이용할 수 있도록 운영 지원 클라우드 서버 운영 및 발생 가능한 장애 사전 차단 실태조사 데이터 오류 점검 및 대학 정보공시 연계 지원 6. 기대 효과 UICC의 효율적 관리 체계를 구축하여 실태조사를 안정적으로 운영 실태조사 항목 지침 변경사항을 반영하고 시스템 기능을 개선하여 사용자 편의성 도모 1. 추진목표 UICC 시스템 기능개선을 통해 이용 편의성 개선 UICC 시스템 운영 지원을 통해 안정적으로 실태조사 추진 2. 추진전략 능력과 경험이 풍부한 전문사업자를 주관사업자로 선정 시스템 구축에 대한 경험이 풍부하고 인력관리, 품질관리 및 유지관리 능력이 우수한 업체를 주관사업자로 선정하여 사업 진행 재단대학과의 원활한 소통을 바탕으로 효율적 협력체계 마련 정보기술 활용전략 한국연구재단에서 운영하는 기존 정보시스템과 연계 호환성 유지 한국연구재단의 보안, 네트워크 등의 기반 인프라를 최대한 활용하여 비용 대비 최대의 효율을 낼 수 있는 정보시스템 구축 표준화 전략 프로젝트 수행 표준안을 제정하고 이를 준수하여 향후 운영유지보수의 편이성 확보 행정안전부의 행정기관 및 공공기관 정보시스템 구축운영 지침 준수 보안 전략 정부재단의 각종 테스트, 보안지침을 준수하여 시스템 운영 및 유지관리 업무수행 3. 추진체계 4. 추진일정 사업기간 : 계약일로부터 210일 추진일정표 1. UICC 시스템 현황 클라우드 및 소프트웨어 구성도 정보시스템 클라우드 상세내역 1. 상세 요구사항 요구사항 총괄표 요구사항 목록 요구사항 상세 내용 (1) 기능요구사항(SFR) (2) 성능 요구사항(PER) (3) 인터페이스 요구사항(INR) (4) 데이터 요구사항(DAR) (5) 테스트 요구사항(TER) (6) 보안 요구사항(SER) (7) 제약 요구사항(COR) (8) 프로젝트 관리 요구사항(PMR) (9) 프로젝트 지원 요구사항(PSR) (11) 운영 요구사항(SOR) 3. 정보보안 관리 및 준수사항 통합 보안계획서를 작성하여 한국연구재단의 승인 필요 공통 사항 사업자는 재단의 보안정책을 위반하였을 경우 사업자 보안 위규 처리 기준 에 따라 위규자 및 관리자를 행정조치하고, 보안 위약금 부과 기준 의 보안 위약금을 재단에 납부함 사업자는 장비, 자료(산출물 및 사업관련 자료 포함), 네트워크 등에 대한 물리적 관리적 기술적 보안대책과 누출금지 대상 정보에 대한 보안관리 계획을 사업제안서에 기재해야하며, 누출금지 대상 정보 누출 시 국가계약법 시행령 제76조에 따라 사업자를 부정당업체로 등록하고 입찰 참가를 제한함 사업 수행과정에서 취득한 자
# ...
#
# --- HWP Document 3: 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20240827859', '공고 차수': '0.0', '사업명': 'EIP3.0 고압가스 안전관리 시스템 구축 용역', '사업 금액': 40000000, '발주 기관': '한국생산기술연구원', '공개 일자': '2024-08-28T11:31:02', '입찰 참여 시작일': '2024-08-29T09:00:00', '입찰 참여 마감일': '2024-09-09T10:00:00', '사업 요약': '- 사업 개요: EIP3.0 고압가스 안전관리 시스템 구축 용역\n- 추진배경: 안전사고 증가, 법적 요구사항, 연구 환경 보호에 대한 필요성\n- 사업범위: 화학물질 운영현황 통계 정보 제공, 고압가스 화학물질 관리 시스템 구축, 안전성 검토 과정 시스템 고도화, 법적 준수와 연구실 관리 시스템 고도화, 화학제품 폐기-회수 관리 시스템 고도화\n- 기대효과: 연구실 안전 확보, 법적 준수, 효율적 관리 시스템 도입', '파일형식': 'hwp', '파일명': '한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp', '텍스트': 'EIP3.0 고압가스 안전관리\r\n시스템 구축 용역\r\n2024. 08.\r\n \r\n디지털행정추진실\r\n한국생산기술연구원\r\n \r\n담당\r\n사양 및 과업\r\n디지털행정추진실\r\n전재우\r\nTEL: \r\n041-589-8095\r\nFAX : \r\n041-589-8095\r\n입찰 및 계약\r\n구매장비관리실\r\n담당자\r\nTEL: \r\n041-589-85XX\r\nFAX:\r\n041-589-8540\r\n목 차  \r\n \r\n   \r\n1. 사업'}
#
# Content:
# 2024. 08. 목 차 1. 사업 개요 가. 추진배경 및 필요성 안전사고 증가 - 고압가스 취급 부주의로 인한 연구실 사고가 빈번하게 발생하고 있으며, 이는 인명 피해와 연구 기기 손상을 초래함 법적 요구사항 - 안전 관리에 대한 법적 요구사항과 규제가 강화되고 있으며, 이를 준수하지 않을 경우 법적 책임과 벌금이 부과 연구 환경 보호 - 연구원들의 건강과 안전을 보호하고, 안전한 연구 환경을 제공하기 위해 체계적인 관리 시스템 구축 필요 나. 사업 범위 원내에서 관리하는 화학물질 운영현황의 통계 정보를 제공하는 시스템 구축 고압가스 화학물질의 정보와 판매허가 업체를 관리하기 위한 시스템 구축 고압가스 화학물질의 구매부터 안전성 검토 과정을 진행하기 위한 시스템 고도화 연구실과 법적 준수 사항을 관리하기 위한 시스템 고도화 화학제품 폐기회수를 관리하기 위한 시스템 고도화 다. 기대효과 연구실 안전 확보 - 고압가스의 안전한 관리를 통해 연구원들의 생명과 신체를 보호하고, 연구실 내 안전사고를 예방하는 것을 목표로 함 법적 준수 - 정부 및 관련 기관의 규제와 법적 요구사항을 준수하여 법적 문제를 예방하고, 안전 관리 수준을 법적 기준 이상으로 유지 효율적 관리 시스템 도입 - 고압가스의 사용, 저장, 폐기 등을 체계적으로 관리할 수 있는 시스템을 도입하여 효율성을 높이고, 안전 관리를 용이하게 함 2. 시스템 현황 가. 대상 시스템 - EIP3.0 업무포털 종합정보시스템 나. 시스템 현황 시스템구성도 H/W 운영 현황 관련기반 소프트웨어 현황 응용시스템 아키텍쳐 업무포털종합정보시스템 - 한국생산기술연구원 기간계 시스템으로, 인사, 급여, 재무, 예산, 연구관리, 기업지원, 출장, 총무 등 전사 자원 관리 및 운영 시스템 업무 메뉴 및 전자결재 운영 현황 (2022.12.31.기준) 연구관리, 기업지원, 재무, 인사, 급여, 구매조달, 지재권 등 19개 업무시스템 운영 연계시스템 (2023.12.31. 기준) 장비 현황 - 운용 중인 전산장비는 총 1,205종이며, 840종을 서비스수준협약(SLA)을 통하여 안정적인 서비스와 신속한 장애 복구 체계 구축 3. 사업 추진방안 가. 추진목표 원내에서 관리하는 화학물질 운영현황의 통계 정보 공유 고압가스 화학물질의 정보와 판매허가 업체를 관리 고압가스 화학물질의 구매부터 안전성 검토 과정을 제공 연구실과 법적 준수 사항을 관리 나. 추진방안 - EIP3.0 업무포털 종합정보 시스템 내 안전관리 업무/결재 시스템의 고압가스 화학물질 관련 신규개발 및 As-Is 화학물질 관리 시스템 고도화 - 고압가스 안전관리 시스템 프로세스 맵에 따른 EIP3.0 업무포털 전산 시스템 신규개발 및 고도화 다. 추진체계 구성도 역할 라. 추진일정(사업기간: 계약체결일 ~ 2024.12.27.) 4. 제안요청 내용 가. 제안요청 개요 1) 사업명 : EIP3.0 고압가스 안전관리 시스템 구축 용역 2) 사업기간 : 계약체결일 ~ 2024.12.27.(5.5M/M) 3) 사업금액 : 40,000천원(부가세 포함) 4) 계약방법 : 제한경쟁입찰 / 협상에 의한 계약 (입찰자격) 직접생산 소프트웨어 중소기업 사업자 및 소상공인(대기업 제한) 5) 사업범위 원내에서 관리하는 화학물질 운영현황의 정보를 제공하는 시스템 구축 고압가스 화학물질의 정보와 판매허가 업체를 관리하기 위한 시스템 구축 고압가스 화학물질의 구매부터 안전성 검토 진행을 위한 시스템 고도화 연구실과 법적 준수 사항을 관리하기 위한 시스템 고도화 화학제품 폐기회수를 관리하기 위한 시스템 고도화 (이 하 여 백) 요구사항 총괄표 (이 하 여 백) 요구사항 목록표 나. 상세요구사항 1) 기능 요구사항(System Function Requirement) 2) 성능 요구사항(PER, Performance Requirement) 3) 인터페이스 요구사항(Interface Requirement) (이 하 여 백) 4) 데이터 요구사항(Data Requirement) (이 하 여 백) 5) 테스트 요구사항(TER, Test Requirement)
# ...
#
# --- HWP Document 4: 인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20240430918', '공고 차수': '0.0', '사업명': '도시계획위원회 통합관리시스템 구축용역', '사업 금액': 150000000, '발주 기관': '인천광역시', '공개 일자': '2024-04-18T16:26:32', '입찰 참여 시작일': '2024-05-02T10:00:00', '입찰 참여 마감일': '2024-05-09T16:00:00', '사업 요약': '- 사업명: 도시계획위원회 통합관리시스템 구축 용역\n- 용역개요: 도시계획위원회와 도시-건축공동위원회의 통합관리시스템 구축\n- 과업배경 및 목적: 수작업으로 처리되던 위원회 업무의 복잡성 해결과 자료 관리 및 보안 문제 개선\n- 과업의 범위: 시스템 구축, 위원회 운영 지원, 내부시스템 연계, 사용자 교육 및 유지관리\n- 기대효과: 체계적-통합적 위원회 운영과 업무 효율성 제고, 자료 관리와 활용 체계 구축, 위원회 심의 지원 및 아카이브 구축', '파일형식': 'hwp', '파일명': '인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp', '텍스트': '도시계획위원회 통합관리시스템 구축\r\n제 안 요 청 서\r\n2024. 4\r\n    \r\n \r\n \r\n 도시계획과 \r\n \r\n목    차\r\nⅠ. 과업의 개요\t  -   \t1\r\n  1. 과 업 명\t  -   \t1\r\n  2. 용역개요\t  -   \t1\r\n  3. 과업배경 및 목적\t  -   \t1\r\n  4. 과업의 범위\t  -   \t2\r\n  5. 기대효과\t  -   \t3\r\nⅡ. 사업추진방안\t  -   \t3\r\n  1. 추진목표\t  -   \t3\r\n  2. 추진체계\t  -   \t3\r\n  3. 추진일정\t  -   \t4\r\n  4. 추진방안\t  -   \t4\r\nⅢ. 제안요청 내용\t  -   \t4\r\n  1. 일반사항\t  -   \t4\r\n  2. 사업내용\t  -   \t5\r\n  3. 제안요청 내용\t  -   \t6\r\nⅣ. 입찰 및 계약에 관한 사항\t  -   \t45\r\n  1. 사업자 선정\t  -   \t45\r\n  2. 입찰 참가자격\t  -   \t45\r\n  3. 입찰 참가 시 주의사항\t  -   \t48\r\nⅤ. 입찰 등록 및 제안서 제출\t  -   \t50\r\n  1. 제출 안내 \t  -   \t50\r\n  2. 제출서류\t  -   \t51\r\nⅥ. 제안서 작성요령 및 서식\t  -   \t52\r\n  1. 제안서 작성방법\t  -   \t52\r\n  2. 제안서 서명 및 효력\t  -   \t55\r\nⅦ. 제안서 평가 및 협상\t  -   \t56\r\n  1. 제안서 평가방법\t  -   \t56\r\n  2. 평가요소 및 배점한도(제안서 심사   기준표)\t  -   \t57\r\n  3. 정량적 평가기준\t  -   \t58\r\nⅧ. 협상대상자 선정 및 협상\t  -   \t61\r\n  1. 협상적격자 및 협상순위 산정\t  -   \t61\r\n  2. 협상적격자 통지 및 협상 절차\t  -   \t61\r\n  3. 협상기간\t  -   \t61\r\n  4. 협상내용과 범위\t  -   \t62\r\n  5. 계약체결 및 이행\t  -   \t62\r\n \r\nⅠ\r\n 과업의 개요   \r\n 1. 과 업 명:  도시계획위원회 통합관리시스템 구축 용역 \r\n 2. 용역개요\r\n    용 역 명: 도시계획위원회 통합관리시스템 구축 용역\r\n    기    간: 착수일로부터 180일\r\n    사 업 비: 금150,000,000원 (VAT 포함)\r\n    계약방법: 제한경쟁입찰(협상에 의한 계약) \r\n   \r\n※ 본 사업은  소프트웨어 진흥법  제50조에 따른 과업내용 확정을 위하여 과업심의위원회를 개최한 사업으로,  소프트웨어 진흥법  제50조,  같은 법 시행령 제47조 제1항 제2호, 제3호에 따라  과업내용 변경 및 그에 따른 계약금액-계약기간 조정이 필요한 경우 계약상대자는 국가기관등의 장에게 소프트웨어사업 과업변경요청서를 제출하여 과업심의위원회의 개최를 요청할 수 있으며, 국가기관등의 장은 과업심의위원회 개최요청에 대해서 특별한 사정이 없으면 수용해야 함.\r\n   \r\n※ 본 사업은  소프트웨어 진흥법  제43조, 같은 법 시행령 제35조,  소프트웨어사업 계약 및 관리감독에 관한 지침  (과학기술정보통부 고시)제5조에 따라 소프트웨어사업 영향평가를 미리 실시한 사업임(붙임 1 참고)\r\n   \r\n※ 본 사업은  소프트웨어사업 계약 및 관리감독에 관한 지침 (과학기술정보통신부고시) 제6조의 규정에 의거한 ‘소프트웨어 개발사업의 적정 사업기간 산정 기준에 따른 사업’ 임\r\n 3. 과업배경 및 목적\r\n    (수작업에 의한 업무의 복잡성) 여러 단계의 위원회 운영업무를 수작업으로 처리, 업무의 복잡성 발생\r\n‧ 심의자료 변경 시 자료의 재배포 등 업무의 중복성 발생 \r\n   위원회 전 과정의 지원체계 구축 필요\r\n    (통합관리시스템 부재로 업무별 개별 처리) 사전준비 단계에서 행정절차는 인천광역시 업무관리시스템을 사용하고, 외부위원은 개별메일 이용\r\n   업무관리시스템, 유관시스템과의 연계체계 필요\r\n    (안건별 처리내역(이력) 관리가 어려움) 심의안건별 처리이력의 관리가 어려움. 전체 심의안건에 대한 일목요연한 현황관리 및 현황파악이 어려움\r\n 위원회별, 안건별 현황관리체계 구축 필요\r\n    (업무 및 자료의 보안 문제 내포)회의 진행 및 자료공개는 비공개를 원칙으로 하나, 외부 위원 대상 심의자료가 메일로 배포되고 있어 자료유출과 관련된 보안의 문제 발생 내포\r\n 자료접근 및 활용에 따른 사용자 권한체계 구축  \r\n4. 과업의 범위\r\n    시스템 구축 대상 위원회\r\n    - 대상(2개) : 도시계획위원회, 도시-건축공동위원회\r\n ※ 위원회 운영확대 및 시스템 고도화 방안 제시\r\n    운영시스템 구조 설계 및 구축 부문\r\n    - 위원회 운영을 위한 사용자별 권한 및 기능 구축\r\n    - 위원회 개최 준비(개최 등록, 안건 등록, 회의소집, 자료 배포 등)를 위한 기능 구축\r\n    - 위원회 심의 운영(회의 진행, 안건 설명, 안건 심의 등) 지원을 위한 기능 구축\r\n    - 위원회 개최 후 결과보고 및 후속조치 등을 위한 기능 구축\r\n    - 위원회 운영 단계별 산출 자료(개최개요, 상정자료, 회의록 및 개최 결과, 보도자료 등) 및 관련 자료에 대한 관리 기능\r\n    - 안건별 이력관리 및 산출 자료 활용(자료 검색, 통계 분석, 보고서 작성 등) 기능\r\n    - 위원회 확대에 대비한 메인화면 구성 및 사용편의성 강화 방안 마련\r\n    - 외부위원의 경우 외부망(인터넷망)을 통하여 접근이 가능 하도록 구성\r\n   * 임의 사용자가 시스템 사용할 수 없도록 권한 관리 철저(회원가입 불가, 임시 아이디 제공 등)\r\n    내부시스템 연계 부문\r\n    - 인천광역시 업무정책포털, 인천시 공간정보플랫폼, UMS시스템 등과 \n연계를 통한 업무 처리 및 행정 절차 연계\r\n    - 부서 등 조직개편에 대응한 자료구조체계 마련\r\n    사용자 교육 및 유지관리\r\n    - 관리자/사용자 매뉴얼 작성 및 시스템 교육\r\n    - 시스템 운영 및 유지관리 방안\r\n5.  기대효과\r\n    시스템 구축 통한 체계적-통합적 위원회 운영 및 관리에 따른 업무 효율성 제고\r\n    위원회 심의 관련 자료의 체계적 이력관리 및 통계관리 등을 통한 자료의 활용 가능성 강화\r\n    위원회 아카이브를 구축하여 위원회 운영관련 자료(관련 계획 및 기준, 내부 방침 등) 활용을 통한 위원회 심의 지원\r\n \r\nⅡ\r\n 사업추진방안\r\n ...
#
# Content:
# 1. 과 업 명: 도시계획위원회 통합관리시스템 구축 용역 2. 용역개요 용 역 명: 도시계획위원회 통합관리시스템 구축 용역 기 간: 착수일로부터 180일 사 업 비: 금150,000,000원 (VAT 포함) 계약방법: 제한경쟁입찰(협상에 의한 계약) 3. 과업배경 및 목적 (수작업에 의한 업무의 복잡성) 여러 단계의 위원회 운영업무를 수작업으로 처리, 업무의 복잡성 발생 심의자료 변경 시 자료의 재배포 등 업무의 중복성 발생 위원회 전 과정의 지원체계 구축 필요 (통합관리시스템 부재로 업무별 개별 처리) 사전준비 단계에서 행정절차는 인천광역시 업무관리시스템을 사용하고, 외부위원은 개별메일 이용 업무관리시스템, 유관시스템과의 연계체계 필요 (안건별 처리내역(이력) 관리가 어려움) 심의안건별 처리이력의 관리가 어려움. 전체 심의안건에 대한 일목요연한 현황관리 및 현황파악이 어려움 위원회별, 안건별 현황관리체계 구축 필요 (업무 및 자료의 보안 문제 내포)회의 진행 및 자료공개는 비공개를 원칙으로 하나, 외부 위원 대상 심의자료가 메일로 배포되고 있어 자료유출과 관련된 보안의 문제 발생 내포 자료접근 및 활용에 따른 사용자 권한체계 구축 4. 과업의 범위 시스템 구축 대상 위원회 - 대상(2개) : 도시계획위원회, 도시건축공동위원회 위원회 운영확대 및 시스템 고도화 방안 제시 운영시스템 구조 설계 및 구축 부문 - 위원회 운영을 위한 사용자별 권한 및 기능 구축 - 위원회 개최 준비(개최 등록, 안건 등록, 회의소집, 자료 배포 등)를 위한 기능 구축 - 위원회 심의 운영(회의 진행, 안건 설명, 안건 심의 등) 지원을 위한 기능 구축 - 위원회 개최 후 결과보고 및 후속조치 등을 위한 기능 구축 - 위원회 운영 단계별 산출 자료(개최개요, 상정자료, 회의록 및 개최 결과, 보도자료 등) 및 관련 자료에 대한 관리 기능 - 안건별 이력관리 및 산출 자료 활용(자료 검색, 통계 분석, 보고서 작성 등) 기능 - 위원회 확대에 대비한 메인화면 구성 및 사용편의성 강화 방안 마련 - 외부위원의 경우 외부망(인터넷망)을 통하여 접근이 가능 하도록 구성 임의 사용자가 시스템 사용할 수 없도록 권한 관리 철저(회원가입 불가, 임시 아이디 제공 등) 내부시스템 연계 부문 - 인천광역시 업무정책포털, 인천시 공간정보플랫폼, UMS시스템 등과 연계를 통한 업무 처리 및 행정 절차 연계 - 부서 등 조직개편에 대응한 자료구조체계 마련 사용자 교육 및 유지관리 - 관리자/사용자 매뉴얼 작성 및 시스템 교육 - 시스템 운영 및 유지관리 방안 5. 기대효과 시스템 구축 통한 체계적통합적 위원회 운영 및 관리에 따른 업무 효율성 제고 위원회 심의 관련 자료의 체계적 이력관리 및 통계관리 등을 통한 자료의 활용 가능성 강화 위원회 아카이브를 구축하여 위원회 운영관련 자료(관련 계획 및 기준, 내부 방침 등) 활용을 통한 위원회 심의 지원 1. 추진목표 각 실국 내 도시계획관련 위원회 통합관리운영지원 시스템 구축 위원회 관련 자료에 대한 관리 및 활용 체계 구축 위원회 아카이브 구축 및 연계를 통한 위원회 심의지원시스템 구축 2. 추진체계 3. 추진일정 추진일정은 발주기관 와 계약상대자 의 상호협의를 통해 변경할 수 있음. 4. 추진방안 긴급발주에 관한 사항 : 해당없음 분리발주에 관한 사항 : 해당없음 1. 일반사항 본 사업은 도시계획위원회 통합관리시스템 구축 용역 을 위해 추진되는 사업으로 포괄적이고 체계적인 접근방법으로 제안하여야 함 본 제안요청서에 기술하지 않았으나, 사업의 추진 시 필수적이라고 판단되는 사항은 제안범위에 포함하여 제안하여야 함 본 제안요청서 및 이후 제안서 제출까지 발생하는 모든 사안에 대하여는 보안을 요하며, 제안서와 관련하여 제안참가 업체는 타 업체 또는 외부기관으로의 제안요청 관련 사항 공개를 금함 본 사업 수행 중 취득한 인천광역시의 정보통신 보안사항 일체에 대하여 보안을 유지하여야 하며, 내부자료 유출 등 문제발생 시 수행업체가 모든 민 형사상 책임을 져야 함 2. 사업내용 세부과업내용은 I. 4. 과업의 범위(P
# ...
#
# --- Inspection Complete ---

# %% [markdown]
# # Implement Semantic Chunking

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# While true semantic chunking often requires deeper document structure analysis
# or advanced models, we can use RecursiveCharacterTextSplitter with parameters
# tuned to try and respect some structural elements like paragraphs or headings
# by splitting on various characters including newlines.

# You could potentially add logic here to pre-process text based on HTML structure
# if using hwp5html, or analyze PDF layout for more semantic splits.
# For this step, we'll use RecursiveCharacterTextSplitter with more aggressive
# splitting characters to try and capture semantic breaks.

# Initialize a text splitter with additional separators that might indicate semantic breaks
# The order of separators matters: try splitting on larger semantic units first.
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # Adjust chunk size as needed
    chunk_overlap=100, # Adjust overlap as needed
    separators=["\n\n", "\n", " ", ""] # Try splitting on paragraphs, then lines, then spaces
)

# Split the processed documents into chunks
# Note: If using hwp5html, the page_content will be HTML, and this splitter
# might not optimally handle HTML tags as semantic separators.
# A dedicated HTML splitter or pre-processing might be needed for better results with HTML.
semantic_chunked_documents = text_splitter.split_documents(processed_documents)

print(f"Original documents: {len(processed_documents)}")
print(f"Semantic chunked documents: {len(semantic_chunked_documents)}")

# Display first few semantic chunked documents
if semantic_chunked_documents:
    print("\nFirst 3 semantic chunked documents example:")
    for i in range(min(3, len(semantic_chunked_documents))):
        print(f"--- Semantic Chunk {i+1} ---")
        print(f"Content snippet: {semantic_chunked_documents[i].page_content[:500]}...")
        print(f"Metadata: {semantic_chunked_documents[i].metadata}")
# Out:
# Original documents: 301
# Semantic chunked documents: 407
#
# First 3 semantic chunked documents example:
# --- Semantic Chunk 1 ---
# Content snippet: 2024. 10. 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 사업예산 : 130,000,000원 범위 내 (VAT 포함) 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결) 학사제도 제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화 산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원 교수자학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현 학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립 트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# --- Semantic Chunk 2 ---
# Content snippet: 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 학사 정보시스템 고도화 기 구축된 학사운영시스템 에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 정보기술 활용 전략 향후 우리대학 학사정보시스템의 환경 변화에 대비하여 상용 DBMS(Oracle, MS SQL Server)를 적용할 수 있도록 구현하여야 함 데이터의 정합성과 무결성 확보를 위한 데이터베이스 재설계 및 통합 구축 최신 IT기술을 활용하여 사용성과 편의성, 생산성을 극대화 유지보수의 용이성 및 기술적 안정성이 높은 개발환경 제공 향후 변화하는 발주기관의 특성을 고려하여 능동적이고 효율적인 시스템으로 구성하여야 한다. 시스템은 향후 확장성을 충분히 고려하여 설계적용되어야 한다. 안정적, 효율적...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# --- Semantic Chunk 3 ---
# Content snippet: 경우에는 그 사유 및 대안을 제시하여야 한다. Reporting 전용 툴을 사용하여 출력물을 설계하되, 기능면에서 제한사항이 있으면 이에 대한 사유를 명시하고 대안을 제시하여야 한다. 통계보고서의 정형화 및 대학 전체가 공통된 내용의 업무지표 사용과 조회자료의 편리한 Export 지원(Excel 등)이 되어야 한다. 구성원별(교수/직원/조교 등), 소속부서와 업무분장에 따라 체계적인 계정 및 권한을 관리할 수 있도록 구축되어야 한다. 데이터 품질관리 전담자를 두어야 하며, 업무처리절차 개선 방안과 구현 방안 제시하여야 한다. 입찰방식 1) 사업자 선정 방식 기본방침 - 최저입찰제에서 오는 사업 시행의 부실수행을 방지하기 위해 공개경쟁에 의한 우수 기술보유 사업자를 종합평가점수 순위에 따라 선정 후, 우선협상에 의해 최종사업 자를 선정한다. 국가를 당사자로 하는 계약에 관한 법률시행령 제43조 협상에 의한 계약체결 기준을 적용 입찰방법 : 협상에 의한 계약 - 계약체결에 필요한 세부적...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}

# %%
# Re-run Embedding Generation and Vector DB (FAISS) Creation
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None


if OPENAI_API_KEY and semantic_chunked_documents:
    embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key=OPENAI_API_KEY)
    vectorstore = FAISS.from_documents(semantic_chunked_documents, embeddings)

    print("FAISS vector store created with embeddings from semantic chunks.")
    print(f"Number of documents in vector store: {vectorstore.index.ntotal}")

else:
    print("Skipping vector store creation due to missing API key or no semantic chunks.")
    vectorstore = None
# Out:
# FAISS vector store created with embeddings from semantic chunks.
# Number of documents in vector store: 407

# %%
# Re-run Advanced Retrieval (using Langchain)
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import DocumentCompressorPipeline
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_transformers import EmbeddingsRedundantFilter
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers import MultiQueryRetriever
from langchain.prompts import PromptTemplate
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None

if OPENAI_API_KEY and vectorstore:
    llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY, temperature=0.3, max_tokens=1500, top_p=0.8)

    template = """다음 문서를 사용하여 질문에 답하세요.
    답변은 가능한 한 정확하고 간결하게 작성하세요.
    제공된 문서에 없는 내용은 언급하지 마세요.
    문서:
    {context}

    질문: {question}

    답변:"""
    QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

    base_retriever = vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={"k": 10, "fetch_k": 20}
    )

    multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever=base_retriever,
        llm=llm
    )

    final_retriever = multiquery_retriever

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=final_retriever,
        return_source_documents=True,
        chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
    )

    print("Advanced RetrievalQA chain created with Multi-Query, MMR, and refined generation parameters/prompt.")

else:
    print("Skipping Advanced RAG chain creation due to missing API key, vector store, or no semantic chunks.")
    qa_chain = None
# Out:
# Advanced RetrievalQA chain created with Multi-Query, MMR, and refined generation parameters/prompt.

# %%
import time

def time_rag_query(qa_chain, query):
    """
    Times the execution of a RAG query.

    Args:
        qa_chain: The RAG chain object.
        query (str): The query string.

    Returns:
        tuple: A tuple containing the response dictionary and the execution time in seconds.
    """
    start_time = time.time()
    response = qa_chain.invoke({"query": query})
    end_time = time.time()
    execution_time = end_time - start_time
    return response, execution_time

# %%
# Re-run Example Query 1
if qa_chain and processed_documents:
    hwp1_doc = next((doc for doc in processed_documents if '한영대학' in doc.metadata.get('파일명', '')), None)
    if hwp1_doc:
        query = "한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 한영대학 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?
#
# Generated Response:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 다음과 같습니다:
#
# 1. **교육 환경의 급격한 변화 대응**: 학령인구 감소, 코로나19 팬데믹으로 인한 교육환경 변화, 인공지능 활용 등으로 대학은 급격한 사회 및 기술 변화에 직면하고 있음.
#
# 2. **분산된 시스템 및 데이터의 통합**: 정보화 요구사항이 증가하나, 노후화된 학사 시스템으로 인해 업무마다 분산된 정보화 추진이 필요함.
#
# 3. **데이터 기반 대학경영 지원 개선**: 분절된 정보 시스템 간 정보 연계 미흡 및 정보화 표준 부재로 인해 경영현황 파악 및 의사결정에 한계가 발생하고 있음.
#
# 4. **사용자 정보서비스 접근성 개선**: 교내 구성원의 정보 탐색 지원을 위한 포털 서비스가 제공되고 있으나, 정보 접근성 및 유용성 개선 요구가 큼.
#
# 5. **대학 경쟁력 강화 및 전략 목표 달성 지원**: 노후화된 시스템의 차세대 구축을 통해 정보 서비스 품질을 강화하고 대학 교육 시스템의 경쟁력을 확보하고자 함.
#
# Query Time: 8.48 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 2024. 10. 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 사업예산 : 130,000,000원 범위 내 (VAT 포함) 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결) 학사제도 제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# . 서약자 : 대표 (인) 한영대학교 총장 귀하 [서식 제9호] [서식 제10호] 정보 비공개동의서 본인은 귀 한영대학교의 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화 참가와 관련하여 취득한 각종 정보에 대하여 제3자에게 일체 누설하지 않겠으며 귀 한영대학교가 정한 보안사항을 철저히 준수할 것을 동의합니다. 2024. . . 상 호(법인명): 주 소 : 대 표 자 : (인) 사업자등록번호 : 한영대학교 총장 귀하 [서식 제11호] [서식 제12호] 봉투규격과 상관없이 밀봉 후 작성, 날인하는 방법 참조하세요. 가격...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT [ 서식 5 ] 주요사업 실적 사 업 명 사 업 기 간 계 약 금 액 발 주 처 비 고 X 연도순으로 기재하다 제안과제와 유사하거나 동일한 업무영역이나 사업형태에 관한 것만 기재한다: 단 현재수행중인 사업은 비고란에 현재수행중임올 명시한다: X 하도급은 발주처가 승인한 경우에 한하여 작성하다 비고란에 원도급회사틀 기재한다: X 공동도급계약일 경우어는 계약금액관에 제안사의 지분만을 기재한다: X 실적올 확인할 수 R는 실적증명서 계약서 이행실적확인서(한국소프트웨어산업협회 발행) 등의...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 아: 첫봇 현 첫봇 고도화 필요 0 1차 첫봇 사업흘 통해 도출권 사용자 요구 반영 필요 교원 직원 세중캠퍼스 학생까지 대상올 확대한 첫봇 시스템 구축 필요 교수 사용자의 교육 연구 관련 다양한 문의에 대한 응답 규정과 연계하여 사용자의 문의 내용에 대한 응답 및 근거가 되는 관련 규정 자료 문서 등올 같이 제공할 수 윗도록 구축 0 1차 첫봇 사업 범위 (상세 내용은 사업 착수 후 공유) 첫보시스템 구축(질의응답 GPT 기반 햇봇 구현) 질의응답 기반 켓복 오른 GPT기반 규정학...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024 7. 01 KOREA UICKSI 고려대학교 KOREA UNIVERSITY X 본 자료는 제안내용의 설명올 위한 배포자로로, 이외 목적으로 무단부제 , 전달 및 사용하는 행위틀 금함...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 구축 개발 수주가 단일건으로 1억원 이상 실적이 있는 업체 Windows Server, MS-SQL기반 ASP.NET 개발환경에 구축 실적이 있는 업체 .NET기반의 Windows Server의 Application 생성 및 표준화된 표준프레임워크을보유하고 있는 업체(타대학교에 적용 및 검증된 프레임워크 활용) 공동수급(공동이행방식) 및 하도급은 불가함의 규정에 의한 경쟁 입찰 참가 자격을 갖춘 과업 수행 가능자 3) 입찰 계약조건 계약의 체결 및 이행에 관하여는 협상에 의한 계약체결 기준 제14조의 규정에 의하여 서면 통보한 협상...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 강구 사업수행자는 다음과 같은 사항울 유지관리 활동에 포함하여 지원 공급한 제품(HW S/W 등)과 개발한 S/W 등의 전 시스템 공급된 상용 제품에 대한 기능 패치 장애발생에 대한 처리(Trouble Shooting) 기타 시스템의 정상운영올 위한 기술지원 등 하자보수계획서 산출정보 요구사항 분류 프로적트지원 요구사항 요구사항 번호 PSR-002 요구사항 명칭 교육 및 기술지원 정의 사용자 교육 및 기술지원 교육 및 기술지원 사업자는 사업 착수부터 완료까지 시스템 개발 및 운영에...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 입학정보 신상정보 학적변동 내역 수강내역 성적내역 장학내역 등록내역 다전공 이수내역 교직 이수내역 졸업진단 내역 자격증 상벌사항 학생자치기구(동아리) 활동 내역 교환교류 프로그램 참여 내역 경력/학력내역 등 학생 전체 정보는 포털올 통해 학생 본인은 모두 조회할 수 있으며 본부부서(학사팀 교무학사팀 대학원행정팀) 학사담당(대학행정실 학과, 특수 전문 대학원행정실 등) 교원은 각 업무에 필요한 정보름 조회 사진올 등록하고 변경 이력올 관리할 수 있도록 기능 구현 계좌(은행 예금주 계...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 NOREA LHIVER5ITY 사업 개요 1. 사업개요 가 사업명: 고려대학교 차세대 포털학사 정보시스템 구축 사업 나: 사업기간: 계약일로부터 24개월 이내 다: 무상유지보수기간 사업종료일로부터 12개월 라: 사업예산 : 71,270,000,000원 (VAT 포함 3년 분할 지급) 2024학년도 약 309 지급 2025학년도 약 40% 지급 2026학년도 약 309 지급 마: 입찰 및 계약 방법: 제한 경쟁 입찰(현상에 의한 계약) 바 본 사업은 3개년에 결친 다년 사업으로 사업 수행에 따른 대가도 3개년에...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 트랙운영 학사정보시스템 고도화 사업에 한정하여 적용 제안사는 한영대학교의 트랙운영 학사정보시스템을 충분히 이해하고, 제안요청 사항을 기본적으로 반영하여 과업내용을 포함하여야 함 제안사는 본 제안요청서에 언급하지 않았으나, 본 과업수행 향상에 도움이 되는 사항이 있을 경우 이를 추가로 제시할 수 있음 과업수행 중 환경변화로 인하여 설계변경 되거나, 기타 예기치 않은 여건의 변화로 과업 대상 업무에 대한 일부의 변경 및 추가요구사항이 발생될 경우에는 발주처와 제안사가 상호 협의하여 변경하여야 함 계약 후 1주일 이내에 계약서, 제안요청...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 목 차 I . 사업개요 1. 사업 개요 2. 사업 배경 3 사업 범위 4. 기대효과 5 끄. 현황 및 문제점 1. 일반 현황 2. 정보화 현황 3. 문제점 및 개선방향 8 15 교. 사업 추진방안 1. 추진 목표 2. 추진 일정 3. 추진 체계 33 33 35 36 IV. 제안요청 내용 1. 제안요청 개요 2. 상세 요구사항 38 38 43 V . 제안 일반 사항 1. 사업관리 사항 2. 입찰 참가 신청 방법 3 사업자 선정 방법 4. 제안 설명회 5. 제안 평가 방식 230 23...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 강의시간표 성적조회 수강소감등록 그 외 학사행정시스템 기능 중 학교가 정하는 사항 서비스 제공 대상은 학교와 현의하여 최종 결정함 일반행정시스템 연계 서비스 제공 방식 현 포털 시스템의 인사 급여 등 행정 모물은 일반행정시스템과 비즈니스 로직올 공유하므로 비즈니스 로직올 재사용하는 방안을 제시 및 적용하여야 함 산출정보 프로그램 목록 프로그램명세서 화면정의서 사용자매뉴얼 등 요구사항 분류 기능 요구사항 요구사항 번호 SFR-포털-008 요구사항 명칭 다국어 서비스 정의 다국어 서비...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 설명 내용 기 구축된 첫봇의 고도화 첫봇 서버 이중화 사용자 대상올 교원 직원까지 확대한 첫봇 서비스 구축 기 구축권 첫봇의 사용자 피드백(불만/개선 의견 등)올 반영하여 구축 GPT틀 적용한 생성형 응답 첫봇 기능 고도화 부서별 자주하는 질의응답 리스트트 수합하여 전체 반영 차세대 시스템 구축으로 인한 연계기능의 경로 변경사항 데이터변경사항, API변경사항 검색엔진 변경사항 등 반영 영문 첫봇 고도화 구축 시기별 자주하는 질문정보 제공 산출정보 프로그램 목록 프로그램명세서 화면정...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 각 대학원별로 최종 등록생에 대하여 학번부여 후 학적으로 이관 처리하는 기능 X 학부도 신규 시스템에 동일한 기능 제공 산출정보 프로그램 목록 프로그램명세서 화면정의서 사용자매뉴얼 등 -161-...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 설명 이숙가 되는 업무의 재설계 및 정보화 방안 제시(BPR) 업무 프로세스 재설계 대상 업무는 ISP에서 학사행정 전반에 걸처 도출된 업무 프로세스 재설계 대상올 기준으로 하려 주요 대상 업무는 아래와 같음 각 학과 졸업기준 요건과 정보화 정도 분석 및 차세대 정보화 개선 방안 대학원별 입시-학적생성 시점에 따른 대학원생 정보시스템 사용 이수 점검 및 개선 방안 도출 (대학원 입시-학적 전반 프로세스 점검]재설계) 장학금 관리 체계 및 장학 추천 /신청-선발 /통계 전반의 정보화...

# %%
# Re-run Example Query 2
if qa_chain and processed_documents:
    hwp2_doc = next((doc for doc in processed_documents if '한국연구재단' in doc.metadata.get('파일명', '')), None)
    if hwp2_doc:
        query = "한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 한국연구재단 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 무엇인가요?
#
# Generated Response:
# 한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 UICC 시스템 기능개선을 통해 이용 편의성을 개선하고, UICC 시스템 운영 지원을 통해 안정적으로 실태조사를 추진하는 것입니다.
#
# Query Time: 3.69 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 2024. 10. 1. 사업명: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선 2. 추진배경 및 필요성 한국연구재단법 제5조, 산업교육진흥 및 산학연협력촉진에 관한 법률 제39조의2 및 제43조에 따라 실시하는 대학 산학협력활동 실태조사를 안정적으로 운영 필요 항목 지침 변경사항 등 변화에 신속하고 정확하게 대응하며, 기능개선에 대한 사용자 요구를 반영하여 사용자 편의성 강화 필요 UICC의 효율적인 관리와 운영을 위한 지원 체계 및 각종 기관 요구사항에 대응 필요 3. 주관기관 : 한국연구재단 4. 사업기간 및 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 1 서식 15 ] 참여인력 현항표 분야별 소속기관 성명 직급 근무경력 소속 최종학교 참여울(%) 담당업무 사업책임자 부문 부문 부문 부문 부문 부문 부문 부문 부문 부문 X 사업책임자(Project Manager)는 반드시 투입울 10096(전담) 가능자로 인선하여 기재 X 각 부문별 소계 및 전체 합계흘 기술 - 268-...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 NOREA LHIVER5ITY 2. 정보화 현황 가 주요 정보시스템 현황 및 사업 대상(흉페이지 제외) 서비스 구분 정보시스템 개발프로그램 대상 운영부서 학사정보시스템(AMS) PowerBuilder 정보개발팀 수강신청시스템 모바일수강신청업 학부모 성적조회, 금학기 공시 성적조회 Java Servlets JSP Ajax 정보개발팀 Java Servlets JSP Ajax 정보개발팀 합격자 발표 Java Servlets JSP Ajax 정보개발팀 학적시스템(구) 학사팀 교육정보흉페이지 CMS 학사팀 입학전형기획...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 정의 통합l스트 진행 및 결과분석 통합터스트 수행 통합 테스트 시나리오에 따라 단위 테스트가 완료된 프로그램들올 대상으로 최소 3회 이상 통합테스트트 실시하고 다음 사항올 검증하여야 함 기능 성능 등의 요구사항 및 설계사양 충족여부 기능의 정상적 수행여부 등 기능수행 후의 결과가 사전에 예측권 결과와 일치 시스템의 접근권한 및 업무 권한에 대한 적절성 대내시스템 간 영역 간 연계 및 이틀 포함하는 업무흐름 대외기관 연계 및 이틀 포함하는 업무 흐름 결함올 파악하고 원인올 추적하여 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 전자서명 주요 기능 위원회회의록 교무처장단회의록 등 주요 회의체 회의록에 대한 전자서명(날인)관리 기능 구현 학사 포털 등 사업대상에서 전자서명이 필요한 업무름 식별하여 적용 서명예시: 지도교수 주임교수 학과장 학장 서명 등 업무예시: 학위청구 논문심사신청 등 현재 전산화b 양식에서 전자서명 필요양식 식별 미전산화된 양식에서 전자서명 필요양식 식별 후 구현 전자결재 연동 주요 기능 계약서 서명본 등올 점부하여 전자결재 기안 후 결재 완료 시 전자계약 프로세스틀 진행하도록 연계 그 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 NOREA LHIVER5ITY 비전 창의적 미래 인재틀 양성하고 인류에 공현하는 대학 발전목표 GLOBAL Top 30 by 2030 대학학신 전락 KU 학신플렉품 구축 영역별 확신전락 창의움합형 혼렌즈 훨신 참여소통형 네트위크 훨신 미래선도형 인프라 훨신 7대 영역 교육 연구 산학협력 글로벌 사회공헌 행 . 재정 영역별 목표 미래선도형 움복합 창의 인재 양성울 위한 교육 패러다임 역신 지속가능한 미래가치 창출올 위한 연구 생태계 구축 국내 최초 산학협력에서 글로벌 최고 산학움합으로 대학 경쟁력 강화글 위한 국...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 KOREA UHIVERsITT 평가목적 평가대상 범위 평가주체 (평가팀) 평가기간 평가절차(방법) 주요 평가사항 평가기준 및 항목 자료수집 및 분석계획 등 포함 평가자료의 수집 및 분석 개인정보보호 관련 기관 내외부정책 환경 분석의 적절성올 확보하여야 함 개인정보 영향평가름 위한 내외부 정책 자료지 수집 및 분석하여야 함 (조직 체계 자료) 기관 내 개인정보보호방침, 개인정보 관리계획, 직제표 개인정보 보호 규정 정보보안 규정 등 분석 (인적 통제 교육 자료) 개인정보 관련 조직 내 업무 분장표 및 직급별 업...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 설명 이숙가 되는 업무의 재설계 및 정보화 방안 제시(BPR) 업무 프로세스 재설계 대상 업무는 ISP에서 학사행정 전반에 걸처 도출된 업무 프로세스 재설계 대상올 기준으로 하려 주요 대상 업무는 아래와 같음 각 학과 졸업기준 요건과 정보화 정도 분석 및 차세대 정보화 개선 방안 대학원별 입시-학적생성 시점에 따른 대학원생 정보시스템 사용 이수 점검 및 개선 방안 도출 (대학원 입시-학적 전반 프로세스 점검]재설계) 장학금 관리 체계 및 장학 추천 /신청-선발 /통계 전반의 정보화...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 해외 학생이 참여하는 프로그램의 신청-접수 수작업/ 시스템 연계 개선 해외 대학 정보 관리 / 해외 대학과의 협약 정보 관리 학내 시스템 간 정보 연계 미혼 개별 부서 도입 시스템 구축 환경 차이 연계 표준 미적용 등으로 학사행정시스템과 관련 시스템 간 데이터 연계 미혼 업무 비효율 발생 U이터 미언계 세중캠퍼스 단독 사용시스템 스o Ui Ls 제규정 정책 등으로 시스템 미연계로 수작업 맛 인해 교내 아사정보 이중관리 이; 만생 8ss E0' 구리리 공유가 제대로 되지 HUB '심...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 릿수름 증가시키논 등 조직코드트 지속적으로 사용할 수 짓는 방안을 제시 및 적용하여야 함 기업/기관관리 학내 기관과 교류하는 외부의 기업 또는 기관 정보름 등록/삭제 변경 관리할 수 있어야 함 교육 관련 교류 기업/기관 정보 관리(계약학과 기업 등 포함) 구매/용역 등 일반행정 업무 관련 교류 기업/기관 정보 관리 산학협력 교류 기업/기관 정보 관리 중복 등록된 기관데이터지 효과적으로 정리할 수 있는 방안을 제시하여야 함 학사력 및 대표학사일정 관리 현재 학사력관리 및 학사일정관리...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 높은 업체를 우선협상대상자로 함 우선협상대상자와 협상이 이루어지면 차 순위와의 협상은 진행하지 않음 협상대상자와 협상이 모두 결렬되면 재공고하여 재입찰 추진함 선정된 계약상대자는 사업추진, 품질보증 등 전체적인 사업 관리에 책임을 짐 선정된 계약상대자는 사업의 성공적 수행, 사업 진행 및 기술지원에 대한 책임 상기에 표시되지 않은 절차는 국가를 당사자로 하는 계약에 관한 법률, 동법 시행령, 동법 시행규칙 및 조달청 기준에 준함 5) 평가 및 협상결과의 공개 제안서 평가결과에 대하여 제안업체는 어떠한 이의도 제기할 수 없다. 제안서...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 요구사항 분류 기능 요구사항 요구사항 번호 SFR-입시-002 요구사항 명칭 대학원 지원자관리 정의 대학원 입시 지원자관리 기능 정의 접수대행자료이관 원서접수 대행업제로부터 지원자의 데이터지 입시시스템에 일굴 업로드하는 기능 각 대학원별 입시 담당자가 업로드 할 수 있도록 기능을 제공함 지원자현항관리 수험번호별 지원자의 지원정보 학력 경력 자격증 등 지원자의 정보름 개별 관리하는 기능 각 대학원별로 지원자 현황울 확인할 수 있도록 하고 전체 대학원 정보틀 총관하여 관리할 수 있도록...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 모든 관련 프로그램이 사용자 환경에 따라 설치되도록 구축하여야 하며, 설치 교육용 CD-ROM을 주관기관과 협의한 부수만큼 제작 공급하고, 제안사 부담으로 사용자 시스템에 설치 지원해야 함 계약목적물의 지식재산권은 재단 과 사업자가 공동으로 소유함을 원칙으로 하되 세부사항은 협의하여 결정함 사업자는 지식재산권의 활용을 위하여 SW산출물의 반출을 요청할 수 있으며, 재단 에서는 보안업무규정(대통령령) 제4조 및 제안요청서에 명시된 누출금지정보에 해당하지 않을 경우 SW산출물을 제공함.(단 사업자는 아래 내용을 준수하여야 함) - 사업...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 KOREA UHIVERsITT 요구사항 분류 프로적트관리 요구사항 요구사항 번호 PMR-0O9 요구사항 명칭 안정화 활동 수행 정의 안정화 기간 중 안정화 활동 수행올 정의 시스템 안정화 활동 수행 안정화 기간 중 발생하는 기능 변경 요구사항에 대해 영향도 분석 및 반영 가능여부름 검토하고 반영여부름 발주기관과 협의하여 가능한 기능 개선 수행 법 제도 변경 및 시행시책 등 업무환경 변화에 따른 기능변경 사용자 및 운영자의 요청에 따른 정보시스템 기능개선 정보시스템의 사용 편의성올 높이기 위한 지속적인 개선 활...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 문제점과 대안방안 등에 대하여 주 원간 진행보고서 제출 추진계획 대비 실적 주요추진내용 및 단계별 산출물 계획사항 및 계획변경사항 주요 의사결정 및 현조사항 수시보고서 우리대학은 원활한 과업 추진올 위해 필요시 비정기적인 보고 요청 가능 중간 및 완로보고서 문서제본 10부 및 USB 등 파일 제출 사업종료일 14일 이전에 보고서 초안을 우리대학과 현의한 후에 보완사항울 반영하여 사업완로시 제출 완료보고회논 우리대학과 현의하여 개최하다 보고회에서 논의원 내용올 최종산출물에 반영함 최...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ;녀 태L시 고려대학교 NOREA LHIVER5ITY 사: 경영통계시스템 데이터 취합 /분석 전반의 수작업 개선 필요 기촌 경영통계시스템의 데이터 수집 저장 및 분석관리체계 미비로 시스템 활용도 저하 각종 통계자료의 공문처리틀 통한 수기 요청 취합으로 업무 비효율 발생 수작업 기반의 동계 급시데이터 0 2 밭전거히 부서KPI 응 이형점검 및 취e/ 보고 성과환류 수작업에 의한 한계 존재 테이터 2 사업성과 및 사업예산 짐행 품질관리 수기관리어 의한 업구 비i움 미급으로 경영공거시스템 I9D 정보장 시용리) 장계시스템 시스템 합용 미...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 KOREA UHIVERsITT 평가 부문 평가항목 평가기준 배점 구현하고자 하는 기능에 요구 성능이 충족되도록 방법론 및 분석 도구 틀 통하여 내용올 구체적으로 분석하엿는지 구현 및 테스트 방안을 구 체적으로 기술하엿는지 평가 제안한 방안 및 기술을 통해 요구 성능올 충족시길 수 있논지 평가 분석 도구 및 구현 방안 테스트 방안을 구체적으로 기술하엿는지 분석 설계 등 각 단계별 품질 요구사항의 점검 및 검토 방안을 구체적으로 계획하엿는지 평가 각 단계마다 품질 요구사항올 점검하는 별도의 전문 인력이 투입되논지...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 기능 구현 포기사유 관리 승인되면 학생에게 알림 처리 학석사연계과정 신청 포기가 최종 승인되어 확정 시 학적에 반영하고 변경 이력올 관리함 석박사통합과정관리 대학원 학적 업무담당자가 학생이 신청한 석박사통합과정신청에 대한 승인올 관리하는 석박사통합과정 신청/ 승인 관리 기능 구현 성적정보 논문정보 지도교수 추천서 등 정보름 관리하고 제출서류틀 점부하여 관리할 수 있도록 함 승인되면 학생에게 알림 처리함 석박사통합과정 진행 중인 학생이 석박사통합과정 중도포기틀 신청하고 업무 담당자가...

# %%
# Re-run Example Query 3
if qa_chain and processed_documents:
    hwp3_doc = next((doc for doc in processed_documents if '한국생산기술연구원' in doc.metadata.get('파일명', '')), None)
    if hwp3_doc:
        query = "한국생산기술연구원의 EIP3.0 고압가스 안전관리 시스템 구축 용역의 사업 개요를 설명해 주세요."
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 한국생산기술연구원 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한국생산기술연구원의 EIP3.0 고압가스 안전관리 시스템 구축 용역의 사업 개요를 설명해 주세요.
#
# Generated Response:
# EIP3.0 고압가스 안전관리 시스템 구축 용역의 사업 개요는 다음과 같습니다:
#
# 1. **사업명**: EIP3.0 고압가스 안전관리 시스템 구축 용역
# 2. **사업기간**: 계약체결일 ~ 2024.12.27.
# 3. **사업금액**: 40,000천원(부가세 포함)
# 4. **계약방법**: 제한경쟁입찰 / 협상에 의한 계약
# 5. **사업범위**:
#    - 원내에서 관리하는 화학물질 운영현황의 정보를 제공하는 시스템 구축
#    - 고압가스 화학물질의 정보와 판매허가 업체를 관리하기 위한 시스템 구축
#    - 고압가스 화학물질의 구매부터 안전성 검토 과정을 진행하기 위한 시스템 고도화
#    - 연구실과 법적 준수 사항을 관리하기 위한 시스템 고도화
#    - 화학제품 폐기회수를 관리하기 위한 시스템 고도화
#
# 이 사업은 고압가스의 안전한 관리를 통해 연구원들의 생명과 신체를 보호하고, 법적 준수를 통해 안전 관리 수준을 법적 기준 이상으로 유지하는 것을 목표로 하고 있습니다.
#
# Query Time: 11.83 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 연구관리, 기업지원, 재무, 인사, 급여, 구매조달, 지재권 등 19개 업무시스템 운영 연계시스템 (2023.12.31. 기준) 장비 현황 - 운용 중인 전산장비는 총 1,205종이며, 840종을 서비스수준협약(SLA)을 통하여 안정적인 서비스와 신속한 장애 복구 체계 구축 3. 사업 추진방안 가. 추진목표 원내에서 관리하는 화학물질 운영현황의 통계 정보 공유 고압가스 화학물질의 정보와 판매허가 업체를 관리 고압가스 화학물질의 구매부터 안전성 검토 과정을 제공 연구실과 법적 준수 사항을 관리 나. 추진방안 - EIP3.0 업무포털 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 KOREA UHIVERsITT 적용계획/ 결과 부분적용 /미적 미 '해당없 용시 사유 및 적용 음 대체기술 구 분 항 목 부분 적용 적용 하드웨어 보안 토론 DB 암호화 제품 상기 제품(9종)이외 중요정보 보호지 위 해 암호기능이 내장문 제품 암호 모둘 검증서에 명시원 제품과 동 일 제품 여부 CC인종 필수제품 유형군(국제 CC인 경 우 보안 적합성 검종 필요) (네트위크)침입차단 (네트위크)침입방지(침입담지 포함) 통합보안관리 웬 응용프로그램 침입 차단 DDos 대응 인터넷 전화 보안 무선침입방지 무선랜 인...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# egovframe포털(www.egovframe.go.kr) 참조 3) 정보시스템 구축 기술 요건 서비스 접근 및 전달 분야 - 정보시스템은 사용자가 다양한 브라우저 환경에서 서비스를 이용할 수 있도록 표준기술을 준수하여야 하고, 장애인저사양 컴퓨터 사용자 등 소외계층을 고려한 설계구현을 검토하여야 한다. 인터페이스 및 통합 분야 - 정보시스템 간 서비스의 연계 및 통합에는 웹서비스 적용을 검토하고, 개발된 웹서비스 중 타 기관과 공유가 가능한 웹서비스는 범정부 차원의공유활용이 가능하도록 지원하여야 한다. 플랫폼 및 기반구조 분야 -...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 시스템올 개발 연동하여 지원할 수 있어야 함 프로적트의 공통모둘과 형상관리 슬루선이 효율적으로 연동되어 배포작업시 속도에 문제가 없어야 함 신규 형상관리 시스템 도입 시 기존 슬루선의 데이터 마이그레이선 작업이 포함되어야 함 기존 시스템의 소스 변경내역 및 PMS 하스토리틀 신규 시스템에서 확인할 있어야 함 배포 시 WAS의 재기동 명령어가 없올 경우 자동배프트 위해 재기동 스크립트 개발 지속적 통합 / 배포(CVCD) 기능울 포함하여 개발자 개발서버 환경 테스트 서버환경 운영서버...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 KOREA UHIVERsITT 요구사항 분류 품질 요구사항 요구사항 번호 QUR-0O2 요구사항 명칭 프로직트 품질관리 정의 프로적트 품질관리 계획 요구 사항 상세 설명 품질관리 방안 제시 및 적용 품질보증의 범위 품질보증올 위한 조직 절차 점검방법 등올 제시하여야 함 산출물의 신 도 및 전문성 품질제고름 위한 품질관리 활동 수행 방안 본 사업 추진 시 예상되는 위험요소 도출 및 관리방법 의사소통 방법 세부 업무수행에 대한 제반 품질보증방안 세부 내용 산출정보 프로적트 품질관리 계획서 요구사항 분류 품질 요구...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 3. 시스템 운용환경 구축비 구 분 산출내역 시스템 운용환경 설계비 시스템 운용환경 조성비 소 계 (단위 원) 금 액 비고 부가가치세 합 계 4. 데이터베이스 구축비 구 분 산출내역 (단위 원) 비고 금 액 인건비 상세내역은 따로 작성 제출 제경비 인건비 X ( ) % 직접경비 이 운 개발원가 X ( ) % 소 계 부가가치세 합 계 5. 소프트웨어 구매 구분 (단위 : 원) 수량 비고 품명 규격 -258-...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 공간관리시스템(아키버스) nodejs; Thingworx 건축팀 정보공시통합비교시스템 평가팀 경영통계시스템 정보개발팀 고려대 채용시스템 정보개발팀 고려대 강사임용지원시스템 정보개발팀 고려대 교원소봉지원시스템 정보개발팀 수집기록관리시스템 박물관 대량메 일발송시스템(EMS) 정보인프라팀 스크램마스터 커유니베이선팀 Javascript nodejs expressJs flutter vuejs 연구실안전관리시스템 안전관리팀 연구포털 (RMS) Java Spring 산학경영팀 연구자네트워크(K...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 산출정보 요구사항 분류 프로적트관리 요구사항 요구사항 번호 PMR-0O8 요구사항 명칭 시스템 안정화 체계 구축 정의 구축권 시스템의 안정화 체계 관리사항 정의 구축 시스템 인수인계 작업 수행 안정된 인수인계름 위해 시스템 테스트 단계부터 인계자와 인수자가 확정되어야 함 인계자는 업무별 상세 인수인계계획서클 작성하여 인수자와 함께 검토하여야 함 인수인계 산출물에는 인계 대상 프로그램 목록 소스 등 유지보수에 필요한 정보가 포함되어야 함 인계 대상 소스는 형상관리시스템에 등록하고 배...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 사업수행 참여자의 비인가 휴대용 저장장U(USB CDIDVD 태불핏 등)논 사업 수행 장소 정보시스템에 연결되어 사용 불가 산출정보 보안관리 계획서 보안서약서 요구사항 분류 보안 요구사항 요구사항 번호 SER-OO2 요구사항 명칭 프로적트 산출물 보안관리 정의 프로적트 작업수행 및 산출물 보안관리 사업수행올 위해 제공된 우리대학 자료의 복사 및 외부반출 금지 제공된 내부자료는 매일 퇴근시 반남 요망 다만 비밀문서름 제외한 일반문서는 잠금장치가 된 서류함에 보관가능 사업 수행 자료외...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 작 성 항 목 작 성 방 법 업무개발에 적용할 방법론 절차 및 기법의 활용방안올 제시하 여야 하여 적용방법론의 경험올 기술하다. 개발방법론에 따른 제출할 산출물의 종류 및 내역 제출시기름 기술하다: 5. 개발방법론 교 기술 및 기능 시스템올 하드웨어부문 소프트웨어 부문 기타부문 등으로 구분 하여 각 구분별 구성장치의 사양 기능 인증내역 등올 제시하고 1. 시스템장비 요구사항 도입장비의 설치 및 공급계획 도입 장비의 하자보수 방안을 기 술하여야 한다: 방법론 및 분석 도구릎 통하여 ...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 2024. 08. 목 차 1. 사업 개요 가. 추진배경 및 필요성 안전사고 증가 - 고압가스 취급 부주의로 인한 연구실 사고가 빈번하게 발생하고 있으며, 이는 인명 피해와 연구 기기 손상을 초래함 법적 요구사항 - 안전 관리에 대한 법적 요구사항과 규제가 강화되고 있으며, 이를 준수하지 않을 경우 법적 책임과 벌금이 부과 연구 환경 보호 - 연구원들의 건강과 안전을 보호하고, 안전한 연구 환경을 제공하기 위해 체계적인 관리 시스템 구축 필요 나. 사업 범위 원내에서 관리하는 화학물질 운영현황의 통계 정보를 제공하는 시스템 구축 고압...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 문제점과 대안방안 등에 대하여 주 원간 진행보고서 제출 추진계획 대비 실적 주요추진내용 및 단계별 산출물 계획사항 및 계획변경사항 주요 의사결정 및 현조사항 수시보고서 우리대학은 원활한 과업 추진올 위해 필요시 비정기적인 보고 요청 가능 중간 및 완로보고서 문서제본 10부 및 USB 등 파일 제출 사업종료일 14일 이전에 보고서 초안을 우리대학과 현의한 후에 보완사항울 반영하여 사업완로시 제출 완료보고회논 우리대학과 현의하여 개최하다 보고회에서 논의원 내용올 최종산출물에 반영함 최...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 보안 분야 적용계획 / 결과 부분적용 /미적 부분 미 '해당없 용시 사유 및 적용 적용 적용 음 대체기술 구 분 항 목 기본 지침 정보시스템의 보안올 위하여 위험분석올 통한 보안 계획올 수립하고 이틀 적용하여야 한다: 이논 정 보시스템의 구축 운영과 관련된 "서비스 접근 및 전달" "플랫픔 및 기반구조" "요소기술' 및 "인터페 이스 및 통합" 분야름 모두 포함하여야 한다: 보안이 중요한 서비스 및 데이터의 접근에 관련된 사용자 인증은 공인전자서명 또는 행정전자서명올 기반으로 하여...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ;녀 태L시 고려대학교 NOREA LHIVER5ITY 그룹워어(GW) 요구사항 분류 기능 요구사항 요구사항 번호 SFR-GW-007 요구사항 명칭 전자결재 정의 전자결재 기능 정의 전자결재 공통 현재 행정시스템에서 생성하는 전체 양식의 전자결재 연동 적용 차세대 시스템에서 추가된 양식 추가 Non-ActiveXIHTML5기반 웬에디터 제공 웬한글기안기 연계 행정안전부 전자문서 규격 공공기관 유통표준 및 기록관리 표준올 준수한 시스템 구축 국가표준(KS X ISO 16175-3) 문현정보- 전자사무환경에서 기록에 대한 원 리 및 기능...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 모든 관련 프로그램이 사용자 환경에 따라 설치되도록 구축하여야 하며, 설치 교육용 CD-ROM을 주관기관과 협의한 부수만큼 제작 공급하고, 제안사 부담으로 사용자 시스템에 설치 지원해야 함 계약목적물의 지식재산권은 재단 과 사업자가 공동으로 소유함을 원칙으로 하되 세부사항은 협의하여 결정함 사업자는 지식재산권의 활용을 위하여 SW산출물의 반출을 요청할 수 있으며, 재단 에서는 보안업무규정(대통령령) 제4조 및 제안요청서에 명시된 누출금지정보에 해당하지 않을 경우 SW산출물을 제공함.(단 사업자는 아래 내용을 준수하여야 함) - 사업...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 사용자 편의성 도모 1. 추진목표 UICC 시스템 기능개선을 통해 이용 편의성 개선 UICC 시스템 운영 지원을 통해 안정적으로 실태조사 추진 2. 추진전략 능력과 경험이 풍부한 전문사업자를 주관사업자로 선정 시스템 구축에 대한 경험이 풍부하고 인력관리, 품질관리 및 유지관리 능력이 우수한 업체를 주관사업자로 선정하여 사업 진행 재단대학과의 원활한 소통을 바탕으로 효율적 협력체계 마련 정보기술 활용전략 한국연구재단에서 운영하는 기존 정보시스템과 연계 호환성 유지 한국연구재단의 보안, 네트워크 등의 기반 인프라를 최대한 활용하여 비용...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 건강검진관리 건강검진 결과틀 등록(추가)하거나 조회된 검진 결과틀 수정 및 삭제할 수 잇는 기능 조회된 건강검진결과큼 파일로 내려 받아 저장하거나 오류내억올 저장 받을 수 있는 기능 건강검진 결과 유소견자 현황울 캠퍼스별 /년도별 /학기별 조회하는 기능 산출정보 프로그램 목록 프로그램명세서 화면정의서 사용자매뉴얼 등 요구사항 분류 기능 요구사항 요구사항 번호 SFR-부속-002 요구사항 명칭 보건 공제 정의 보건 공제 의로공제관리 기능 정의 의로공제접수관리 신규 공제 내역 입력올 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ;녀 태L시 고려대학교 NOREA LHIVER5ITY 사: 경영통계시스템 데이터 취합 /분석 전반의 수작업 개선 필요 기촌 경영통계시스템의 데이터 수집 저장 및 분석관리체계 미비로 시스템 활용도 저하 각종 통계자료의 공문처리틀 통한 수기 요청 취합으로 업무 비효율 발생 수작업 기반의 동계 급시데이터 0 2 밭전거히 부서KPI 응 이형점검 및 취e/ 보고 성과환류 수작업에 의한 한계 존재 테이터 2 사업성과 및 사업예산 짐행 품질관리 수기관리어 의한 업구 비i움 미급으로 경영공거시스템 I9D 정보장 시용리) 장계시스템 시스템 합용 미...

# %%
# Re-run Example Query 4
if qa_chain and processed_documents:
    hwp4_doc = next((doc for doc in processed_documents if '인천광역시' in doc.metadata.get('파일명', '')), None)
    if hwp4_doc:
        query = "인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 인천광역시 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 무엇인가요?
#
# Generated Response:
# 인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 다음과 같습니다:
# - 용역명: 도시계획위원회 통합관리시스템 구축 용역
# - 기간: 착수일로부터 180일
# - 사업비: 금150,000,000원 (VAT 포함)
# - 계약방법: 제한경쟁입찰(협상에 의한 계약)
#
# Query Time: 5.52 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 1. 과 업 명: 도시계획위원회 통합관리시스템 구축 용역 2. 용역개요 용 역 명: 도시계획위원회 통합관리시스템 구축 용역 기 간: 착수일로부터 180일 사 업 비: 금150,000,000원 (VAT 포함) 계약방법: 제한경쟁입찰(협상에 의한 계약) 3. 과업배경 및 목적 (수작업에 의한 업무의 복잡성) 여러 단계의 위원회 운영업무를 수작업으로 처리, 업무의 복잡성 발생 심의자료 변경 시 자료의 재배포 등 업무의 중복성 발생 위원회 전 과정의 지원체계 구축 필요 (통합관리시스템 부재로 업무별 개별 처리) 사전준비 단계에서 행정절차는...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 제2전공(이중전공 움합전공 학생설계전공) 복수전공 등 다중전공별로 일정 관리 다중전공의 신청 차수 지망 차수 관리 여러 다전공 신청 가능 학업계획서 등록 다중전공 선발 기준(학기 학점 평점평균 등)올 충족하지 못할 경우 신청물가사유 안내 신청취소포기신청의 경우 취소사유 포기사유릎 관리 다중전공전형 사정요소(성적 면접 학업계획서 등)별 점수름 관리 학과(부) 대학의 합/불 판정 및 승인 결과틀 관리 최종 승인되어 다중전공 진입이 확정되면 학생에게 알림 처리 다중전공 신청 포기가 최종...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 수 증 상기 업체는 인천광역시에서 시행하는 도시계획위원회 통합관리시스템 구축 용역 입찰과 관련하여 붙임과 같이 서류를 제출하고 제안 공모에 참가할 것을 신청합니다. 2024년 월 일 인천광역시장 귀하 ------------------------------ (인) ----------------------- 절 취 선 접 수 증 도시계획위원회 통합관리시스템 구축 용역 제안 공모 접수하였음을 확인합니다. 서식 제2호 서식 제3호 사 용 인 감 계 상기인은 위 인감을 인천광역시에서 시행하는 도시계획위원회 통합관리시스템 구축 용역의 입찰 계...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 발생하는 모든 사안에 대하여는 보안을 요하며, 제안서와 관련하여 제안참가 업체는 타 업체 또는 외부기관으로의 제안요청 관련 사항 공개를 금함 본 사업 수행 중 취득한 인천광역시의 정보통신 보안사항 일체에 대하여 보안을 유지하여야 하며, 내부자료 유출 등 문제발생 시 수행업체가 모든 민 형사상 책임을 져야 함 2. 사업내용 세부과업내용은 I. 4. 과업의 범위(P2) 참조 위원회 통합관리시스템 을 구축하여 도시계획위원회, 도시건축공동위원회 업무를 처리 할 수 있도록 시스템 구축 운영 단계(위원회 개최 준비/위원회 개최 시/위원회 개최...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 학사 정보시스템 고도화 기 구축된 학사운영시스템 에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 정보기술 활용 전략 향후 우리대학 학사정보시스템의 환경 변화에 대비하여 상용 DBMS(Oracle, MS SQL Server)를 적용할 수 있도록 구현하여야...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT DA업무관리 주제영역 도메인그룹 인포타입 등 관리 작업스레줄 정보관리 및 실행결과 조회 산출정보 설치결과서 기술지원 확악서 요구사항 분류 시스템장비 요구사항 요구사항 번호 ECR-0O7 요구사항 명칭 리포팅 슬루선 정의 리포팅 슬루선 요구사항 요구 사항 상세 설명 일반 요건 일반행정 시스템에서 사용중인 리포팅 틀 유지 서버 증설로 인한 라이선스 추가 구매 필요 리포트 공통모둘 개발 및 기존 모둘과의 연동 방안을 제시하고 연동작업시 기존 행정시스템의 공통모둘 작업이 포함되어야 함 세...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ;녀 태L시 고려대학교 NOREA LHIVER5ITY 사: 경영통계시스템 데이터 취합 /분석 전반의 수작업 개선 필요 기촌 경영통계시스템의 데이터 수집 저장 및 분석관리체계 미비로 시스템 활용도 저하 각종 통계자료의 공문처리틀 통한 수기 요청 취합으로 업무 비효율 발생 수작업 기반의 동계 급시데이터 0 2 밭전거히 부서KPI 응 이형점검 및 취e/ 보고 성과환류 수작업에 의한 한계 존재 테이터 2 사업성과 및 사업예산 짐행 품질관리 수기관리어 의한 업구 비i움 미급으로 경영공거시스템 I9D 정보장 시용리) 장계시스템 시스템 합용 미...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 역량기반 교과목 운영체계 정보화 개선 강의계획서 상 역량항목 입력올 서울캠퍼스 역량으로만 구축하여 세증캠퍼스 적용 불가 2024년부터 운영되는 CQI보고서클 현재는 역량관리시스템(KUchive KUSEUM)에서 관리하고 있어; 학사행정시스템으로 기능 이관 필요 학생들의 수강소감 및 그에 대한 사후조치틀 현재는 액설로 관리 제금검 전공-교맙 교과 외먼관리 점보화 지원 미급 서금램 서문램 전곡-고망-비교과 전공뜩화역량 대사흰생 책심 문갑여람관리처계 매짐 필요 먹라관리 필요 미늄 4Hs...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 작성하여야 함 제안서 목차 및 작성 방법 2. 제안서 서명 및 효력 제출된 제안서의 내용은 인천광역시에서 요청하지 않는 한 변경 할 수 없으며, 계약 체결 시 계약 조건의 일부로 간주한다. 제안내용에 대한 확인을 위하여 추가 자료를 요청 할 수 있으며, 이에 따라 제출된 자료는 제안서와 동일한 효력을 가진다. 제안서에 기재된 내용 이외의 의사표시는 인정하지 않는다. 제안업체는 본 제안요청과 관련한 모든 문서를 대외비로 취급하여야 하며, 제안참여 업체관계자 이외의 인원에 대해서는 공개하지 말아야 한다. 제안서 평가위원회의 평가내용 및...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 및 관련 자료에 대한 관리 기능 - 안건별 이력관리 및 산출 자료 활용(자료 검색, 통계 분석, 보고서 작성 등) 기능 - 위원회 확대에 대비한 메인화면 구성 및 사용편의성 강화 방안 마련 - 외부위원의 경우 외부망(인터넷망)을 통하여 접근이 가능 하도록 구성 임의 사용자가 시스템 사용할 수 없도록 권한 관리 철저(회원가입 불가, 임시 아이디 제공 등) 내부시스템 연계 부문 - 인천광역시 업무정책포털, 인천시 공간정보플랫폼, UMS시스템 등과 연계를 통한 업무 처리 및 행정 절차 연계 - 부서 등 조직개편에 대응한 자료구조체계 마련...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 비인가자에 의한 플로우 통제의 변조 URL 직접 접근 콜라이언트 스크립트 변조 등 우회 방지 기능 구현 산출정보 프로그램 목록 프로그램명세서 화면정의서 사용자매뉴얼 등 요구사항 분류 기능 요구사항 요구사항 번호 SFR-공통-005 요구사항 명칭 연계관리 정의 공통 연계관리 기능 정의 연계정보관리 연계 대상 시스템별 연계 정보름 관리하는 기능 구현 내부/외부 연계 시스템에서 사용하는 데이터구조 변경시 영향도 분석 및 정상적 기능 유지름 위한 방안 제시 및 적용 교내 시스템 연계정보관...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 나. 상세요구사항 1) 기능 요구사항(System Function Requirement) 2) 성능 요구사항(PER, Performance Requirement) 3) 인터페이스 요구사항(Interface Requirement) (이 하 여 백) 4) 데이터 요구사항(Data Requirement) (이 하 여 백) 5) 테스트 요구사항(TER, Test Requirement) 6) 보안 요구사항(SER, Security Requirement) 7) 품질 요구사항(Quality Requirement) 8) 제약사항(Constrain...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 프로직트관리 요구사항(PMR) 요구사항 분류 프로적트관리 요구사항 요구사항 번호 PMR-0O7 요구사항 명칭 사업 추진일정 정의 사업 추진일정 계획 사업 추진일정 관리 단계별 일정 우선순위 세부활동 등이 포함된 일정계획 제시 사업기간 동안 이루어질 보고 및 검토계획올 상세하게 제시(착수 중간 완로보고 주간 월간보고 등) 본 사업 요구사항 대비 산출물의 반영여부름 추적 관리할 수 있는 전산 프로그램(PMS 등)올 통한 활동 수행 방안 제시 요구 일정계획에 따른 관리방안 및 체계 제시...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 차세대 정보시스템 DB설계자와 주기적인 정보교류 및 의사소통 기존 시스템에 운영 중인 데이터 이관방안 및 데이터의 공유방안올 수립하여 제시 데이터의 유형 및 특성올 파악하여 용이성 안정성 전환시간 등흘 고려한 효과적인 유형별 전환 방법 정의 이관 안정성올 확보할 수 있도록 수차에 결친 단계별 처리방안 수립 및 일 정계획 수립 데이터 이관작업 수행에 필요한 가이드라인 작성 담당자별 책임과 역할울 정의하고 이관 및 공유 데이터에 대한 검종항목, 검증방안 및 검증 주체름 명확히 제시 대...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 차세대 학사행정시스템 일반행정시스템 연구포털 (2) 웬메일시스템(2) 학습관리시스템(LMS) KUchive KUSEUM MRO시스템(구매대행) (2) 형상관리시스템 성과관리시스템 모바일 통합업 그룹웨어(전자결재 포함) 공간관리통합시스템 경영통계시스템 공동기기시스템 SK미래관 예약시스템 모바일좌석배정업(서울) 모바일좌석배정업(세종) 경력개발시스템(서울) 경력개발시스템(세종) (2) 도서관흉페이지(서울 중앙도서관) 도서관흉페이지(서울 의학도서관) 도서관흉페이지(세종 학술정보원) 규정관...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# egovframe포털(www.egovframe.go.kr) 참조 3) 정보시스템 구축 기술 요건 서비스 접근 및 전달 분야 - 정보시스템은 사용자가 다양한 브라우저 환경에서 서비스를 이용할 수 있도록 표준기술을 준수하여야 하고, 장애인저사양 컴퓨터 사용자 등 소외계층을 고려한 설계구현을 검토하여야 한다. 인터페이스 및 통합 분야 - 정보시스템 간 서비스의 연계 및 통합에는 웹서비스 적용을 검토하고, 개발된 웹서비스 중 타 기관과 공유가 가능한 웹서비스는 범정부 차원의공유활용이 가능하도록 지원하여야 한다. 플랫폼 및 기반구조 분야 -...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 전자서명 주요 기능 위원회회의록 교무처장단회의록 등 주요 회의체 회의록에 대한 전자서명(날인)관리 기능 구현 학사 포털 등 사업대상에서 전자서명이 필요한 업무름 식별하여 적용 서명예시: 지도교수 주임교수 학과장 학장 서명 등 업무예시: 학위청구 논문심사신청 등 현재 전산화b 양식에서 전자서명 필요양식 식별 미전산화된 양식에서 전자서명 필요양식 식별 후 구현 전자결재 연동 주요 기능 계약서 서명본 등올 점부하여 전자결재 기안 후 결재 완료 시 전자계약 프로세스틀 진행하도록 연계 그 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 산출정보 요구사항 분류 프로적트관리 요구사항 요구사항 번호 PMR-0O8 요구사항 명칭 시스템 안정화 체계 구축 정의 구축권 시스템의 안정화 체계 관리사항 정의 구축 시스템 인수인계 작업 수행 안정된 인수인계름 위해 시스템 테스트 단계부터 인계자와 인수자가 확정되어야 함 인계자는 업무별 상세 인수인계계획서클 작성하여 인수자와 함께 검토하여야 함 인수인계 산출물에는 인계 대상 프로그램 목록 소스 등 유지보수에 필요한 정보가 포함되어야 함 인계 대상 소스는 형상관리시스템에 등록하고 배...

# %%
# Re-run Example Query 5
if qa_chain and processed_documents:
    pdf_doc = next((doc for doc in processed_documents if '고려대학교' in doc.metadata.get('파일명', '')), None)
    if pdf_doc:
        query = "고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경을 설명해주세요."
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 고려대학교 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경을 설명해주세요.
#
# Generated Response:
# 고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경은 다음과 같습니다:
#
# 1. **교육 환경의 급격한 변화 대응**: 학령인구 감소, 코로나19 팬데믹으로 인한 교육 환경 변화, 인공지능의 활용 등으로 대학은 급격한 사회 및 기술 변화에 직면하고 있습니다.
#
# 2. **분산된 시스템 및 데이터의 통합**: 급변하는 교육 환경 속에서 정보화 요구사항이 증가하고 있으나, 고려대학교는 노후화된 학사 시스템을 기반으로 업무마다 분산된 정보화 추진을 하고 있어 시스템 통합에 대한 요구가 증가하고 있습니다.
#
# 3. **데이터 기반 대학 경영 지원 개선**: 분절된 정보 시스템 간의 정보 연계 미흡 및 정보화 표준 부재로 인해 경영 현황 파악 및 의사결정 시 한계가 발생하고 있습니다.
#
# 4. **사용자 정보 서비스 접근성 개선**: 교내 구성원의 정보 탐색 지원을 위한 포털 서비스가 제공되고 있으나, 포털의 정보 접근성 및 유용성에 대한 개선 요구가 상당합니다.
#
# 5. **대학 경쟁력 강화 및 전략 목표 달성 지원**: 노후화된 시스템의 차세대 구축을 통해 정보 서비스의 품질을 강화하고 대학 교육 시스템의 경쟁력을 확보하고자 합니다.
#
# Query Time: 8.17 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 NOREA LHIVER5ITY 사업 개요 1. 사업개요 가 사업명: 고려대학교 차세대 포털학사 정보시스템 구축 사업 나: 사업기간: 계약일로부터 24개월 이내 다: 무상유지보수기간 사업종료일로부터 12개월 라: 사업예산 : 71,270,000,000원 (VAT 포함 3년 분할 지급) 2024학년도 약 309 지급 2025학년도 약 40% 지급 2026학년도 약 309 지급 마: 입찰 및 계약 방법: 제한 경쟁 입찰(현상에 의한 계약) 바 본 사업은 3개년에 결친 다년 사업으로 사업 수행에 따른 대가도 3개년에...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024 7. 01 KOREA UICKSI 고려대학교 KOREA UNIVERSITY X 본 자료는 제안내용의 설명올 위한 배포자로로, 이외 목적으로 무단부제 , 전달 및 사용하는 행위틀 금함...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 관리자관리 포털 시스템 관리자 등록 및 변경 관리 기능 구현 관리자 통합계정관리(통합정보시스템 공통기능) 관리자 승인 권한 관리자 P관리 관리자 이력 관리 등 현재 포털 관리자기능 재구현 및 신규 관리 필요사항 구현 산출정보 프로그램 목록 프로그램명세서 화면정의서 사용자매뉴얼 등 요구사항 분류 기능 요구사항 요구사항 번호 SFR-포털-007 요구사항 명칭 행정시스템 연계 서비스 정의 행정시스템 연계 서비스 정의 행정시스템 연계 서비스 제공 방식 학사행정시스템 화면 중 (학생 교수)...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 아: 첫봇 현 첫봇 고도화 필요 0 1차 첫봇 사업흘 통해 도출권 사용자 요구 반영 필요 교원 직원 세중캠퍼스 학생까지 대상올 확대한 첫봇 시스템 구축 필요 교수 사용자의 교육 연구 관련 다양한 문의에 대한 응답 규정과 연계하여 사용자의 문의 내용에 대한 응답 및 근거가 되는 관련 규정 자료 문서 등올 같이 제공할 수 윗도록 구축 0 1차 첫봇 사업 범위 (상세 내용은 사업 착수 후 공유) 첫보시스템 구축(질의응답 GPT 기반 햇봇 구현) 질의응답 기반 켓복 오른 GPT기반 규정학...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 NOREA LHIVER5ITY 3 추진 체계 가 추진 조직도 정보화위원회 교무부총장 정보화 실무위원회 차세대정보화추진단 본부 단장 교무부총장 디지털정보처장 디지털정보처 부단장 디지털전락팀 포델학사/ 국저화TFT 포털/학사 국제화파트 정보통합 / 일반행정 파트 정보통합 일반행정 TFT 기획 관리 건축 / 시설 /안전 원격 다외 SSC 입시 산단 정보가발 /인프라 학예 미래교육원 포털 전자결재 학사 학생 국제 전자계약/ 규정 정보인프라 파트장 시업관리 모델모바일 / 경영통계 요구사항 도출 업무 프로세스 재설계 구축...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 학사 정보시스템 고도화 기 구축된 학사운영시스템 에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 정보기술 활용 전략 향후 우리대학 학사정보시스템의 환경 변화에 대비하여 상용 DBMS(Oracle, MS SQL Server)를 적용할 수 있도록 구현하여야...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 3. 사업 범위 가: 응용SW개발 고려대학교 차세대 포털 학사 정보시스템 구축 사업 정보시스템 주요내용 비고 통합로그인 통합/지능형 검색 마이페이지 공지/알림 일정관리 커묶니티 게시판 사용자별 정보서비스 위젯 연계서비스(월메일 첫봇; 전자결재 , 학사 행정 서비스) 등 학생(졸업생포함) 교직원 연구원 등 내부 구성원 대상 포털 학생 교수 등 신분/개인별 주요 정보 제공 학사 행정/연구 시스템의 주요 기능 직접 접근 개인화 위짓 등 개인화-SSO(기존 보유 활용) 간편인증 2차인증적...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 개인정보 수집 이용 동의서 개인정보 수집/이용 동의 안내 개인정보보호번에 따라 고려대학교 사업 참여에 대한 개인정보 처리(수집, 이용) 내 역울 안내해 드리오니 자세히 읽은 후 동의하여 주시기 바람니다: [필수정보] 개인정보 수집/이용 내역(동의 필수) 수집 이용 개인정보 항목 수집 이용 목적 보유 및 이용 기간 고려대학교 '차세대 성명 소속 직위 학력 포털 학사 시스템 연령 경력 구축 사업' 입찰참가신청 수집 이용 동의일로부터 보유목적 달성 시 단 사업 이력관리블 위하여 사업 종...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ;녀 태L시 고려대학교 NOREA LHIVER5ITY 나: 주요 서비스 구성 현황 포털 학사 모바일입 시스템 기능 현황 방문 후 열람 가능 포털 학사 데이터 연계 현황 방문 후 열람 가능 다: 인프라 현황 하드웨어 및 시스템 S/W 현황 방문 후열람 가능 3. 문제점 및 개선방향 -14-...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ;녀 태L시 고려대학교 KOREA UHIVERsITT 학사행정시스템 요구사항 분류 기능 요구사항 요구사항 번호 SFR-학사-001 요구사항 명칭 학적기본관리 정의 학적 학적기본관리 기능 정의 학사일정관리 캠퍼스 대학(원) 학과(부)의 각종 학사 일정올 등록하여 관리할 수 있는 학사일정관리 기능 구현 학사일정올 등록하고 신청이 필요한 학사일정의 시작일자와 종료일자루 등록 컬린터 형태로 학사일정올 관리할 수 있도록 함 정원관리 학과별로 정원 내정원 외 인원올 관리할 수 잇는 학사정원, 입학정원 편제정원 관리 기능 구현 년도별 학기별 대...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 다양한 검색어 입력 편의 기능 구현 자연어 처리 자동완성 오타고정 다국어 처리 연관 검색어 처리 추천어 처리 등 사용자 의도에 맞는 다양한 형태의 검색 결과 표출 사용자 권한별 검색 결과 표출 인기검색어 연관검색어 등 다양한 유형의 통계 지원 첫봇 구축된 첫봇 서비스와 연계하여 질의 수행 / 응답 확인이 가능하도록 기능 구현 산출정보 프로그램 목록 프로그램명세서 화면정의서 사용자매뉴얼 등 요구사항 분류 기능 요구사항 요구사항 번호 SFR-포털-002 요구사항 명칭 포털연동 정의 포...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 서식 25] 보안서약서 (용역업체 직원용) 고려대학교 정보시스템 관련 업무(기술지원, 개발 기타)틀 수행하는 협력회사 상주파견업체 기타 외부업체 직원들은 본 서약서가 업무기간분만 아니라 업무 해제 후에도 일정기간 적용월 수 있음올 인식하고 숙독하신 후 서명하기 바람니다: 1. 나는 고려대학교로부터 취득한 모든 정보름 관련 업무에 한해 이용할 것이미 개인적으로 사 용하거나 별도 보관하지 아니한다: 2. 나는 고려대학교로부터 제공받은 각종 정보자산을 무단 변조 복사 웨손 분실 등으로부...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 차세대 정보시스템 DB설계자와 주기적인 정보교류 및 의사소통 기존 시스템에 운영 중인 데이터 이관방안 및 데이터의 공유방안올 수립하여 제시 데이터의 유형 및 특성올 파악하여 용이성 안정성 전환시간 등흘 고려한 효과적인 유형별 전환 방법 정의 이관 안정성올 확보할 수 있도록 수차에 결친 단계별 처리방안 수립 및 일 정계획 수립 데이터 이관작업 수행에 필요한 가이드라인 작성 담당자별 책임과 역할울 정의하고 이관 및 공유 데이터에 대한 검종항목, 검증방안 및 검증 주체름 명확히 제시 대...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 공간관리시스템(아키버스) nodejs; Thingworx 건축팀 정보공시통합비교시스템 평가팀 경영통계시스템 정보개발팀 고려대 채용시스템 정보개발팀 고려대 강사임용지원시스템 정보개발팀 고려대 교원소봉지원시스템 정보개발팀 수집기록관리시스템 박물관 대량메 일발송시스템(EMS) 정보인프라팀 스크램마스터 커유니베이선팀 Javascript nodejs expressJs flutter vuejs 연구실안전관리시스템 안전관리팀 연구포털 (RMS) Java Spring 산학경영팀 연구자네트워크(K...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 설명 이숙가 되는 업무의 재설계 및 정보화 방안 제시(BPR) 업무 프로세스 재설계 대상 업무는 ISP에서 학사행정 전반에 걸처 도출된 업무 프로세스 재설계 대상올 기준으로 하려 주요 대상 업무는 아래와 같음 각 학과 졸업기준 요건과 정보화 정도 분석 및 차세대 정보화 개선 방안 대학원별 입시-학적생성 시점에 따른 대학원생 정보시스템 사용 이수 점검 및 개선 방안 도출 (대학원 입시-학적 전반 프로세스 점검]재설계) 장학금 관리 체계 및 장학 추천 /신청-선발 /통계 전반의 정보화...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국녀 벼LA 고려대학교 NOREA LHIVER5ITY 가: 포털시스템 포털 화면 이중관리로 인한 유지보수 어려움 현재의 포털 서비스 구현 형태는 메뉴/화면 수정 시 포털의 메뉴/화면과 해당하는 학사행정 일반행정시스템의 메뉴 화면올 이중으로 관리해야 하는 구조 기뉴 포드 심지도 두물R화 도델리 민사 급며는 5'도포덤 기쁨다 필크하다 저공하고 그 도 기논혼 포념 내무머 구런하여 관련 시스템과 기늄 급육표 초리철 미로 민혀 중부 기늄되 수점히 월요: 컴로 미중 완걸미 밥심하고 도급 레시판 저규니리 지리관리 점보는 포되다다 및고 그 되 검...

# %% [markdown]
# # Task
# Implement metadata filtering and conversational memory in the RAG chain and update the example queries to demonstrate these features.

# %% [markdown]
# ## Implement metadata filtering
#
# ### Subtask:
# Modify the retrieval process to allow filtering documents based on metadata.

# %% [markdown]
# **Reasoning**:
# Update the RetrievalQA chain creation to include metadata filtering capabilities in the retriever.

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import DocumentCompressorPipeline
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_transformers import EmbeddingsRedundantFilter
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers import MultiQueryRetriever
from langchain.prompts import PromptTemplate
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None

if OPENAI_API_KEY and vectorstore:
    llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY, temperature=0.3, max_tokens=1500, top_p=0.8)

    template = """다음 문서를 사용하여 질문에 답하세요.
    답변은 가능한 한 정확하고 간결하게 작성하세요.
    제공된 문서에 없는 내용은 언급하지 마세요.
    문서:
    {context}

    질문: {question}

    답변:"""
    QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

    # Update the base retriever to accept filters
    # The filter structure will be determined dynamically based on the query in later steps.
    # For now, we just modify the retriever to potentially use a filter.
    # Langchain's FAISS retriever supports filtering by metadata.
    # The filter needs to be a dictionary specifying the key and value to filter on.
    # Example: {"발주 기관": "한영대학"}
    # We will demonstrate filtering in the example queries in the next step.

    # We will create a base retriever that accepts a filter parameter in its get_relevant_documents method
    # However, the standard .as_retriever() method from FAISS doesn't directly expose a filter parameter
    # in this way for simple use with RetrievalQA.
    # A more direct way to integrate filtering with RetrievalQA is to pass the filter
    # in the query to the chain. Let's revert the retriever creation back to how it was,
    # and the filtering logic will be applied when invoking the QA chain later.

    # Reverting to the multi-query retriever without explicit filter in the retriever definition
    base_retriever = vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={"k": 10, "fetch_k": 20}
    )

    multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever=base_retriever,
        llm=llm
    )

    final_retriever = multiquery_retriever

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=final_retriever,
        return_source_documents=True,
        chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
    )

    print("RetrievalQA chain created, ready for metadata filtering in query invocation.")

else:
    print("Skipping RAG chain creation due to missing API key or vector store.")
    qa_chain = None
# Out:
# RetrievalQA chain created, ready for metadata filtering in query invocation.

# %%
import time

def time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter=None):
    """
    Times the execution of a RAG query with optional metadata filtering,
    correctly applying the filter to the retriever's search_kwargs.

    Args:
        qa_chain: The RAG chain object.
        query (str): The query string.
        metadata_filter (dict, optional): A dictionary specifying metadata filter criteria.
                                          Defaults to None.

    Returns:
        tuple: A tuple containing the response dictionary and the execution time in seconds.
    """
    start_time = time.time()

    # Access the retriever within the QA chain
    # The exact path might vary slightly depending on the chain type and retriever wrapping
    # If using MultiQueryRetriever wrapped around a base retriever, we need to access the base retriever
    if hasattr(qa_chain.retriever, 'retrievers') and isinstance(qa_chain.retriever.retrievers, list):
         # This case might apply if using something like EnsembleRetriever or similar multi-retriever setups
         # For MultiQueryRetriever, the base retriever is usually accessed differently
         base_retriever = qa_chain.retriever.retrievers[0] # Assuming the first retriever is the base one
    elif hasattr(qa_chain.retriever, 'retriever'):
         # This is the case for ContextualCompressionRetriever and likely MultiQueryRetriever
         base_retriever = qa_chain.retriever.retriever
    else:
         # Direct retriever instance
         base_retriever = qa_chain.retriever


    # Temporarily modify the retriever's search_kwargs to include the filter
    original_search_kwargs = base_retriever.search_kwargs
    if metadata_filter:
        # Create a copy of original search_kwargs and add the filter
        modified_search_kwargs = original_search_kwargs.copy()
        modified_search_kwargs["filter"] = metadata_filter
        base_retriever.search_kwargs = modified_search_kwargs
        print(f"Applying filter: {metadata_filter}")
    else:
        # Ensure no filter is applied if metadata_filter is None
        if "filter" in original_search_kwargs:
             modified_search_kwargs = original_search_kwargs.copy()
             del modified_search_kwargs["filter"]
             base_retriever.search_kwargs = modified_search_kwargs
        print("No filter applied.")


    # Invoke the chain with the query
    # The search_kwargs are now set on the retriever itself
    response = qa_chain.invoke({"query": query})

    # Restore the original search_kwargs on the retriever
    base_retriever.search_kwargs = original_search_kwargs

    end_time = time.time()
    execution_time = end_time - start_time
    return response, execution_time

# Example Query 1 with Metadata Filter (Filter by '발주 기관': '한영대학')
if qa_chain and processed_documents:
    query = "이 사업의 추진 배경 및 필요성은 무엇인가요?"
    metadata_filter = {"발주 기관": "한영대학"}
    print(f"Query: {query}")
    response, query_time = time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter)

    print("\nGenerated Response:")
    print(response['result'])
    print(f"\nQuery Time: {query_time:.2f} seconds")
    print("\nSource Documents:")
    for doc in response['source_documents']:
        print(f"--- Source: {doc.metadata.get('source', 'N/A')} ---")
        print(f"Metadata: {doc.metadata}")
        print(doc.page_content[:300] + "...")
else:
    print("RAG chain or processed documents not initialized.")

print("-" * 50)

# Example Query 2 with Metadata Filter (Filter by '파일형식': 'pdf')
if qa_chain and processed_documents:
    query = "이 사업의 추진 배경을 설명해주세요."
    metadata_filter = {"파일형식": "pdf"}
    print(f"Query: {query}")
    response, query_time = time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter)

    print("\nGenerated Response:")
    print(response['result'])
    print(f"\nQuery Time: {query_time:.2f} seconds")
    print("\nSource Documents:")
    for doc in response['source_documents']:
        print(f"--- Source: {doc.metadata.get('source', 'N/A')} ---")
        print(f"Metadata: {doc.metadata}")
        print(doc.page_content[:300] + "...")
else:
    print("RAG chain or processed documents not initialized.")

print("-" * 50)

# Example Query 3 with Metadata Filter (Filter by '사업명')
if qa_chain and processed_documents:
    # Find an example 사업명 from the processed documents
    example_doc = processed_documents[0] if processed_documents else None
    if example_doc and '사업명' in example_doc.metadata:
        example_사업명 = example_doc.metadata['사업명']
        query = f"'{example_사업명}' 사업의 개요는 무엇인가요?"
        metadata_filter = {"사업명": example_사업명}
        print(f"Query: {query}")
        response, query_time = time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter)

        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} ---")
            print(f"Metadata: {doc.metadata}")
            print(doc.page_content[:300] + "...")
    else:
         print("Could not find an example document with '사업명' metadata for Query 3.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query: 이 사업의 추진 배경 및 필요성은 무엇인가요?
# Applying filter: {'발주 기관': '한영대학'}
#
# Generated Response:
# 제공된 문서에는 이 사업의 추진 배경 및 필요성에 대한 구체적인 내용이 포함되어 있지 않습니다. 따라서 해당 질문에 대한 답변을 제공할 수 없습니다.
#
# Query Time: 3.09 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 함. 본 사업은 기능점수 기반으로 수립되어 소프트웨어사업 관리감독에 관한 일반기준 (미래창조과학부 고시) 제7조(제안요청서 준비)의 단서 조항에 따라 제안사의 투입인력 계획을 핵심인력에 한하여 제안 요청하는 사업이다. [자료 1] 사업자 보안위규 처리기준 [자료 2] 누출금지 대상정보 누출 시 제재조치 사항 계약업체는 국가를 당사자로 하는 계약에 관한 법률 시행령 제76조 제1항 제18호 규정을 위반하여 아래의 누출금지 대상정보를 무단으로 누출할 경우 아래와 같이 입찰참가자격이 제한(부정당업체 제재 조치)된다. - 정보 누출 횟수가...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# . 서약자 : 대표 (인) 한영대학교 총장 귀하 [서식 제9호] [서식 제10호] 정보 비공개동의서 본인은 귀 한영대학교의 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화 참가와 관련하여 취득한 각종 정보에 대하여 제3자에게 일체 누설하지 않겠으며 귀 한영대학교가 정한 보안사항을 철저히 준수할 것을 동의합니다. 2024. . . 상 호(법인명): 주 소 : 대 표 자 : (인) 사업자등록번호 : 한영대학교 총장 귀하 [서식 제11호] [서식 제12호] 봉투규격과 상관없이 밀봉 후 작성, 날인하는 방법 참조하세요. 가격...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 경우에는 그 사유 및 대안을 제시하여야 한다. Reporting 전용 툴을 사용하여 출력물을 설계하되, 기능면에서 제한사항이 있으면 이에 대한 사유를 명시하고 대안을 제시하여야 한다. 통계보고서의 정형화 및 대학 전체가 공통된 내용의 업무지표 사용과 조회자료의 편리한 Export 지원(Excel 등)이 되어야 한다. 구성원별(교수/직원/조교 등), 소속부서와 업무분장에 따라 체계적인 계정 및 권한을 관리할 수 있도록 구축되어야 한다. 데이터 품질관리 전담자를 두어야 하며, 업무처리절차 개선 방안과 구현 방안 제시하여야 한다. 입찰방...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 따라 폐기할 것 - 문서의 보안등급 부여 및 차별화 된 권한관리를 수행할 것 등 본 사업의 수행 결과물(계약목적물)에 대한 지식재산권은 과업 수행 중 설계된 내용에 대해서는 별도의 정함이 없는 한 지분은 균등한 것으로 하고, 시스템 설계를 발주기관이 한 것에 대하여는 발주기관이 갖도록 합니다. 다만, 개발의 기여도 및 계약목적물의 특수성(보안, 영업비밀 등)을 고려하여 계약당사자간의 협의를 통해 지식재산권 귀속주체 등에 대해 공동소유와 달리 정할 수 있습니다. 또한, 지식재산권의 타 용도 및 상업적 활용 시 반드시 발주기관과 협의하...
# --------------------------------------------------
# Query: 이 사업의 추진 배경을 설명해주세요.
# Applying filter: {'파일형식': 'pdf'}
#
# Generated Response:
# 이 사업의 추진 배경은 다음과 같습니다:
#
# 1. **교육 환경의 급격한 변화 대응**: 학령인구 감소, 코로나19 팬데믹으로 인한 교육 환경 변화, 인공지능의 활용 등으로 대학은 급격한 사회 및 기술 변화에 직면하고 있습니다.
#
# 2. **분산된 시스템 및 데이터의 통합 필요**: 정보화 요구사항이 증가하고 있으나, 고려대학교는 노후화된 학사 시스템을 기반으로 업무마다 분산된 정보화 추진으로 인해 시스템 통합에 대한 요구가 증가하고 있습니다.
#
# 3. **데이터 기반 대학 경영 지원 개선**: 분절된 정보 시스템 간 정보 연계 미흡 및 정보화 표준 부재로 인해 경영 현황 파악 및 의사결정 시 한계가 발생하고 있습니다.
#
# 4. **사용자 정보 서비스 접근성 개선**: 교내 구성원의 정보 탐색 지원을 위한 포털 서비스가 제공되고 있으나, 포털의 정보 접근성 및 유용성에 대한 개선 요구가 상당합니다.
#
# 5. **대학 경쟁력 강화 및 전략 목표 달성 지원**: 노후화된 시스템의 차세대 구축을 통해 정보 서비스의 품질을 강화하고 대학 교육 시스템의 경쟁력을 확보하고자 합니다.
#
# Query Time: 7.61 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 2, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 목 차 I . 사업개요 1. 사업 개요 2. 사업 배경 3 사업 범위 4. 기대효과 5 끄. 현황 및 문제점 1. 일반 현황 2. 정보화 현황 3. 문제점 및 개선방향 8 15 교. 사업 추진방안 1. 추진 목표 2. 추진 일정 3. 추진 체계 33 33 35 36 IV. 제안요청 내용 1. 제안요청 개요 2. 상세 요구사항 38 38 43 V . 제안 일반 사항 1. 사업관리 사항 2. 입찰 참가 신청 방법 3 사업자 선정 방법 4. 제안 설명회 5. 제안 평가 방식 230 23...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 233, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 3. 사업자 선정 방법 가 참가 자격 1) 소프트웨어산업진콩법 제24조 규정에 의거 소프트웨어사업자(컴퓨터관련 서 비스사업 업종코드 1468)로 등록된 업체 2) 국가틀 당사자로 하는 계약에 관한 법률시행령 제12조 및 동법시행규칙 제74 조 규정에 의한 자격올 구비한 업체 3) 국가틀 당사자로 하는 계약에 관한 법률 제27조 및 동법시행령 제27조 및 동 법시행령 제76조에 의한 부정당업자로 제재지 받지 양분 업체 4) 소프트웨어산업진콩법 제48조 제4항에 따라 상호출자제한기업집...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 207, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 보안 요구사항(SER) 요구사항 분류 보안 요구사항 요구사항 번호 SER-007 요구사항 명칭 프로적트 보안관리 정의 프로적트 보안 관리틀 위한 정보보안 관리지침 등올 준수 사업 정보 누출 방지름 위한 관리체계 수립 사업 착수 수행 완료 등 사업 전체 단계별 보안관리 방안 수립 사업수행조직 내 보안 개인정보 책임자 담당자루 지정하여 운영 사업기간 내 보안상 문제점 발견시 즉시 대책올 수립 후 해결방안 제출 용역 수행과정에서 사업 수행사에 의하여 관련 행정정보 개인정보 등이 유출월 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 246, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 작 성 항 목 작 성 방 법 기술하엿논가름 평가하고 구현 경험이 잇는 인터페이스 담 당자가 투입되논지 평가한다: 도입되논 장비의 성능 테스트 또는 구축된 시스템이 목표 대비 제대로 운영되는가을 테스트하고 점검하기 위한 테스트 요구 사항울 기술하다: 목표시스템의 테스트 유형(단위 테스트 통합 테스트 시스템 테스트 성능 테스트 등) 테스트 환경 방법 절차 등 요구사항올 기술하다: 4. 테스트 요구사항 V 프로적트 관리 사업위험 사업진도 사업수행 시 보안율 관리하는 방법 사업수행 성과물...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 231, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 6) 사업자등록증 사본 (원본대조필) 7) 법인등기부등본 (최근 3개월이내 발급 개인사업자는 대표자 주민등록등본) 8) 법인인감증명서 (최근 3개월이내 발급 개인사업자는 대표자 인감증명서) 9) 입찰보증금 (하단 다-1) 참조) 10) 소프트웨어사업자 등록증 사본 17) 기업 분류 확인 자료(중소기업 중권기업 대기업 등) 12) 지방세 및 국세 남세 증명서 다: 유의사항 7) 제안사는 입찰보증금올 남부하여야 함: 이 경우 입찰보증금의 금액 남부방법 등에 관하여는 국가을 당사자로 하...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 254, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT [ 서식 6 ] 사업 실적 증명서 업체명(상호) 대 표 자 영업소재지 전 화 번 호 신청인 사업자번호 제 출 처 증명서 용도 입찰 및 제안서 심사 제출용 ISPIBPR PMO/감리 구 시스템개발 분 운영 및 유지관리 ( ) 기 타 ( ) 사 업 명 업 행 ": 적 사 업 개 요 계약 이행실적 계 약 번 호 계약일자 계약기간 금액 공동비율 실 적 비 고 위 사실올 증명함 년 월 일 증명서 기 관 명 : 발 급 기 관 주 소 : (인) (전화번호 (FAX번호: 발급부서 담당자: (인)...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 57, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 설명 이숙가 되는 업무의 재설계 및 정보화 방안 제시(BPR) 업무 프로세스 재설계 대상 업무는 ISP에서 학사행정 전반에 걸처 도출된 업무 프로세스 재설계 대상올 기준으로 하려 주요 대상 업무는 아래와 같음 각 학과 졸업기준 요건과 정보화 정도 분석 및 차세대 정보화 개선 방안 대학원별 입시-학적생성 시점에 따른 대학원생 정보시스템 사용 이수 점검 및 개선 방안 도출 (대학원 입시-학적 전반 프로세스 점검]재설계) 장학금 관리 체계 및 장학 추천 /신청-선발 /통계 전반의 정보화...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 222, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 사업관리 자(PM)은 전체 사업흘 총관할 수 있는 지식과 경험올 보유한 자로 정규직 관리자로 선정함 사업수행올 위해 필요한 장소 설비 및 기타 자원은 상호 협의하여 정하며 , 사업수행에 필요한 환경조성(장비 등) 소요비용 일체틀 제안사가 부담함 본 사업은 상주하여 업무름 수행하는 것' 권고 하나 특정분야 업무에 대해서는 원격지원올 포함한 비상주 근무 가능 사업수행에 필요한 기간 자원 인력 조직 등올 제시하고 착수보고회 등의 보고회틀 실시하여 관련 비용은 주관사업자 부담으로 함 사업...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', 'method': 'pdf_ocr', 'page': 219, '공고 번호': None, '공고 차수': None, '사업명': '차세대 포털·학사 정보시스템 구축사업', '사업 금액': 11270000000, '발주 기관': '고려대학교', '공개 일자': '2024-07-01T00:00:00', '입찰 참여 시작일': '2024-07-05T11:00:00', '입찰 참여 마감일': '2024-08-12T11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 콤W 보롬 고려대학교 KOREA UHIVERsITT 정의 공동 수급 및 하도급 관리 방안 제시 공동 수급 및 하도급 관리 본 사업의 과업의 일부름 하도급하려분 경우 r 소프트웨어 진흥법 제51조 제부항에 따라 사업금액의 100분 50올 초과할 수 없으며 제3항에 따라 재하도급은 원직적으로 불허함 . 다만 단서 조함에 해당하는 경우는 그러하지 아니함 하도급올 하려는 경우 제안서에 하도급 계획서(계약체결 시)틀 제출하여야 함 하도급금액이 전체 사업금액의 109틀 초과하는 경우에는 공동수급체름 구성하여 본 사업에 참여하고 공동수급체름 구...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# ...
# 처분을 받은 날로 부터 2년 동안 참가하지 않겠으며 ° 1억원 이상 2억원 미만의 금품 또는 그 밖의 재산상 이익을 제공한 사실이 드러날 경우에는 한영대학교에서 발주하는 입찰에 입찰참가자 격 제한 처분을 받은 날로부터 1년 동안 참가하지 않겠으며 ° 1천만원 이상 1억원 미만의 금품 또는 그 밖의 재산상 이익을 제공한 사실이 드러날 경우에는 한영대학교에서 발주하는 입찰에 입찰참가자 격 제한 처분을 받은 날로부터 6개월 동안 참가하지 않겠으며 ° 1천만원 미만의 금품 또는 그 밖의 재산상 이익을 제공한 사실이 드러날 경우에는 한영대학...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 구축 개발 수주가 단일건으로 1억원 이상 실적이 있는 업체 Windows Server, MS-SQL기반 ASP.NET 개발환경에 구축 실적이 있는 업체 .NET기반의 Windows Server의 Application 생성 및 표준화된 표준프레임워크을보유하고 있는 업체(타대학교에 적용 및 검증된 프레임워크 활용) 공동수급(공동이행방식) 및 하도급은 불가함의 규정에 의한 경쟁 입찰 참가 자격을 갖춘 과업 수행 가능자 3) 입찰 계약조건 계약의 체결 및 이행에 관하여는 협상에 의한 계약체결 기준 제14조의 규정에 의하여 서면 통보한 협상...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 학사 정보시스템 고도화 기 구축된 학사운영시스템 에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 정보기술 활용 전략 향후 우리대학 학사정보시스템의 환경 변화에 대비하여 상용 DBMS(Oracle, MS SQL Server)를 적용할 수 있도록 구현하여야...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 트랙운영 학사정보시스템 고도화 사업에 한정하여 적용 제안사는 한영대학교의 트랙운영 학사정보시스템을 충분히 이해하고, 제안요청 사항을 기본적으로 반영하여 과업내용을 포함하여야 함 제안사는 본 제안요청서에 언급하지 않았으나, 본 과업수행 향상에 도움이 되는 사항이 있을 경우 이를 추가로 제시할 수 있음 과업수행 중 환경변화로 인하여 설계변경 되거나, 기타 예기치 않은 여건의 변화로 과업 대상 업무에 대한 일부의 변경 및 추가요구사항이 발생될 경우에는 발주처와 제안사가 상호 협의하여 변경하여야 함 계약 후 1주일 이내에 계약서, 제안요청...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# . 서약자 : 대표 (인) 한영대학교 총장 귀하 [서식 제9호] [서식 제10호] 정보 비공개동의서 본인은 귀 한영대학교의 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화 참가와 관련하여 취득한 각종 정보에 대하여 제3자에게 일체 누설하지 않겠으며 귀 한영대학교가 정한 보안사항을 철저히 준수할 것을 동의합니다. 2024. . . 상 호(법인명): 주 소 : 대 표 자 : (인) 사업자등록번호 : 한영대학교 총장 귀하 [서식 제11호] [서식 제12호] 봉투규격과 상관없이 밀봉 후 작성, 날인하는 방법 참조하세요. 가격...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', 'method': 'pyhwp', 'page': None, '공고 번호': '20241001798', '공고 차수': '0.0', '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000, '발주 기관': '한영대학', '공개 일자': '2024-10-04T13:51:23', '입찰 참여 시작일': None, '입찰 참여 마감일': '2024-10-15T17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 감독관 입회하에 종합시험을 실시하고 규격서 요구사항 및 제안서 제안 내용이 어떠한 문제도 없이 원활히 수행되어야 한다. 검사 결과 감독관의 지적사항 및 시정요구가 있을 경우는 사업자는 성실히 이행하여야 한다. 계약상대자는 본교의 요구사항에 맞게 사업을 완료 후 검사요청을 하여야 하며 본 사업 완료 후 완료보고서, 납품 및 검사조서를 제출하여 감독관에게 검사 승인을 받아야 한다. 계약상대자는 계약내역에 따라 수요기관에 용역이행대금을 청구하고, 본교는 직접 계약상대자에게 용역대금을 지급한다. 본교는 검사에 필요한 계약상대자의 미비한 서...

# %% [markdown]
# ## Add conversational memory
#
# ### Subtask:
# Integrate conversational memory into the RAG chain to maintain context across turns.

# %% [markdown]
# **Reasoning**:
# Integrate conversational memory into the RAG chain to maintain context across turns.

# %%
from langchain.chains import RetrievalQA
# Import the necessary components for conversational memory
from langchain.memory import ConversationBufferMemory
from langchain_openai import ChatOpenAI
from langchain.retrievers import MultiQueryRetriever
from langchain.prompts import PromptTemplate
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None # Set to None to prevent further errors

if OPENAI_API_KEY and vectorstore:
    # Initialize the ChatOpenAI model for generation (will also be used for Multi-Query)
    llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY, temperature=0.3, max_tokens=1500, top_p=0.8)

    # Define a refined prompt template that includes chat history
    # This template guides the language model on how to use the retrieved context and the conversation history
    template = """다음 채팅 기록과 문서를 사용하여 질문에 답하세요.
    채팅 기록:
    {chat_history}

    문서:
    {context}

    질문: {question}

    답변:"""
    QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

    # Base Retriever with higher k and MMR
    base_retriever = vectorstore.as_retriever(
        search_type="mmr", # Use MMR search
        search_kwargs={"k": 10, "fetch_k": 20} # Increased k and fetch_k
    )

    # Implement Multi-Query Retriever
    # The multi-query retriever itself does not inherently handle conversational context
    # It generates multiple queries based on the *current* query.
    # Conversational memory needs to be integrated at the chain level.
    multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever=base_retriever,
        llm=llm
    )

    final_retriever = multiquery_retriever

    # Initialize ConversationBufferMemory to store chat history
    # memory_key='chat_history' corresponds to the chat history variable in the prompt template
    # input_key='question' corresponds to the variable in the chain that will receive the user's query
    memory = ConversationBufferMemory(memory_key="chat_history", input_key="question")


    # Create a RetrievalQA chain with the advanced retriever and refined prompt
    # Add the memory parameter to the chain
    qa_chain_with_memory = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff", # 'stuff' chain type is suitable for including context in the prompt
        retriever=final_retriever, # Use the advanced retriever
        return_source_documents=True,
        chain_type_kwargs={"prompt": QA_CHAIN_PROMPT, "memory": memory} # Pass the refined prompt and memory
    )

    # Update the qa_chain variable
    qa_chain = qa_chain_with_memory

    print("Advanced RetrievalQA chain created with Multi-Query, MMR, refined generation parameters/prompt, and conversational memory.")

else:
    print("Skipping RAG chain creation due to missing API key or vector store.")
    qa_chain = None # Set qa_chain to None if creation failed
# Out:
# Advanced RetrievalQA chain created with Multi-Query, MMR, refined generation parameters/prompt, and conversational memory.

# %% [markdown]
# **Reasoning**:
# Demonstrate the conversational memory by asking follow-up questions that rely on the previous turn's context.

# %%
# Function to time RAG query (re-using the previous definition for consistency)
import time

def time_rag_query(qa_chain, query):
    """
    Times the execution of a RAG query.

    Args:
        qa_chain: The RAG chain object.
        query (str): The query string.

    Returns:
        tuple: A tuple containing the response dictionary and the execution time in seconds.
    """
    start_time = time.time()
    response = qa_chain.invoke({"query": query})
    end_time = time.time()
    execution_time = end_time - start_time
    return response, execution_time

# Example Conversation with Conversational Memory
if qa_chain and processed_documents:
    print("--- Starting Conversation with Memory ---")

    # First turn: Ask about a specific project's background (similar to previous examples)
    query1 = "한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?"
    print(f"\nUser Query 1: {query1}")
    response1, time1 = time_rag_query(qa_chain, query1)
    print("\nGenerated Response 1:")
    print(response1['result'])
    print(f"Query 1 Time: {time1:.2f} seconds")
    # Source documents are returned but not explicitly printed here for brevity,
    # as the focus is on the conversational flow.

    print("-" * 30)

    # Second turn: Ask a follow-up question that relies on the previous turn's context
    # This query doesn't mention "한영대학교" or the full project name,
    # relying on the memory to understand "이 사업" (this project).
    query2 = "그 사업의 사업 기간은 얼마나 되나요?"
    print(f"\nUser Query 2: {query2}")
    response2, time2 = time_rag_query(qa_chain, query2)
    print("\nGenerated Response 2:")
    print(response2['result'])
    print(f"Query 2 Time: {time2:.2f} seconds")

    print("-" * 30)

    # Third turn: Another follow-up question
    query3 = "사업 금액은 얼마인가요?"
    print(f"\nUser Query 3: {query3}")
    response3, time3 = time_rag_query(qa_chain, query3)
    print("\nGenerated Response 3:")
    print(response3['result'])
    print(f"Query 3 Time: {time3:.2f} seconds")

    print("--- Conversation with Memory Ended ---")

else:
    print("RAG chain with memory or processed documents not initialized.")
# Out:
# --- Starting Conversation with Memory ---
#
# User Query 1: 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?
#
# Generated Response 1:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 다음과 같습니다:
#
# 1. **학사제도 개편과 연계**: 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공하여 취업문을 확대하기 위한 필요성이 있습니다.
#
# 2. **산업현장 경쟁력 강화**: 트랙제 교육과정의 도입 및 운영을 통해 산업체 수요에 맞춘 교육과정을 운영하고 활성화하여 교육과정의 내실화를 도모하고, 기업 수요에 연계하여 산업체 및 지역사회에서 현장 실무형 인재를 양성할 필요성이 있습니다.
#
# 3. **효과적인 지원 체계 구축**: 트랙 기반 교육과정의 운영 및 관리 체계를 효과적으로 지원하기 위해 교수자와 학습자 중심의 교육환경을 조성하고, 대학 교육의 가치를 구현할 필요가 있습니다.
#
# 4. **학사운영 시스템의 고도화**: 대학 체제 개편에 대한 대응체계를 확립하고, 트랙제도 교과과정 개편 및 표준 운영 관리를 위한 시스템 구현이 필요합니다. 이는 교육과정, 수강신청, 성적, 학적 관리 등 다양한 기능을 포함해야 합니다.
#
# 5. **확장성과 유연성 고려**: 시스템의 확장성과 유연성을 고려하여 유지보수가 용이하도록 설계해야 하며, 다양한 사용자(교수, 직원, 학생)의 정보 접근성과 사용 편의성을 고려해야 합니다.
#
# 이러한 배경과 필요성은 한영대학교의 교육환경 변화에 효과적으로 대응하고, 학생들에게 더 나은 교육 기회를 제공하기 위한 기반을 마련하는 데 중점을 두고 있습니다.
# Query 1 Time: 7.38 seconds
# ------------------------------
#
# User Query 2: 그 사업의 사업 기간은 얼마나 되나요?
#
# Generated Response 2:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 사업 기간은 계약 체결일로부터 24개월 이내입니다.
# Query 2 Time: 2.89 seconds
# ------------------------------
#
# User Query 3: 사업 금액은 얼마인가요?
#
# Generated Response 3:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 사업 금액은 129,300,000원(부가가치세 포함)입니다.
# Query 3 Time: 3.19 seconds
# --- Conversation with Memory Ended ---
