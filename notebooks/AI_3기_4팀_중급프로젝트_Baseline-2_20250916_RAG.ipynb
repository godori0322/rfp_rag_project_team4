# %% [markdown]
# ### 데이터 확인 및 불러오기
#
# - 데이터는 구글 드라이브 > 프로젝트 > 중급 프로젝트 > 원본데이터에 있어요.
# - 제공된 문서 파일들과 `data_list.csv` 파일에 담긴 메타데이터를 확인합니다.
# - 문서 파일을 불러옵니다. `hwp`와 `pdf` 두 가지 포맷에 대응할 수 있어야 해요.
# - 유용한 메타데이터가 무엇일지 판단하여 함께 활용해 보세요.
#
# ### 문서 청킹
#
# - 청크 크기, 그리고 청크 간 중첩 크기를 잘 설정하여 문서를 청킹합니다.
# - (심화) 제안서 포맷을 활용해 의미 단위까지 고려하여 문서를 청킹해 보고 성능을 확인해 보세요.
#
# ### 임베딩 생성
#
# - 임베딩 성능과 비용을 고려해 적절한 임베딩 모델을 선정합니다.
# - 사용의 편의성과 검색 기능을 고려해 적절한 Vector DB를 선정합니다.
#
# ### Retrieval 기능 구현
#
# - 먼저 naive한 retrieval을 구현해 베이스라인으로 삼으면 좋습니다. 베이스라인을 기반으로 점점 더 retrieval 기능을 고도화해 나가면 됩니다.
# - 데이터 소스 문서가 하나가 아니라 여러 개이기 때문에, 타깃 문서를 정확히 찾기 위해 메타데이터 필터링을 활용할 수 있습니다. 이때 사용자가 발주 기관이나 사업명 같은 정보를 비슷하지만 정확하지는 않게 입력하는 케이스도 고려하는 게 좋아요.
# - (심화) Retrieval과 관련해 다양한 옵션과 기법을 실험하면서 성능을 확인해 보세요.
#     - Retrieval을 위한 프롬프트 엔지니어링
#     - Top-k 검색에서 k 값 설정
#     - 단순 유사도 기반 검색 / MMR(Maximum Marginal Relevance) / Hybrid Search
#     - Multi-Query, Re-Ranking 등 심화 기법
#
# ### Generation 기능 구현
#
# - 텍스트 생성 능력과 비용을 고려해 적절한 언어 모델을 선정합니다.
# - 원하는 답변 양상과 분량에 따라서 temperature, top_p, max tokens 등 텍스트 생성과 관련된 옵션도 적절하게 설정해 주세요.
# - 답변 생성을 위한 최적의 프롬프트를 작성합니다.
#     - Retrieval 과정에서 찾은 컨텍스트를 충실히 반영해야 합니다.
#     - 불필요한 내용이 답변에 포함되지 않도록 합니다.
#     - 응답의 톤이나 스타일을 조정합니다.
#     - 비용을 고려해 토큰 사용량도 최적화해 보세요.
# - RAG 시스템이 대화 맥락을 유지하여 사용자와 대화를 이어 갈 수 있도록 해 주세요.
#
# ### 성능 평가
#
# - 답변의 품질을 평가할 때는 다음과 같은 기준을 사용할 수 있습니다.
#     - 사용자가 요청한 내용을 단일 문서에서 정확하게 뽑아내 답변하는지
#     - 사용자가 여러 문서에 대해 요청한 내용을 잘 종합해서 답변하는지
#     - 후속 질문의 맥락을 잘 이해하고 답변하는지
#     - 문서에 포함되어 있지 않은 내용에 대해서는 모른다고 답변하는지
# - 위와 같은 기준을 어떤 방식으로 평가하고 어떤 지표로 나타낼지 선정해 보세요.
# - 주어진 문서 데이터에 맞게 다양한 질문 세트를 준비하여 성능 평가에 활용해 보세요.
#     - 질문 예시
#         - 국민연금공단이 발주한 이러닝시스템 관련 사업 요구사항을 정리해 줘.
#             - 콘텐츠 개발 관리 요구 사항에 대해서 더 자세히 알려 줘.
#             - 교육이나 학습 관련해서 다른 기관이 발주한 사업은 없나?
#         - 기초과학연구원 극저온시스템 사업 요구에서 AI 기반 예측에 대한 요구사항이 있나?
#             - 그럼 모니터링 업무에 대한 요청사항이 있는지 찾아보고 알려 줘.
#         - 한국 원자력 연구원에서 선량 평가 시스템 고도화 사업을 발주했는데, 이 사업이 왜 추진되는지 목적을 알려 줘.
#         - 고려대학교 차세대 포털 시스템 사업이랑 광주과학기술원의 학사 시스템 기능개선 사업을 비교해 줄래?
#             - 고려대학교랑 광주과학기술원 각각 응답 시간에 대한 요구사항이 있나? 문서를 기반으로 정확하게 답변해 줘.
# - 품질 좋은 답변도 중요하지만 응답 속도가 너무 느려져서도 안 됩니다.

# %%
# Google Drive Mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

data_dir = '/content/drive/MyDrive/Data' # Updated path
print(f"Listing contents of directory: {data_dir}")
try:
    for item in os.listdir(data_dir):
        print(item)
except FileNotFoundError:
    print(f"Directory not found: {data_dir}")
except Exception as e:
    print(f"An error occurred while listing directory contents: {e}")
# Out:
# Listing contents of directory: /content/drive/MyDrive/Data
# files
# data_list.csv
# data_list.gsheet

# %% [markdown]
# # Install Packages

# %%
# !pip install langchain langchain-openai easyocr pyhwp hwp-extract pymupdf pymupdf4llm faiss-cpu langchain-community
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.33-py3-none-any.whl.metadata (2.4 kB)
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Collecting pyhwp
#   Downloading pyhwp-0.1b15.tar.gz (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.1/218.1 kB 18.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting hwp-extract
#   Downloading hwp_extract-0.1.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pymupdf
#   Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Collecting pymupdf4llm
#   Downloading pymupdf4llm-0.0.27-py3-none-any.whl.metadata (4.8 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.75)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.4.24)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.2)
# Collecting langchain-core<1.0.0,>=0.3.72 (from langchain)
#   Downloading langchain_core-0.3.76-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (1.106.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.11.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.5 in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.23.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr) (4.12.0.88)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from easyocr) (1.16.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from easyocr) (11.3.0)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr) (0.25.2)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr) (2.1.1)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from pyhwp) (43.0.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from pyhwp) (5.4.0)
# Collecting olefile>=0.43 (from pyhwp)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting pycryptodome~=3.0 (from hwp-extract)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (25.0)
# Collecting requests<3,>=2 (from langchain)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.104.2->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch->easyocr) (3.4.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->pyhwp) (1.17.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (2025.8.28)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr) (0.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->pyhwp) (2.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->easyocr) (3.0.2)
# Downloading langchain_openai-0.3.33-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.3 MB/s eta 0:00:00
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 106.9 MB/s eta 0:00:00
# Downloading hwp_extract-0.1.0-py3-none-any.whl (10 kB)
# Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 100.3 MB/s eta 0:00:00
# Downloading pymupdf4llm-0.0.27-py3-none-any.whl (30 kB)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 69.8 MB/s eta 0:00:00
# Downloading langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 86.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_core-0.3.76-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 45.2 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 14.6 MB/s eta 0:00:00
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 103.6 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.9 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 22.7 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 62.0 MB/s eta 0:00:00
# Downloading python_bidi-0.6.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 kB 32.8 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 6.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: pyhwp
#   Building wheel for pyhwp (setup.py) ... done
#   Created wheel for pyhwp: filename=pyhwp-0.1b15-py3-none-any.whl size=315452 sha256=b1706e935fdda57c680b7aa834337e434f6d982859b3a673a12364625e66d6d8
#   Stored in directory: /root/.cache/pip/wheels/8e/13/81/cc88f3dcc6e177769677759fffa4ee79fc8eed460d2a36c0cb
# Successfully built pyhwp
# Installing collected packages: python-bidi, pyclipper, requests, pymupdf, pycryptodome, olefile, ninja, mypy-extensions, marshmallow, faiss-cpu, typing-inspect, pymupdf4llm, hwp-extract, pyhwp, dataclasses-json, langchain-core, langchain-openai, easyocr, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.75
#     Uninstalling langchain-core-0.3.75:
#       Successfully uninstalled langchain-core-0.3.75
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 easyocr-1.7.2 faiss-cpu-1.12.0 hwp-extract-0.1.0 langchain-community-0.3.29 langchain-core-0.3.76 langchain-openai-0.3.33 marshmallow-3.26.1 mypy-extensions-1.1.0 ninja-1.13.0 olefile-0.47 pyclipper-1.3.0.post6 pycryptodome-3.23.0 pyhwp-0.1b15 pymupdf-1.26.4 pymupdf4llm-0.0.27 python-bidi-0.6.6 requests-2.32.5 typing-inspect-0.9.0

# %%
# 필수 빌드 도구 & 라이브러리 설치
# !apt-get update
# !apt-get install -y build-essential libgsf-1-dev libxml2-dev libglib2.0-dev libiconv-hook-dev

# 소스코드 clone
# !git clone https://github.com/mete0r/pyhwp.git


# 설치
# !python setup.py install
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [346 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,006 kB]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [43.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,624 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,795 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,274 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [88.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,581 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [5,627 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,311 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [80.3 kB]
# Get:23 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [5,441 kB]
# Get:24 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,267 kB]
# Fetched 35.6 MB in 5s (7,742 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# libglib2.0-dev is already the newest version (2.72.4-0ubuntu2.6).
# libglib2.0-dev set to manually installed.
# The following additional packages will be installed:
#   gir1.2-gsf-1 libgsf-1-114 libgsf-1-common libiconv-hook1 libxml2
# The following NEW packages will be installed:
#   gir1.2-gsf-1 libgsf-1-114 libgsf-1-common libgsf-1-dev libiconv-hook-dev
#   libiconv-hook1
# The following packages will be upgraded:
#   libxml2 libxml2-dev
# 2 upgraded, 6 newly installed, 0 to remove and 48 not upgraded.
# Need to get 1,997 kB of archives.
# After this operation, 2,774 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2-dev amd64 2.9.13+dfsg-1ubuntu0.9 [804 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2 amd64 2.9.13+dfsg-1ubuntu0.9 [764 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgsf-1-common all 1.14.47-1ubuntu0.1 [13.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgsf-1-114 amd64 1.14.47-1ubuntu0.1 [111 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gir1.2-gsf-1 amd64 1.14.47-1ubuntu0.1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgsf-1-dev amd64 1.14.47-1ubuntu0.1 [228 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libiconv-hook1 amd64 0.0.20021209-12 [59.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libiconv-hook-dev amd64 0.0.20021209-12 [3,094 B]
# Fetched 1,997 kB in 2s (1,024 kB/s)
# (Reading database ... 126374 files and directories currently installed.)
# Preparing to unpack .../0-libxml2-dev_2.9.13+dfsg-1ubuntu0.9_amd64.deb ...
# Unpacking libxml2-dev:amd64 (2.9.13+dfsg-1ubuntu0.9) over (2.9.13+dfsg-1ubuntu0.8) ...
# Preparing to unpack .../1-libxml2_2.9.13+dfsg-1ubuntu0.9_amd64.deb ...
# Unpacking libxml2:amd64 (2.9.13+dfsg-1ubuntu0.9) over (2.9.13+dfsg-1ubuntu0.8) ...
# Selecting previously unselected package libgsf-1-common.
# Preparing to unpack .../2-libgsf-1-common_1.14.47-1ubuntu0.1_all.deb ...
# Unpacking libgsf-1-common (1.14.47-1ubuntu0.1) ...
# Selecting previously unselected package libgsf-1-114:amd64.
# Preparing to unpack .../3-libgsf-1-114_1.14.47-1ubuntu0.1_amd64.deb ...
# Unpacking libgsf-1-114:amd64 (1.14.47-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-gsf-1:amd64.
# Preparing to unpack .../4-gir1.2-gsf-1_1.14.47-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-gsf-1:amd64 (1.14.47-1ubuntu0.1) ...
# Selecting previously unselected package libgsf-1-dev:amd64.
# Preparing to unpack .../5-libgsf-1-dev_1.14.47-1ubuntu0.1_amd64.deb ...
# Unpacking libgsf-1-dev:amd64 (1.14.47-1ubuntu0.1) ...
# Selecting previously unselected package libiconv-hook1.
# Preparing to unpack .../6-libiconv-hook1_0.0.20021209-12_amd64.deb ...
# Unpacking libiconv-hook1 (0.0.20021209-12) ...
# Selecting previously unselected package libiconv-hook-dev.
# Preparing to unpack .../7-libiconv-hook-dev_0.0.20021209-12_amd64.deb ...
# Unpacking libiconv-hook-dev (0.0.20021209-12) ...
# Setting up libgsf-1-common (1.14.47-1ubuntu0.1) ...
# Setting up libiconv-hook1 (0.0.20021209-12) ...
# Setting up libxml2:amd64 (2.9.13+dfsg-1ubuntu0.9) ...
# Setting up libiconv-hook-dev (0.0.20021209-12) ...
# Setting up libgsf-1-114:amd64 (1.14.47-1ubuntu0.1) ...
# Setting up libxml2-dev:amd64 (2.9.13+dfsg-1ubuntu0.9) ...
# Setting up gir1.2-gsf-1:amd64 (1.14.47-1ubuntu0.1) ...
# Setting up libgsf-1-dev:amd64 (1.14.47-1ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# Cloning into 'pyhwp'...
# remote: Enumerating objects: 12379, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 12379 (delta 38), reused 30 (delta 30), pack-reused 12333 (from 3)
# Receiving objects: 100% (12379/12379), 4.46 MiB | 16.43 MiB/s, done.
# Resolving deltas: 100% (7571/7571), done.
# python3: can't open file '/content/setup.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Load data_list.csv and find NaN values

# %%
import pandas as pd
import os

data_dir_path = '/content/drive/MyDrive/Data' # Updated path
csv_path = os.path.join(data_dir_path, 'data_list.csv')

try:
    # Load the CSV file into a pandas DataFrame
    data_list_df = pd.read_csv(csv_path)

    # Display the first few rows of the DataFrame
    print("First 5 rows of data_list.csv:")
    display(data_list_df.head())

    # Check for NaN values in each column
    print("\nChecking for NaN values:")
    nan_counts = data_list_df.isnull().sum()

    # Display the count of NaN values per column
    print("Number of NaN values per column:")
    print(nan_counts)

except FileNotFoundError:
    print(f"Error: The file {csv_path} was not found.")
except Exception as e:
    print(f"An error occurred while reading the CSV file or checking for NaN values: {e}")
# Out:
# First 5 rows of data_list.csv:
#          공고 번호  공고 차수                                       사업명        사업 금액  \
# 0  20241001798    0.0  한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화  130000000.0
# 1  20241002912    0.0        2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선  129300000.0
# 2  20240827859    0.0                EIP3.0 고압가스 안전관리 시스템 구축 용역   40000000.0
# 3  20240430918    0.0                      도시계획위원회 통합관리시스템 구축용역  150000000.0
# 4  20240430896    0.0              봉화군 재난통합관리시스템 고도화 사업(협상)(긴급)  900000000.0
#
#        발주 기관                공개 일자            입찰 참여 시작일            입찰 참여 마감일  \
# 0       한영대학  2024-10-04 13:51:23                  NaN  2024-10-15 17:00:00
# 1     한국연구재단  2024-10-04 15:01:52  2024-10-14 10:00:00  2024-10-16 14:00:00
# 2  한국생산기술연구원  2024-08-28 11:31:02  2024-08-29 09:00:00  2024-09-09 10:00:00
# 3      인천광역시  2024-04-18 16:26:32  2024-05-02 10:00:00  2024-05-09 16:00:00
# 4   경상북도 봉화군  2024-04-18 16:33:28  2024-04-26 09:00:00  2024-04-30 17:00:00
#
#                                                사업 요약 파일형식  \
# 0  - 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한...  hwp
# 1  - 사업 개요: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선\n...  hwp
# 2  - 사업 개요: EIP3.0 고압가스 안전관리 시스템 구축 용역\n- 추진배경: 안...  hwp
# 3  - 사업명: 도시계획위원회 통합관리시스템 구축 용역\n- 용역개요: 도시계획위원회와...  hwp
# 4  - 사업명: 봉화군 재난통합관리시스템 고도화 사업\n- 사업개요: 공동수급(공동이행...  hwp
#
#                                              파일명  \
# 0     한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp
# 1  한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp
# 2       한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp
# 3                 인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp
# 4      경상북도 봉화군_봉화군 재난통합관리시스템 고도화 사업(협상)(긴급).hwp
#
#                                                  텍스트
# 0      \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 ...
# 1    \r\n \r\n \r\n  \r\n제 안 요 청 서\r\n[ 2024년 대학 ...
# 2      \r\n    \r\nEIP3.0 고압가스 안전관리\r\n시스템 구축 용역\...
# 3    \r\n  \r\n \r\n도시계획위원회 통합관리시스템 구축\r\n제 안 요 청...
# 4        \r\n  \r\n \r\n제안요청서\r\n \r\n사 업 명\r\n봉화...
# Checking for NaN values:
# Number of NaN values per column:
# 공고 번호        18
# 공고 차수        18
# 사업명           0
# 사업 금액         1
# 발주 기관         0
# 공개 일자         0
# 입찰 참여 시작일    26
# 입찰 참여 마감일     8
# 사업 요약         0
# 파일형식          0
# 파일명           0
# 텍스트           0
# dtype: int64

# %% [markdown]
# # Load and Process Documents (using Langchain)

# %%
import os
import sys
import fitz  # PyMuPDF
import easyocr
import numpy as np
from PIL import Image
import subprocess
from langchain.schema import Document
# Reverting to pyhwp for HWP extraction
import pyhwp
import pandas as pd # Import pandas for data_list_df usage
import re # Import re for text cleaning


def find_executable(executable_name):
    """Finds the full path to an executable within the environment's PATH or script directories."""
    # Check in PATH first
    for path in os.environ["PATH"].split(os.pathsep):
        exe_path = os.path.join(path, executable_name)
        if os.path.isfile(exe_path) and os.access(exe_path, os.X_OK):
            return exe_path

    # Check in common script directories relative to sys.executable
    script_dirs = [
        os.path.join(os.path.dirname(sys.executable), 'bin'), # Linux/macOS
        os.path.join(os.path.dirname(sys.executable), 'Scripts') # Windows
    ]
    for script_dir in script_dirs:
        exe_path = os.path.join(script_dir, executable_name)
        if os.path.isfile(exe_path) and os.access(exe_path, os.X_OK):
            return exe_path

    return None

def clean_text(text):
    """
    Cleans extracted text by removing excessive whitespace and potentially noise characters,
    including single quotes and dots within text, and specific long dot sequences.
    """
    # Remove excessive whitespace (spaces, tabs, newlines)
    text = re.sub(r'\s+', ' ', text).strip()

    # Remove potential noise characters (e.g., single dots that are not part of ellipses or punctuation)
    # This is a basic approach; more sophisticated methods might be needed depending on the noise.
    text = re.sub(r'(?<!\.)\.(?!\.)', '', text) # Remove single dots not part of an ellipsis - This might be too aggressive
    text = text.replace('·', '') # Remove specific dot character often seen in HWP conversions

    # Remove single quotes
    text = text.replace("'", "")

    # Remove dots that are not preceded or followed by a space or are not part of a number (heuristic)
    # This is a more aggressive removal and might remove some valid dots in abbreviations etc.
    # Consider refining this regex based on specific noise patterns observed.
    text = re.sub(r'(?<!\s)\.(?!\s)', '', text) # Removing this as it might be too aggressive
    text = re.sub(r'(?<!\d)\.(?!\d)', '', text) # Removing this as it might be too aggressive

    # Remove occurrences of "<표>" and "<그림>" tags
    text = text.replace("<표>", "").replace("<그림>", "")


    # Add more specific cleaning for long sequences of dots or similar noise
    # This regex targets sequences of 2 or more non-alphanumeric characters (including dots, dashes, etc.)
    # You might need to adjust this regex based on the specific noise patterns you observe
    text = re.sub(r'[^a-zA-Z0-9\s]{2,}', '', text)

    # More aggressive removal of multiple dots or similar characters
    text = re.sub(r'\.{2,}', '', text) # Remove sequences of 2 or more dots
    text = re.sub(r'[-]{2,}', '', text) # Remove sequences of 2 or more dashes
    text = re.sub(r'[·]{2,}', '', text) # Remove sequences of 2 or more middle dots


    return text


# Define HWP extraction function using pyhwp (basic text extraction)
def extract_text_from_hwp(hwp_path):
    """
    Extracts text from an HWP file using pyhwp's basic text extraction.
    Tries hwp5txt command-line tool first as it's generally more reliable.

    Args:
        hwp_path (str): The path to the HWP file.

    Returns:
        str: The extracted text from the HWP.
    """
    text = ""
    hwp5txt_path = find_executable('hwp5txt')

    if hwp5txt_path:
        try:
            # Use hwp5txt command-line tool via subprocess
            result = subprocess.run([hwp5txt_path, hwp_path], capture_output=True, text=True, encoding='utf-8')
            if result.returncode == 0:
                text = result.stdout
            else:
                print(f"Warning: hwp5txt failed for {hwp_path}: {result.stderr}")
                text = "" # Fallback to empty if hwp5txt fails
        except Exception as e:
            print(f"Warning: Error running hwp5txt for {hwp_path}: {e}")
            text = "" # Fallback to empty if hwp5txt throws exception
    else:
        print("Warning: hwp5txt command not found. HWP extraction might not work as expected.")
        text = "" # Fallback to empty if hwp5txt is not found

    return clean_text(text) # Apply cleaning


# Define function for PDF text extraction using easyOCR
def extract_text_from_pdf_easyocr(pdf_path):
    """
    Extracts text from a PDF file using easyOCR.

    Args:
        pdf_path (str): The path to the PDF file.

    Returns:
        str: The extracted text from the PDF.
    """
    # Initialize easyocr reader for Korean and English (adjust languages as needed)
    reader = easyocr.Reader(['ko', 'en'])
    text = ""
    try:
        pdf_document = fitz.open(pdf_path)
        for page_num in range(pdf_document.page_count):
            page = pdf_document.load_page(page_num)

            # Render page to an image (as a numpy array) for easyOCR
            pixmap = page.get_pixmap()
            img = Image.frombytes("RGB", [pixmap.width, pixmap.height], pixmap.samples)
            img_np = np.array(img)

            # Use easyOCR to read text from the image
            result = reader.readtext(img_np, detail=0) # detail=0 returns only the text
            text += " ".join(result) + "\n" # Join lines with a space and add newline between pages

        pdf_document.close()
    except Exception as e:
        print(f"Error processing PDF {pdf_path} with easyOCR: {e}")
        text = "" # Return empty string in case of processing error

    return clean_text(text) # Apply cleaning


data_dir = '/content/drive/MyDrive/Data/files' # Updated path
csv_path = '/content/drive/MyDrive/Data/data_list.csv' # Path to data_list.csv

try:
    # Load data_list.csv into a pandas DataFrame
    data_list_df = pd.read_csv(csv_path)
except FileNotFoundError:
    print(f"Error: data_list.csv not found at {csv_path}")
    data_list_df = pd.DataFrame() # Create an empty DataFrame if file not found
except Exception as e:
    print(f"An error occurred while loading data_list.csv: {e}")
    data_list_df = pd.DataFrame() # Create an empty DataFrame on error


processed_documents = []

# Specify the files to process - based on previous examples and user request for top 4 HWP and top 1 PDF
# This assumes the order in data_list_df reflects the "top" files the user wants to process.
if not data_list_df.empty:
    hwp_files_to_process = data_list_df[data_list_df['파일형식'] == 'hwp']['파일명'].tolist()[:4]
    pdf_files_to_process = data_list_df[data_list_df['파일형식'] == 'pdf']['파일명'].tolist()[:1]
    files_to_process = hwp_files_to_process + pdf_files_to_process
else:
    files_to_process = []
    print("Cannot determine files to process as data_list.csv was not loaded.")


print(f"Attempting to process specified files from directory: {data_dir}")
print(f"Files selected for processing: {files_to_process}")

if not os.path.isdir(data_dir):
    print(f"Error: Directory not found at {data_dir}")
else:
    for filename in files_to_process:
        file_path = os.path.join(data_dir, filename)
        if os.path.isfile(file_path):
            # Get metadata for the current file
            file_metadata = data_list_df[data_list_df['파일명'] == filename].iloc[0].to_dict() if filename in data_list_df['파일명'].values else {}

            if filename.lower().endswith('.pdf'):
                try:
                    text = extract_text_from_pdf_easyocr(file_path) # Use easyOCR function
                    if text:
                         # Add metadata to the Document object
                        processed_documents.append(Document(page_content=text, metadata={"source": file_path, **file_metadata}))
                        print(f"Processed PDF: {filename}")
                except Exception as e:
                    print(f"Failed to process PDF {filename} with easyOCR: {e}")
            elif filename.lower().endswith('.hwp'):
                try:
                    text = extract_text_from_hwp(file_path) # Use pyhwp function (via hwp5txt)
                    if text:
                         # Add metadata to the Document object
                        processed_documents.append(Document(page_content=text, metadata={"source": file_path, **file_metadata}))
                        print(f"Processed HWP: {filename}")
                except Exception as e:
                    print(f"Failed to process HWP {filename} with pyhwp (hwp5txt): {e}")
            else:
                print(f"Skipping unsupported file type: {filename}")
        else:
            print(f"Warning: Specified file not found: {filename}")


print("\nDocument processing complete.")
print(f"Total documents processed: {len(processed_documents)}")

# Display one HWP and one PDF example with metadata if available
print("\nExamples of processed documents with metadata:")
hwp_example = next((doc for doc in processed_documents if doc.metadata.get('파일형식') == 'hwp'), None)
pdf_example = next((doc for doc in processed_documents if doc.metadata.get('파일형식') == 'pdf'), None)

if hwp_example:
    print("--- HWP Document Example ---")
    print(f"Content snippet: {hwp_example.page_content[:500]}...")
    print(f"Metadata: {hwp_example.metadata}")
else:
    print("No HWP documents were successfully processed with metadata.")

if pdf_example:
    print("\n--- PDF Document Example ---")
    print(f"Content snippet: {pdf_example.page_content[:500]}...")
    print(f"Metadata: {pdf_example.metadata}")
else:
    print("\nNo PDF documents were successfully processed with metadata.")
# Out:
# Attempting to process specified files from directory: /content/drive/MyDrive/Data/files
# Files selected for processing: ['한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp', '한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp', '인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp', '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf']
# Processed HWP: 한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp
# Processed HWP: 한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp
# Processed HWP: 한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp
# Processed HWP: 인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp
# Processed PDF: 고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf
#
# Document processing complete.
# Total documents processed: 5
#
# Examples of processed documents with metadata:
# --- HWP Document Example ---
# Content snippet:  2024 10      □ 사 업 명 :      -    □  : 130,000,000원  내 (VAT  □  :  3  1  *  및        수  □  :                  및      및          및        및      ◦    및     ◦          ◦            ◦    및         ◦          /  /  /   ◦      및     함 ◦       및     ❍  :  3  1   ※   와     수   □     ◦     -           및  ◦     및        및    -  및     수   -    및     수   ◦   -         □    ◦ 기      WEB        ◦          □    ◦        DBMS(Oracle, MS SQL Server  수   함 ◦        및   ◦  IT      ◦   및        ◦           ◦      ...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
#
# --- PDF Document Example ---
# Content snippet:  ROa UIVER SITY 제 안 요 청 서        2024 7 07 aE  KOREA UNIVERSITY 본            ROa UIVER SITY 목 차  1   2   3   :   I  및  1    2    및  I   1   2   3   IV   1   2   V     230   2     230 3    233 4   236 5    236 VL    242   242  ROa Mtfr cT 2    242 3   및  242 248-297  KORKA UVER SITY   1          나    24  다  :   12 라  : 11,270,000,000원 (VAT  3년   2024 약 3096  2025 약 4096  2026 약 3096  마  및         바 본  3        3    2   및  가              및         나   및                         다        간   및  화   ...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '공고 번호': nan, '공고 차수': nan, '사업명': '차세대 포털·학사 정보시스템 구축사업 ', '사업 금액': 11270000000.0, '발주 기관': '고려대학교', '공개 일자': '2024-07-01 00:00:00', '입찰 참여 시작일': '2024-07-05 11:00:00', '입찰 참여 마감일': '2024-08-12 11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}

# %%
# Re-run Embedding Generation and Vector DB (FAISS) Creation
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None


if OPENAI_API_KEY and semantic_chunked_documents:
    embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key=OPENAI_API_KEY)
    vectorstore = FAISS.from_documents(semantic_chunked_documents, embeddings)

    print("FAISS vector store created with embeddings from semantic chunks.")
    print(f"Number of documents in vector store: {vectorstore.index.ntotal}")

else:
    print("Skipping vector store creation due to missing API key or no semantic chunks.")
    vectorstore = None
# Out:
# FAISS vector store created with embeddings from semantic chunks.
# Number of documents in vector store: 303

# %%
# Re-run Advanced Retrieval (using Langchain)
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import DocumentCompressorPipeline
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_transformers import EmbeddingsRedundantFilter
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers import MultiQueryRetriever
from langchain.prompts import PromptTemplate
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None

if OPENAI_API_KEY and vectorstore:
    llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY, temperature=0.3, max_tokens=1500, top_p=0.8)

    template = """다음 문서를 사용하여 질문에 답하세요.
    답변은 가능한 한 정확하고 간결하게 작성하세요.
    제공된 문서에 없는 내용은 언급하지 마세요.
    문서:
    {context}

    질문: {question}

    답변:"""
    QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

    base_retriever = vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={"k": 10, "fetch_k": 20}
    )

    multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever=base_retriever,
        llm=llm
    )

    final_retriever = multiquery_retriever

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=final_retriever,
        return_source_documents=True,
        chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
    )

    print("Advanced RetrievalQA chain created with Multi-Query, MMR, and refined generation parameters/prompt.")

else:
    print("Skipping Advanced RAG chain creation due to missing API key, vector store, or no semantic chunks.")
    qa_chain = None
# Out:
# Advanced RetrievalQA chain created with Multi-Query, MMR, and refined generation parameters/prompt.

# %%
import time

def time_rag_query(qa_chain, query):
    """
    Times the execution of a RAG query.

    Args:
        qa_chain: The RAG chain object.
        query (str): The query string.

    Returns:
        tuple: A tuple containing the response dictionary and the execution time in seconds.
    """
    start_time = time.time()
    response = qa_chain.invoke({"query": query})
    end_time = time.time()
    execution_time = end_time - start_time
    return response, execution_time

# %%
# Re-run Example Query 1
if qa_chain and processed_documents:
    hwp1_doc = next((doc for doc in processed_documents if '한영대학' in doc.metadata.get('파일명', '')), None)
    if hwp1_doc:
        query = "한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 한영대학 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?
#
# Generated Response:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 다음과 같습니다:
#
# 1. **교육 환경의 급격한 변화**: 학생 수 감소, 코로나19 팬데믹으로 인한 교육 환경 변화, 인공지능의 활용 등으로 대학이 급격한 사회-기술 변화에 직면하고 있습니다.
#
# 2. **분산된 시스템 및 데이터의 통합 필요**: 정보화 요구가 증가하고 있으나, 현재 노후화된 학사 시스템으로 인해 업무가 분산되어 있어 시스템 통합에 대한 필요성이 커지고 있습니다.
#
# 3. **데이터 기반 대학 경영 지원 개선**: 분절된 정보 시스템 간의 정보 연계 미비 및 정보화 표준 부재로 인해 경영 현황 파악 및 의사결정 시 한계가 발생하고 있습니다.
#
# 4. **사용자 정보 서비스 접근성 개선**: 교내 구성원의 정보 접근 지원을 위한 포털 서비스가 제공되고 있으나, 정보 접근성 및 유용성에 대한 개선 요구가 상당합니다.
#
# 5. **대학 경쟁력 강화 및 전략 목표 달성 지원**: 노후화된 시스템의 차세대 구축을 통해 정보 서비스의 품질을 강화하고 대학 교육 시스템의 경쟁력을 확보하고자 합니다.
#
# Query Time: 9.74 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 2024 10      □ 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 □ 사업예산 : 130,000,000원 범위 내 (VAT 포함) □ 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 □ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)  학사제도제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 또는 해지하여도 감수하겠으며 손해배상 청구 등 일체의 민․형사상 이의를 제기하지 않겠습니다 4 회사 임․직원이 관계 교직원에게 금품, 향응 등 부당한 이익을 제공하거나 담합 등 불공정 행위를 하지 않도록 하는회사윤리강령과 내부비리 제보자에 대해서도 일체의 불이익처분을 하지 않는 사규를 제정토록 노력하겠습니다 위 청렴계약 서약은 상호 신뢰를 바탕으로 한 약속으로서 반드시 지킬 것이며, 낙찰자로 결정될 시 본 서약 내용을 그대로 계약특수조건으로 계약하여 이행하고, 입찰참가자격 제한, 계약해지 등 한영대학교의 조치와 관련하여 당사가 한영...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 기능 구런 #로보자시더이터 고려대학교 ROa UIVER SITY 첫봇 헌 햇봇 고도화 필요 0 i차 첫봇 사업들 통해 도출린 사용자 요구 반영 필요 교원 직원 세중캠퍼스 학생까지 대상블 확대한 햇봇 시스템 구축 필요 교수 사용자의 교육 연구 관련 다양한 문의에 대한 용답 규정과 연계하여 사용자의 문의 나용에 대한 용답 및 근거가 되는 관련 규정 자규 문서 등음 같이 제공찰 수 윗도록 구축 1차 햇봇 사업 범위 (상세 내용은 사업 착수 후 공유) 첫못시스템 구축(질의응답 GPT 기반 첫봇 구현) 질의용답 기반 GPT기반 규정학습 햇봇...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 명기하여야 함 - 단, 상용S/W, 패키지 등의 서비스 지원인력, 외부 자문인력 등 통상적인 개발인력이 아닌 경우는 제안서에 명기하지 말 것(핵심인력에서 제외)  □ 일반사항 ○ 본 제안서는 「한영대학교 특성화 막춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화」사업에 한정하여 적용 ○ 제안사는 한영대학교의 트랙운영 학사정보시스템을 충분히 이해하고, 제안요청 사항을 기본적으로 반영하여 과업내용을 포함하여야 함 ○ 제안사는 본 제안요청서에 언급하지 않았으나, 본 과업수행 향상에 도움이 되는 사항이 있을 경우 이를 추가로 제시할 수...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 대한 통계현황 조회 및 출력 기능 구현 - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 ◦ 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 □ 학사 정보시스템 고도화 ◦ 기 구축된 “학사운영시스템”에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 ◦ 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 □ 정보기술 활용 전략 ◦ 향후 우리대학 학사정보시스템의 환경 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 학적 통합관리체계 수립 학적번동 유관부서 점보 연계 업무 처리 처계 구축 라사제도 변화 대용 한계 광여모집 신움합대학 연계 마이크로디그리 등 새로문 학사제도든 원활하게 문영할 수 및도록 학사점보시스템 개선 필요 광역 모집 문명 지원 타 대략과 연계한 빨림전공 운영 지원 마이크로디그리 이수 제공 및 인종 지원 장학코드 정비 및 잠학업무 점보화 수준 항상 필요 지급조건 변경 등예 따라 대년 동말한 장학금 코드 새로 생성 점보공유 부족으로 잠학금 신청문 눕치는 검무 발생 연속장학생 잠학기준 변경 관리 미뉴으로 연속장학 자격 유지 확인 수...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024 7 07 aE 고려대학교 KOREA UNIVERSITY 본 자고; 게민내공의 신편움 취한 "포자고로 부거으로 '년부지 사용타; 형위: 구립- 고려대학교 ROa UIVER SITY 목 차 사업개요 1 사업 개요 2 사업 배경 3 사업 범위 : 기대 증과 I 현황 및 문제점 1 일반 된참  2 점수화 된참 문제점 및 개선방방 I 사업 추진방안 1 추진 욕표 2 추진 밀정 3 추진 체계 IV 제안요청 내용 1 제안요섬 개요 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 데미터 추출 교원 직원 세중검퍼스 학생 으로 서비스 대상 확다 1차 사업 결과 사용자 피드백 반명 고도화 GFT 적용 모델의 고도과 전체 기능 컴문 서비스 구축 경'늄계시스템과 원데이터 주촌 적재밤식 데이터마트 생성방식 밑원퇴 Fythan으로 구현간 모델의 연속실뱀 및 병렬실뱀 야키석처 고도 시신버 고도화 A신버 포라서비스 셋봇서비스든 농합하여 추전-눕계 데미터 기능 저설계 (전체 고려대학교 ROa Mtfr cT 나 개인정보 영향평가 시스템의 구속 문영 변경 등이 개인점보어 미치논 영향울 사전에 조사 예측 검토하여 개선밤안물 도출하...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 이용 내역(동의 필수) 수집 이용 개인정보 항목 수집 이용 목적 보유 맛 이용 기간 고리대학교 '차세대 수집-이용 동의밀로부터 보유목적 달성 섬명; 소속; 직위 학력 꾸털 확사 시스템 단 사업 이력관리듬 위하여 사업 증료 후 연령 경력 구속 사업' 5년 간 보관 입찰참가신점 뭐 동의 안내어 기부할 고리가 있습니다 그러나 동의 거부할 경무 사업 참여에 제 한이 있든 수 엎습니다 위와 같은 개인점수의 수집 이용어 동의하십니까? 동의람 동의하지 암음 (민서명) 고러대학교 총장 귀하 2U 고려대학교 ROa Mtfr cT 서식 17 ] 정보...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# (분산된 시스템 및 데미터의 동합) 급변하는 교육환경 속어서 정보화 요구사함온 증가하나 우리 대학온 노후화된 학사 시스템올 기반으로 업무마다 분산된 보화름 추진하고 있어 시스템 동합에 대한 요구가 증가함 다 (데이터 기반 대학경염 지원 개선) 분절된 점부시스템 간 정보언계 미름늄 및 정보 화 표준 부재로 인하여 경영현환파악 및 의사결정 시 한계가 발생함 라 (사용자 정보서비스 접근성 개선) 또한 교내 구성원의 정보담색 지원율 위한 포 털 서비스가 제공되고 있으나 포달의 정보 접근성 및 유용성데 다한 개선 요구 가 상당함 마 (대학 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 숙독하신 주 서명하기 바합니다: 나는 고려대학교로부터 취,관 모든 정보름 관련 업무어 한해 이용관 것이며 개인적으로 사 용하거나 빌도 보곤하지 아니라다 나는 고려대학교로부터 제공받문 각종 정보자산은 무단 변조 복사 취손 눈실 슬으로부터 안전하게 곤리하켓다 나는 지원업무와 무관관 경무상대가 누구이건 간어 밑 필요가 업는 자에게 업무 중 취늑한 소유청보분 누설하지 사컷다 뜨히 암은 정보나 시설에 접근하지 많으다, 고려다학교 곤련 업무록 수행 # 때만 허가받온 처리시설(정보 시스템 정보 데이터; 전산자원 윗음 이용하다 나는 업무지원은 흰...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 영문화 된 규정점보 체계 구축 필요 외국인 구성쩐이 조회[활용할 수 및도록 염문버전 규정 서비스 제공 필요 한재 도입된 규정관리시스템의 메뉴 규정 사용자화면블 모두 영문으로 제공 모털 검색 햇봇 전자결재 시스템과 면계 헌 도입된 규정관리시스템의 사용자 개선 요구가 있든 경무 반영 고려대학교 ROa Mtfr cT 사  경영통계시스템 데이터 취합 / 분석 전반의 수작업 개선 필요 0 기존 경영통계시스템의 데이터 수집 저장 및 분석관리제계 미비로 시스템 활용도 저하 각종 통계자규의 공문저리들 통한 수기 요성 취합으로 업무 비표분 발생 스...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 참여관 수 빗는 사업금말의 하한(과학기운정보농신부고 소프트웨어 품질인중의 세부기준 및 절차(과학기순정보봉신부고시) 소프트데어 사업 하도급계약의 적정성 판단기준(과-학기술정보 농신부고시) 용역계약일반조건(기회재정부계약예규) 험상에 의찬 계약체걷기준(기회재정부 계약예규) 하도급거래 긍정화지짐(공 정거래 뒤원 점보 오조치에 곤란 지침(과-학기술정보늄신부고시) 개인점보의 기술적-관리적 보소조치 기준(방송속신위원 리고시) 스6 회대7) 고려대학교 ROa UIVER SITY 서비스 접근 및 전달 분야 적용계회 / 겉과 부분적용/미 구 눈 해당...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 구성원 정보름 등록관 수 있도록 구런 설명 내용 자치단처밭 구성원 정보는 중담 자치단처의 경무 학생지린담에서 {록하다 단과대학 소속 자치단체의 경무 각 단과대학{학부 , 과예서 틈록하도록 합 구성원 {록은 위란 학번 입리 시 학상의 학직 상E {재적 상E , 휴학 여부 틈와 교차 제크가 되어이 합 학번은 입리하면 외 구성원의 학직사람 이름 소속 연락처 온 자동으로 학적에서 연제되다 자치단체에서의 직색온 입력해야 합 자치단처 회원정보는 면도빌로 조회관 있어야 탑 자치단체 찬습관리 하성 자치단처빌 참동 너먹든 름록람 137- 고려대학교...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ROa UIVER SITY 서식 13 ] 하도급 적정성 판단 자기평가표 1 계약 내용 수급인 관련 사람 하수급인 관련 사람 사 업 명 하업룹 수 급 인 (전화) 하수급인 (전화) 하도금여 정액 하동학계약 계약기간 화 도 학장류복 화장다복 국갈증작록관월 하당국둘 X 부분하도굽술 (다) (하도급계막금먹(p) / 하도급예점액(A)) X 100 2 자기평가결과 판 단 함 국 사유 {뀌T중국이월 자경어 입찰참가제한 중인지 여부) 가 사업수행실적 사연학금일이 나 고용안점 및 적법근로 소 계 가 하도급대금 지급방식의 적정심 '악방속 하도급 금액...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 올#플렉정e다 &구하E 둘시] 숙가차 지너겨움 겨네; ; 여겨고 겨억까다 7 대적 -CeC 마어 설기다 국개사-기 기여 역#락 다구# l월다 습청하#f 나 고러대학교 비전 소 ; 그나오 고려대학교 ROa Mtfr cT 창의석 미러 연자j 엉성하고 인#어 공안하논 더욱 GLoUAL Toa Dbi iUX AIrE 그 플라다논 개 본O: {권 슈고스T캠베 하크 훨 미어 바도 올모가 부 Narse 1이터; 대하다:: 다 기관 인력 현환 (대규 흉데이지 기준) 교직원 현환 구분 전임교원 비전임교원 직원 서물캠퍼스 525명 2,883명 1,1...

# %%
# Re-run Example Query 2
if qa_chain and processed_documents:
    hwp2_doc = next((doc for doc in processed_documents if '한국연구재단' in doc.metadata.get('파일명', '')), None)
    if hwp2_doc:
        query = "한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 한국연구재단 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 무엇인가요?
#
# Generated Response:
# 한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 UICC 시스템 기능개선을 통해 이용 편의성을 개선하는 것입니다.
#
# Query Time: 5.81 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 2024 10       1 사업명: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선 2 추진배경 및 필요성 □ 한국연구재단법 제5조, 산업교육진흥 및 산학연협력촉진에 관한 법률 제39조의2 및 제43조에 따라 실시하는 대학 산학협력활동 실태조사를 안정적으로 운영 필요 □ 항목 지침 변경사항 등 변화에 신속하고 정확하게 대응하며, 기능개선에 대한 사용자 요구를 반영하여 사용자 편의성 강화 필요 □ UICC의 효율적인 관리와 운영을 위한 지원 체계 및 각종 기관 요구사항에 대응 필요 3 주관기관 : 한국연구재단 4 사...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 반찬계좌 보이거 탑 교녀고외장학생관리어서 결의서작성 연결 처리루 전자걸재 기능 필요 수업표 지급방식 잠학금은 대출계좌 채번R점 승인 구 전자결재 진행 다량의 환수 더이터롬 일관 전표처리관 수 있거 설계 필요 중복지원 심사(지급) 정보 파일 다문로드 대출처번계좌 정보파일 업로드 등록 반환 결의시 잠학금이 있는 경무 장학금 순위에 따라 잠학금계 좌로 이제하는 내용 설계 필요 (SFR-학사-032 등록금수님관리) 등록: 등록금 반퀴결의 잠학: 장학금 지출결의 별도로 하지만 티부서 담당자들에서 통합 메뉴로 보이도록 설계 필요 (각 부서 담...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 시스템 <업무 메뉴 및 전자결재 운영 현황 (20221231기준)>  * 연구관리, 기업지원, 재무, 인사, 급여, 구매조달, 지재권 등 19개 업무시스템 운영 中 ○ 연계시스템 (20231231 기준)  ○ 장비 현황 - 운용 중인 전산장비는 총 1,205종이며, 840종을 서비스수준협약(SLA)을 통하여 안정적인 서비스와 신속한 장애 복구 체계 구축  3 사업 추진방안 가 추진목표 ㅇ 원내에서 관리하는 화학물질 운영현황의 통계 정보 공유 ㅇ 고압가스 화학물질의 정보와 판매허가 업체를 관리 ㅇ 고압가스 화학물질의 구매부터 안전성 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 기능 구런 #로보자시더이터 고려대학교 ROa UIVER SITY 첫봇 헌 햇봇 고도화 필요 0 i차 첫봇 사업들 통해 도출린 사용자 요구 반영 필요 교원 직원 세중캠퍼스 학생까지 대상블 확대한 햇봇 시스템 구축 필요 교수 사용자의 교육 연구 관련 다양한 문의에 대한 용답 규정과 연계하여 사용자의 문의 나용에 대한 용답 및 근거가 되는 관련 규정 자규 문서 등음 같이 제공찰 수 윗도록 구축 1차 햇봇 사업 범위 (상세 내용은 사업 착수 후 공유) 첫못시스템 구축(질의응답 GPT 기반 첫봇 구현) 질의용답 기반 GPT기반 규정학습 햇봇...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 기타장학 SFR-학사-040 자치단제관리 SFR-학사-041 통사관리 SFR-학사-042 학생 삼벌(수상) 관리 SFR-학사-043 지도교수관리 SFR-학사-044 취업통계 SFR-학사-045 병무기초자 규관리 SFR-학사-046 병무 예비군관리 SFR-학사-047 민밥위관리 SFR-학사-048 기타 학사 언계모든 관리 SFR-부속-001 진국 업무관리 보건 공제 SFR-부속-002 의국 공제관리 고려대학교 ROa Mtfr cT 구분 요구사항 ID 요구사항 명칭 SFR-부속-003 회계업무관리 SFR-부속-이C4 코드관리 SFR-부...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 환경 설정 틈 관련 )밭 표준 및 가이드에 반명하여다 하머 개발프레임워국예 반험하기 어려운 녹립다 R소밑 경우; 빌도 추가 문서로 관리하여이 공놈 모분의 개발 및 직용 설계 단계 이전어 업무 거밭 및 시스템 구성은 위란 공통 기늄모늘) 음 도준하여 제시하여이 하다 개밭 단계 이전에 재사용 공중요 소(공놈 모물 및 컴포년트]큼 개발하여 잘용 가이드와 함께 제공하여야 합 개발험 표준 기속이 아년 경무 적용 불가 사유름 입중하고 추관기관의 사전 승인은 투안 후 적용 활 수 있음 산물정보 아키Y처 정의서 R구사함 문류 표준 R구사방 R구사...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# [상문 학교와 협의하여 쇠품 결정탑 일반뱀정시스템 견계 서비스 제공 밤식 현 포털 시스템의 인사 급어 틈 뱀정 모든문 일반행정시스템과 비즈니스 로직문 공유하므로 비즈니스 로직문 재사용하는 밤안문 제시 및 적용하여이 밥 산출정보 프로그램 복록; 프로그럼명시서 회면정의서 사용자매뉴벌 틈 요구사항 분류 기능 R구사람 요구사항 번호 SFR-구닐-008 요구사항 명칭 다국어 서비스 정의 다국어 서비스 제공 대상 방식 정의 다국어 서비스 제공 [상 향추 다국어 서비스가 가능하도록 환경문 구추하고 년 사법어 서는 덩어 서비스름 제공탑 도둑어서 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# ROa UIVER SITY 서식 13 ] 하도급 적정성 판단 자기평가표 1 계약 내용 수급인 관련 사람 하수급인 관련 사람 사 업 명 하업룹 수 급 인 (전화) 하수급인 (전화) 하도금여 정액 하동학계약 계약기간 화 도 학장류복 화장다복 국갈증작록관월 하당국둘 X 부분하도굽술 (다) (하도급계막금먹(p) / 하도급예점액(A)) X 100 2 자기평가결과 판 단 함 국 사유 {뀌T중국이월 자경어 입찰참가제한 중인지 여부) 가 사업수행실적 사연학금일이 나 고용안점 및 적법근로 소 계 가 하도급대금 지급방식의 적정심 '악방속 하도급 금액...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 녀떡 만녀 성적표훈력 업무 용도어 따른 각종 성적표름 춥력하는 기능 보관국 확인봉 틈 전처 학생의 성적표분 관리판 수 덧도록 합 열람봉 발씀용 틈 학생 개별로 섬적표늘 관리팔 수 맛도록 참 성적분포현함관리 학고-발써점 부어현화 과보발등급분포도 순위일감표 교수감좌분되점현화 틈 산출정보 프로그램 복록 프로그럼명시서 퇴면점의서 사남자다 뉴얼 틈 요구사항 분류 기능 요구사방 요구사항 번호 SFR 학사 JI8 요구사항 명칭 슬업기준관리 정의 졸업 졸업기주관리 기능 정의 0 음업사정학 사일정관리 은업사정 일정어 따른 프로그램 제어튼 복직으로 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 프로세스 재설계 그 외 학교 및 사업자가 제안하는 프로세스 개선 필P 업무 업무 프로서스 재설계의 성공직민 수함과 차세다 시스템 가발의 만정직민 반영블 위해 프로세스 설계 담당 인격문 개발 인력과는 붙도로 투입하는 방만은 제시해이 합 산물정보 프로세스 재선계 보고서 고려대학교 ROa UIVER SITY 그 기능 요구사항 공통 요구사항 분류 기능 요구사방 요구사항 번호 SFR-공놈-001 요구사항 명칭 기초정보관리 정의 공농 기준정 토관리 기능 정의 공습고드관리 대략 시스템 전반어서 사분되는 공습의 코드 등록/ 작제변경 관리 기능 구...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 고려하여 시스템 설계를 하여야 한다 ◦ 제안되는 모든 S/W는 기존 환경을 고려하여 개발 되어야하며, 기능상의 제한 등으로 인하여 불가피한 경우에는 그 사유 및 대안을 제시하여야 한다 ◦ Reporting 전용 툴을 사용하여 출력물을 설계하되, 기능면에서 제한사항이 있으면 이에 대한 사유를 명시하고 대안을 제시하여야 한다 ◦ 통계보고서의 정형화 및 대학 전체가 공통된 내용의 업무지표 사용과 조회자료의 편리한 Export 지원(Excel 등)이 되어야 한다 ◦ 구성원별(교수/직원/조교 등), 소속부서와 업무분장에 따라 체계적인 계정 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 사함 다중전공 신청자 선밭 기준(학기 학점, 평점명균 틈} 정보름 관리하는 기능 상세 세부 구현 설명 내용 제2전 공(이중전공, 움합전공 학생실계전공} 복수전공 틈 다중전공길 사정 기준 정보 관리 다전공문가학과관리 다운전공은 신청관 수 없는 학과 부견전공) 정보분 곤리하는 기능 제2전공(이중전공 움합전공 학생설계전공) 복수전공 틈 다중전공빌로 다전공년가학과 관리 다전공처리(신청 승인 주소} 학생이 제2전금(이중전공, 눈합전공, 탁생선계전공) 복수전공 틈 다툼전공문 신청 { 신청 취소 포기신청하고 학과부} 대학, 다중전공 업무부서 담...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 지원 세부 함극별 성적 관리 체계 구런 필요 교수자가 최종 평가 등급만 입력하는 방식으로 성적이 관리팀 섬적평가 세부함극별 결과 점수 제공 붙가 강의계 화서 껍가히9 굽간고사 기" 교사 기피늄 주시고사 배y이터 {승진관리 기능 미념 '콤출표월 13 소과 아의어 입불금자 오@대로뒷-말 _ 점수 피비 모가 덕V 터 슈 서왼 수 ULa 하룻로하H 업무 학전 성적 평기정숙말 팀퓨갈능 콤골지피_훌-분 공유 표_요관 고려대학교 ROa UIVER SITY 섬적평가 함국별 점수 관리 체계 구신 출결정보 관리 본교 학생 학점고규 성적처리블 위히 정...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 다문로드 다문로드 정보분 대학알리미 사이트에 업로드}학부 총관담당자)- > 최종 편제조사 곁과 저장(학부 총곧담당자) 전년도 자료복사 후 변경사람 수정 및 환정 기능 권반에 따른 차듭 고려대학교 ROa UIVER SITY 기능 제공 {학과부]빌 담당자) 곤련자료 업로드 기능 제공 수정데이터 교민관 수 및는 기능 제금 편제단뒤조사기간 학사력에 마른 놈제 기능 재공 계약학과 문담곤리 계막학과 산학협리창동 실태조사름 지원관 수 F는 계막학과 문영현화 함복 관리 기능 재공 계약학과 설치 운령 현랑(취누학뒤 계약학과 유험, 겨일 모처학과 명...

# %%
# Re-run Example Query 3
if qa_chain and processed_documents:
    hwp3_doc = next((doc for doc in processed_documents if '한국생산기술연구원' in doc.metadata.get('파일명', '')), None)
    if hwp3_doc:
        query = "한국생산기술연구원의 EIP3.0 고압가스 안전관리 시스템 구축 용역의 사업 개요를 설명해 주세요."
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 한국생산기술연구원 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한국생산기술연구원의 EIP3.0 고압가스 안전관리 시스템 구축 용역의 사업 개요를 설명해 주세요.
#
# Generated Response:
# 한국생산기술연구원의 EIP3.0 고압가스 안전관리 시스템 구축 용역은 고압가스 취급 부주의로 인한 연구실 사고를 예방하고, 법적 요구사항을 준수하기 위해 체계적인 관리 시스템을 구축하는 사업입니다. 이 사업의 주요 목표는 다음과 같습니다:
#
# 1. 원내에서 관리하는 화학물질 운영현황의 통계 정보를 제공하는 시스템 구축.
# 2. 고압가스 화학물질의 정보와 판매허가 업체를 관리하는 시스템 구축.
# 3. 고압가스 화학물질의 구매부터 안전성 검토 과정을 진행하기 위한 시스템 고도화.
# 4. 연구실과 법적 준수 사항을 관리하기 위한 시스템 고도화.
# 5. 화학제품 폐기·회수를 관리하기 위한 시스템 고도화.
#
# 이 사업을 통해 연구원들의 생명과 신체를 보호하고, 연구실 내 안전사고를 예방하며, 법적 문제를 예방하고 안전 관리 수준을 법적 기준 이상으로 유지하는 것을 목표로 하고 있습니다.
#
# Query Time: 8.74 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 시스템 <업무 메뉴 및 전자결재 운영 현황 (20221231기준)>  * 연구관리, 기업지원, 재무, 인사, 급여, 구매조달, 지재권 등 19개 업무시스템 운영 中 ○ 연계시스템 (20231231 기준)  ○ 장비 현황 - 운용 중인 전산장비는 총 1,205종이며, 840종을 서비스수준협약(SLA)을 통하여 안정적인 서비스와 신속한 장애 복구 체계 구축  3 사업 추진방안 가 추진목표 ㅇ 원내에서 관리하는 화학물질 운영현황의 통계 정보 공유 ㅇ 고압가스 화학물질의 정보와 판매허가 업체를 관리 ㅇ 고압가스 화학물질의 구매부터 안전성 ...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 한다 ○ 데이터의 무결성, 일치성, 기밀성, 가용성 등을 고려하여 구축하여야 한다 ○ JAVA 기반의 정보시스템 구축 개발 시는 전자정부 표준프레임워크에 기반 한 지정된 공유서비스(공통컴포넌트)를 우선적으로 사용하여야 한다 ※ 컴포넌트에 대한 상세 기능은 egovframe포털(wwwegovframegokr) 참조 3) 정보시스템 구축 기술 요건 ○ 서비스 접근 및 전달 분야 - 정보시스템은 사용자가 다양한 브라우저 환경에서 서비스를 이용할 수 있도록 표준기술을 준수하여야 하고, 장애인·저사양 컴퓨터 사용자 등 소외계층을 고려한 설계...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 형상관리습투선 라이선스님 사랑 추가로 도입하여이 합 상세 세부 신규 서너어 DB맘로회 DB모니터림 험상관리스투선은 설치하고 정상구소은 설명 너용 교인하여이 생상관리 슬부선 오른소스gt Enns 틈물 환용만 힘상관리 직붕 및 R점사방 관리 ae 고려대학교 ROa UIVER SITY 시스템은 개발 연습하여 지원활 있어이 합 프로적트의 공플모습과 험상관리 슬투선이 묘율적으로 연습되어 바 포작업 속도에 문제가 없어이 합 신규 험상관리 시스템 도입 시 기촌 슬투선의 데이터 다이그러이선 작업이 도합되어이 합 기촌 시스템의 소스 변경녀먹 PMS...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 인터페이스를 지원하여야 한다 라 기타사항 ○ 상기 추가 제안내용 외에 이 사업에 반드시 필요하다고 판단되는 사항을 제시할 수 있다 ○ EIP 업무포털 종합정보시스템 관련 산출물 및 기타 필요 산출물을 참고할 수 있으며, 신청자에 한하여 산출물 열람 가능 ▪ 열람시기 : 제안서 공고일부터 접수마감전일까지 ▪ 열람장소 : 우리 원 디지털행정추진실 또는 지정장소 ▪ 열람산출물 : EIP 관련 주요 산출물 ▪ 열람방법 - 열람일 전일까지 사전예약한 자에 한하여 열람 - 열람자는 소속사 신분증 제시 - 열람방법은 산출물 단순열람만 가능(복사...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 전자기록-생산시스템 기록관리 기능요건 R구 공공#준 NAK 32013(v1D)) 전자기록생산시스템 기록관리 기능요건 사함 제고부 전자문서시스템 상세 세부 공공#준 NAK 32015(v1D) 전자기록생산시스템 기록관리기능요건 설명 내용 제교부 업무관리시스템 정부 및 공공기관과의 전자문서 유용모습이 적용된 시스템 구축 뵙 기단기로 전자문서 유둥지린이 가능단 시스템 구추 걷지관료문서 외부 유출 보만 방만은 고려단 시스템 구축 권단번 농합검색 기능 저공{ 처리부서 제복 기록물철명 등록-구준 등록일자 담당자 기만자 등으로 조리) 전자걷재 총...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 있는 보관함에 보관하여야 함 ❍ 사업 수행 중 반입된 장비의 반출은 금지하되, 불가피한 경우 “물품반출입대장”[재단서식]을 작성하여 관리하고 반출 시 업무자료 삭제, 반입 시 백신으로 정밀점검을 수행하여야 함 ❍ 사업 종료 시 반입된 장비를 완전삭제 프로그램을 사용하여 업무자료를 삭제한 후 “전산장비 반입ㆍ반출 확인서”[재단서식]를 J-Tops에 제출하고 승인받아야 한다 ❍ 참여인력 PC 및 휴대용 저장매체에 정보시스템 접속정보(ID, 패스워드) 저장을 금지함 ❍ 참여인력의 개인 휴대폰은 카메라 및 충전포트에 보안스티커를 부착하여야...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 운영 □ 실태조사 항목 지침 변경사항을 반영하고 시스템 기능을 개선하여 사용자 편의성 도모   1 추진목표 □ UICC 시스템 기능개선을 통해 이용 편의성 개선 □ UICC 시스템 운영 지원을 통해 안정적으로 실태조사 추진 2 추진전략 □ 능력과 경험이 풍부한 전문사업자를 주관사업자로 선정 ㅇ 시스템 구축에 대한 경험이 풍부하고 인력관리, 품질관리 및 유지관리 능력이 우수한 업체를 주관사업자로 선정하여 사업 진행 ㅇ 재단·대학과의 원활한 소통을 바탕으로 효율적 협력체계 마련 □ 정보기술 활용전략 ㅇ 한국연구재단에서 운영하는 기존 정...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# CPU머 모리 사용물 ECR-OD1 지능병 검색스구선 ECR-UD2 UI 개발 도구 ECR-0D3 테스트 지동화 도구 ECR-0D4 통합보 니터림 캠서버 b어들리키이선서버 시스템장비 ECR-UD5 DB모델림 도구 R구사함 ECR-DDG 메티데이터관리 손구선 (ECR) ECR-U7 리포팅 손T선 ECR-0D8 UMs 서비스 ECR-ODg A기 시스템 ECR-DiD DB관리 형상관리 슬구선 ECR-Dui 증명 손구선 INR-OO1 사용자 인터퍼이스 인터께이스 INR-002 시스템 언계 일반 R구사람 INR-003 시스템 점수 연계방만 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 212- 고려대학교 ROa UIVER SITY 뱀정기관 및 공공기관 정보시스템 구축 운영 지침 (챔정안전부고시) 공공데이터 관리 지침 (밤 정만전부고시) 공공기관의 더이터버이스 #준회 지침 (방정만전부고시) 한국럼 밑 곤련스 집근성 지침(KWCAG 21) 개밭 전 과정든 SW 기 발보만 시규어 코팅) 개밭 시스템든 전자정부 표준 프러임뭐크 직문 뵙음플프로그램 기발보만 가이드 201C{행정만전부) 전자정부 집서비스 취막점 더음지침 (행정만전부) 소프트웨어 기발보만 가이드밤정만전부) 콤페이지 SW밑) 개발보만 가이드{뱀정만전부) 산출정...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 국지늄계 하제대학관리시스템 국저 교육님 교환 방문학생 지원시스템 국저 교류님 현장실 습 온라민시스템 현상실습지원선터 안망학사시스템 만광학사 합성실 학성상담관리시스 템 CIMP) 학심상담센터 극지어 학원시스템 (A5P) 한국머선터 밑반방 정시스템 (GMS) sprna eyria 정보가밭번 그마 입찰시스템 spring eyria 정보가밭번 일반 구마다 범시스템 관리밥 5K미래관 공간예닥 시스템 nadejs; AricraidiiPhicre 건독밥 고려대학교 ROa Mtfr cT 공간관리시스템 (아키버스) radejs Thingwiarx ...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 2024 08   목 차  1 사업 개요 가 추진배경 및 필요성 ㅇ 안전사고 증가 - 고압가스 취급 부주의로 인한 연구실 사고가 빈번하게 발생하고 있으며, 이는 인명 피해와 연구 기기 손상을 초래함 ㅇ 법적 요구사항 - 안전 관리에 대한 법적 요구사항과 규제가 강화되고 있으며, 이를 준수하지 않을 경우 법적 책임과 벌금이 부과 ㅇ 연구 환경 보호 - 연구원들의 건강과 안전을 보호하고, 안전한 연구 환경을 제공하기 위해 체계적인 관리 시스템 구축 필요 나 사업 범위 ㅇ 원내에서 관리하는 화학물질 운영현황의 통계 정보를 제공하는 시스템...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 산촌로음 삭제 산출문 삭저 곤련 대규자 명의 화막서 제출 필요 산물정보 보안관리 계회서 보안서막서 29 고려대학교 ROa Mtfr cT 품질 요구사항(QUR) 요구사항 분류 문질 R구사방 요구사항 번호 QUR-D01 요구사항 명칭 이해 용기점 정의 이해 용이점 개념 정의 사용자가 이해{이용이 용이한 시스템 구런 프로그램의 설치 제거 이용이 봉이하여이 합 사용자 대뉴얻 또는 관리자 매뉴벌에 시스템 또는 프로그럼은 설치하거나 제거하기 위산 청보분 문서로 제공 "시스템 및 프로그램의 설치 및 제거 봉이성은 평가-하기 뒤해 매뉴얼은 바당으...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 부득이 하도급 계약이 필요한 경우 「소프트웨어사업 하도급 승인 및 관리지침」(과학기술정보통신부 고시 제2018-18호, 201838)을 준수하여야 합니다 다 사업수행자의 준수사항 1) 사업수행 중 획득한 아래 누출금지 대상정보를 사업수행기간 및 사업종료 이후에 누출 시에는「국가를 당사자로 하는 계약에 관한 법률 시행규칙」제76조 의거 부정당업자로 제재합니다  2) 사업 진행 중 취득한 관련 정보는 외부로 누설하여서는 아니 되며, 정보누설로 인한 문제발생 시 해당자는 한국생산기술연구원에서 취하는 조치에 이의를 제기할 수 없다는 비밀유...

# %%
# Re-run Example Query 4
if qa_chain and processed_documents:
    hwp4_doc = next((doc for doc in processed_documents if '인천광역시' in doc.metadata.get('파일명', '')), None)
    if hwp4_doc:
        query = "인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 인천광역시 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 무엇인가요?
#
# Generated Response:
# 인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 다음과 같습니다:
# - 용역명: 도시계획위원회 통합관리시스템 구축 용역
# - 기간: 착수일로부터 180일
# - 사업비: 금150,000,000원 (VAT 포함)
# - 계약방법: 제한경쟁입찰(협상에 의한 계약)
#
# Query Time: 6.63 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 1 과 업 명: 「도시계획위원회 통합관리시스템 구축 용역」 2 용역개요 ○ 용 역 명: 도시계획위원회 통합관리시스템 구축 용역 ○ 기 간: 착수일로부터 180일 ○ 사 업 비: 금150,000,000원 (VAT 포함) ○ 계약방법: 제한경쟁입찰(협상에 의한 계약)    3 과업배경 및 목적 ○ (수작업에 의한 업무의 복잡성) 여러 단계의 위원회 운영업무를 수작업으로 처리, 업무의 복잡성 발생 ‧ 심의자료 변경 시 자료의 재배포 등 업무의 중복성 발생 ☞ 위원회 전 과정의 지원체계 구축 필요 ○ (통합관리시스템 부재로 업무별 개별 처...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 연계복록 및 함부의 추가 변경 삭제 절차의 정의 절차분 수립하여이 합 연계 시스템 도입 시 시스템과 연제터 체계 수립 오류 데이터의 진단 및 기신 절차늘 저시하여야 탑 데이터 구조관리 방안(매뉴벌 가이드 틈) 데이터 표준 구조 면계 , 문질) 산출정보 관리 제계서 요구사항 분류 데이터 R구사람 요구사항 번호 DAF-UD5 요구사항 명칭 연계 데이터 관리체계 정의 연계 데이터 관리체계 수립 데이터 연제 관리 방만 제시 R구 내외부 제공기관 및 참옮기관 간 면계데이터의 정합성이 유지되도록 구축 사함 연계데이터어 대란 머타데이터튼 작성하...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 대한 통계현황 조회 및 출력 기능 구현 - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 ◦ 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 □ 학사 정보시스템 고도화 ◦ 기 구축된 “학사운영시스템”에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 ◦ 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 □ 정보기술 활용 전략 ◦ 향후 우리대학 학사정보시스템의 환경 ...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 여부 서면으로 제출 받음 ○ 협상에 의하여 사업자가 선정되면, 선정된 사업자는 보완요청사항과 협상에 의한 조정결과를 반영하여 계약을 체결함 5 계약체결 및 이행 ○ 협상대상자와 협상이 성립되면 특별한 사유가 없는 한 10일 이내에 계약을 체결하여야 하며, 이를 이행하지 않으면 평가위원회에서 선정된 차 순위 기관(단체)과 계약체결을 할 수 있음 ○ 협상이 성립된 이후 계약을 포기할 경우 제안서 내용에 대하여 연고권 등 일체의 권리를 주장할 수 없음 ○ 계약체결 및 이행에 관하여는 협상결과와 지방자치단체를 당사자로 하는 계약에 관한 법...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 운영 □ 실태조사 항목 지침 변경사항을 반영하고 시스템 기능을 개선하여 사용자 편의성 도모   1 추진목표 □ UICC 시스템 기능개선을 통해 이용 편의성 개선 □ UICC 시스템 운영 지원을 통해 안정적으로 실태조사 추진 2 추진전략 □ 능력과 경험이 풍부한 전문사업자를 주관사업자로 선정 ㅇ 시스템 구축에 대한 경험이 풍부하고 인력관리, 품질관리 및 유지관리 능력이 우수한 업체를 주관사업자로 선정하여 사업 진행 ㅇ 재단·대학과의 원활한 소통을 바탕으로 효율적 협력체계 마련 □ 정보기술 활용전략 ㅇ 한국연구재단에서 운영하는 기존 정...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 사함 다중전공 신청자 선밭 기준(학기 학점, 평점명균 틈} 정보름 관리하는 기능 상세 세부 구현 설명 내용 제2전 공(이중전공, 움합전공 학생실계전공} 복수전공 틈 다중전공길 사정 기준 정보 관리 다전공문가학과관리 다운전공은 신청관 수 없는 학과 부견전공) 정보분 곤리하는 기능 제2전공(이중전공 움합전공 학생설계전공) 복수전공 틈 다중전공빌로 다전공년가학과 관리 다전공처리(신청 승인 주소} 학생이 제2전금(이중전공, 눈합전공, 탁생선계전공) 복수전공 틈 다툼전공문 신청 { 신청 취소 포기신청하고 학과부} 대학, 다중전공 업무부서 담...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 기촌 보유 겁소덧)은 하이브리드 방식으로 모바일서비스 농합 , 구추 밑부 서비스 년경 (주기씌지) 하이브리드 모바밑 셈 도' 무쉬(알람) 기능 기준정보 곤리 권산관리 사용자 관리 틈 공놈 관리 학적 교과, 수업 성직 큰업 교직 등록; 장학 범무 보건 공지 국지어학원 학생 데이터 농합 학사전반 학사행정시스템 학부; 대학원 의학계밑 모두 도랍하는 학사점점 기능 농함관리 KUchivel비교과 펴량) LMS(감의지원} 도서관 기숙사 현장실습 , CassHU3(히신움합다학) 유관시스팀 면계 수강신청 시스템(모바밑 수강신청 시스템 도함) 고려...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 시스템 <업무 메뉴 및 전자결재 운영 현황 (20221231기준)>  * 연구관리, 기업지원, 재무, 인사, 급여, 구매조달, 지재권 등 19개 업무시스템 운영 中 ○ 연계시스템 (20231231 기준)  ○ 장비 현황 - 운용 중인 전산장비는 총 1,205종이며, 840종을 서비스수준협약(SLA)을 통하여 안정적인 서비스와 신속한 장애 복구 체계 구축  3 사업 추진방안 가 추진목표 ㅇ 원내에서 관리하는 화학물질 운영현황의 통계 정보 공유 ㅇ 고압가스 화학물질의 정보와 판매허가 업체를 관리 ㅇ 고압가스 화학물질의 구매부터 안전성 ...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 산출 자료(개최개요, 상정자료, 회의록 및 개최 결과, 보도자료 등) 및 관련 자료에 대한 관리 기능 - 안건별 이력관리 및 산출 자료 활용(자료 검색, 통계 분석, 보고서 작성 등) 기능 - 위원회 확대에 대비한 메인화면 구성 및 사용편의성 강화 방안 마련 - 외부위원의 경우 외부망(인터넷망)을 통하여 접근이 가능 하도록 구성 * 임의 사용자가 시스템 사용할 수 없도록 권한 관리 철저(회원가입 불가, 임시 아이디 제공 등) ○ 내부시스템 연계 부문 - 인천광역시 업무정책포털, 인천시 공간정보플랫폼, UMS시스템 등과 연계를 통한 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 프로세스 재설계 그 외 학교 및 사업자가 제안하는 프로세스 개선 필P 업무 업무 프로서스 재설계의 성공직민 수함과 차세다 시스템 가발의 만정직민 반영블 위해 프로세스 설계 담당 인격문 개발 인력과는 붙도로 투입하는 방만은 제시해이 합 산물정보 프로세스 재선계 보고서 고려대학교 ROa UIVER SITY 그 기능 요구사항 공통 요구사항 분류 기능 요구사방 요구사항 번호 SFR-공놈-001 요구사항 명칭 기초정보관리 정의 공농 기준정 토관리 기능 정의 공습고드관리 대략 시스템 전반어서 사분되는 공습의 코드 등록/ 작제변경 관리 기능 구...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 한다 ○ 데이터의 무결성, 일치성, 기밀성, 가용성 등을 고려하여 구축하여야 한다 ○ JAVA 기반의 정보시스템 구축 개발 시는 전자정부 표준프레임워크에 기반 한 지정된 공유서비스(공통컴포넌트)를 우선적으로 사용하여야 한다 ※ 컴포넌트에 대한 상세 기능은 egovframe포털(wwwegovframegokr) 참조 3) 정보시스템 구축 기술 요건 ○ 서비스 접근 및 전달 분야 - 정보시스템은 사용자가 다양한 브라우저 환경에서 서비스를 이용할 수 있도록 표준기술을 준수하여야 하고, 장애인·저사양 컴퓨터 사용자 등 소외계층을 고려한 설계...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 않았으나, 사업의 추진 시 필수적이라고 판단되는 사항은 제안범위에 포함하여 제안하여야 함 ○ 본 제안요청서 및 이후 제안서 제출까지 발생하는 모든 사안에 대하여는 보안을 요하며, 제안서와 관련하여 제안참가 업체는 타 업체 또는 외부기관으로의 제안요청 관련 사항 공개를 금함 ○ 본 사업 수행 중 취득한 인천광역시의 정보통신 보안사항 일체에 대하여 보안을 유지하여야 하며, 내부자료 유출 등 문제발생 시 수행업체가 모든 민․형사상 책임을 져야 함 2 사업내용 ※ 세부과업내용은 I 4 과업의 범위(P2) 참조 ○ “위원회 통합관리시스템”을...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 2024 08   목 차  1 사업 개요 가 추진배경 및 필요성 ㅇ 안전사고 증가 - 고압가스 취급 부주의로 인한 연구실 사고가 빈번하게 발생하고 있으며, 이는 인명 피해와 연구 기기 손상을 초래함 ㅇ 법적 요구사항 - 안전 관리에 대한 법적 요구사항과 규제가 강화되고 있으며, 이를 준수하지 않을 경우 법적 책임과 벌금이 부과 ㅇ 연구 환경 보호 - 연구원들의 건강과 안전을 보호하고, 안전한 연구 환경을 제공하기 위해 체계적인 관리 시스템 구축 필요 나 사업 범위 ㅇ 원내에서 관리하는 화학물질 운영현황의 통계 정보를 제공하는 시스템...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 2024 10      □ 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 □ 사업예산 : 130,000,000원 범위 내 (VAT 포함) □ 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 □ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)  학사제도제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 ...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 2024 10       1 사업명: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선 2 추진배경 및 필요성 □ 한국연구재단법 제5조, 산업교육진흥 및 산학연협력촉진에 관한 법률 제39조의2 및 제43조에 따라 실시하는 대학 산학협력활동 실태조사를 안정적으로 운영 필요 □ 항목 지침 변경사항 등 변화에 신속하고 정확하게 대응하며, 기능개선에 대한 사용자 요구를 반영하여 사용자 편의성 강화 필요 □ UICC의 효율적인 관리와 운영을 위한 지원 체계 및 각종 기관 요구사항에 대응 필요 3 주관기관 : 한국연구재단 4 사...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 인터퍼미스 정의서 요구사항 분류 민터메이스 요구사방 요구사항 번호 INR- 요구사항 명칭 면계데이터 점감섬 교보 및 연계 모둘 잘용 정의 연계데이터 점합섬 환보 및 연계 모분 제금 개념 점의 R구 사함 연제데이터 정합성 확보 상세 세부 시스템길 기관번 연제밤식에 따는 각 유행번 정합성 확보밤만은 설명 내용 제시하여이 합 데이터 누각은 방지하기 위해 면계 단계빌 정합성 검중방단은 193 -ODA 고려대학교 ROa Mtfr cT 제시하여이 합 연제 모물 촬용 고려다학교고어서 저공하는 API슬투선의 면계 방단은 제공히고 이r가 발생하지 ...

# %%
# Re-run Example Query 5
if qa_chain and processed_documents:
    pdf_doc = next((doc for doc in processed_documents if '고려대학교' in doc.metadata.get('파일명', '')), None)
    if pdf_doc:
        query = "고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경을 설명해주세요."
        response, query_time = time_rag_query(qa_chain, query)

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...")
    else:
        print("Could not find processed document for 고려대학교 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경을 설명해주세요.
#
# Generated Response:
# 고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경은 다음과 같습니다:
#
# 1. **교육 환경의 급격한 변화**: 인구 감소, 코로나19 팬데믹으로 인한 교육 환경 변화, 인공지능의 활용 등으로 대학이 급격한 사회-기술 변화에 직면하고 있습니다.
#
# 2. **분산된 시스템 및 데이터의 통합 필요성**: 정보화 요구가 증가하고 있지만, 기존의 노후화된 학사 시스템에 기반하여 업무가 분산되어 있어 시스템 통합에 대한 요구가 커지고 있습니다.
#
# 3. **데이터 기반 대학 경영 지원 개선**: 분절된 정보 시스템 간의 정보 연계 미흡 및 정보화 표준 부재로 인해 경영 현황 파악 및 의사결정 시 한계가 발생하고 있습니다.
#
# 4. **사용자 정보 서비스 접근성 개선**: 교내 구성원의 정보 탐색 지원을 위한 포털 서비스가 제공되고 있으나, 정보 접근성과 유용성에 대한 개선 요구가 상당합니다.
#
# 5. **대학 경쟁력 강화 및 전략 목표 달성 지원**: 노후화된 시스템의 차세대 구축을 통해 정보 서비스의 품질을 강화하고, 대학의 교육 시스템 경쟁력을 확보하고자 합니다.
#
# Query Time: 21.61 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024 7 07 aE 고려대학교 KOREA UNIVERSITY 본 자고; 게민내공의 신편움 취한 "포자고로 부거으로 '년부지 사용타; 형위: 구립- 고려대학교 ROa UIVER SITY 목 차 사업개요 1 사업 개요 2 사업 배경 3 사업 범위 : 기대 증과 I 현황 및 문제점 1 일반 된참  2 점수화 된참 문제점 및 개선방방 I 사업 추진방안 1 추진 욕표 2 추진 밀정 3 추진 체계 IV 제안요청 내용 1 제안요섬 개요 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 시스템 정보가밭번 눕랍머 시집시스템(UMS) 디지 털 선락팀 캠머 일시스템 정보민프라팀 금명발급시스템 학심저 Spring bgat, 모바일손합(호맛맨 디지 털 선락팀 Java Katlin Swift 모바일신문노 spring 학심저 고려대 교둑(서늘 / 막자) 시스템 IIDJe 5 디지 털 선락팀 고려대학교 ROa Mtfr cT 나 주요 서비스 구성 현황 포털 박사 모바밀맵 시스템 기능 현환 방문 후 일람 가능 꾸털 학사 데이터 연계 현참 방문 후 얼람 가능 인프라 현환 하드웨어 및 시스템 S/W 현참 방문 후 열람 가능 3 문제점 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 대한 통계현황 조회 및 출력 기능 구현 - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 ◦ 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 □ 학사 정보시스템 고도화 ◦ 기 구축된 “학사운영시스템”에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 ◦ 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 □ 정보기술 활용 전략 ◦ 향후 우리대학 학사정보시스템의 환경 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 기능 구런 #로보자시더이터 고려대학교 ROa UIVER SITY 첫봇 헌 햇봇 고도화 필요 0 i차 첫봇 사업들 통해 도출린 사용자 요구 반영 필요 교원 직원 세중캠퍼스 학생까지 대상블 확대한 햇봇 시스템 구축 필요 교수 사용자의 교육 연구 관련 다양한 문의에 대한 용답 규정과 연계하여 사용자의 문의 나용에 대한 용답 및 근거가 되는 관련 규정 자규 문서 등음 같이 제공찰 수 윗도록 구축 1차 햇봇 사업 범위 (상세 내용은 사업 착수 후 공유) 첫못시스템 구축(질의응답 GPT 기반 첫봇 구현) 질의용답 기반 GPT기반 규정학습 햇봇...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 구런 비밀번호 변경 마이메뉴설정 제공더뉴벌 필요한 설정정보 관리 알림설정 공지 추천_ 업데이트 눕어 대란 밑림 수신 본{오프 틈 업무 충류번 알람 온/오프 틈 사용자 선호에 따른 편의 기능 제공 방안은 모바일 고려대학교 ROa Mtfr cT 제시하여이 밥 건어선점 기본언어(만글 엉어) 도움말 언어설청문 단국어, 영어분 기본적므로 지원하고 함루 확대 지원관 침도록 설계하여이 밥 산출정보 프로그램 복록; 프로그럼명시서 회면정의서 사용자매뉴벌 틈 고려대학교 ROa UIVER SITY 학사행정시스템 요구사항 분류 기능 요구사방 요구사항 번...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 2024 10      □ 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 □ 사업예산 : 130,000,000원 범위 내 (VAT 포함) □ 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 □ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)  학사제도제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# (분산된 시스템 및 데미터의 동합) 급변하는 교육환경 속어서 정보화 요구사함온 증가하나 우리 대학온 노후화된 학사 시스템올 기반으로 업무마다 분산된 보화름 추진하고 있어 시스템 동합에 대한 요구가 증가함 다 (데이터 기반 대학경염 지원 개선) 분절된 점부시스템 간 정보언계 미름늄 및 정보 화 표준 부재로 인하여 경영현환파악 및 의사결정 시 한계가 발생함 라 (사용자 정보서비스 접근성 개선) 또한 교내 구성원의 정보담색 지원율 위한 포 털 서비스가 제공되고 있으나 포달의 정보 접근성 및 유용성데 다한 개선 요구 가 상당함 마 (대학 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 올#플렉정e다 &구하E 둘시] 숙가차 지너겨움 겨네; ; 여겨고 겨억까다 7 대적 -CeC 마어 설기다 국개사-기 기여 역#락 다구# l월다 습청하#f 나 고러대학교 비전 소 ; 그나오 고려대학교 ROa Mtfr cT 창의석 미러 연자j 엉성하고 인#어 공안하논 더욱 GLoUAL Toa Dbi iUX AIrE 그 플라다논 개 본O: {권 슈고스T캠베 하크 훨 미어 바도 올모가 부 Narse 1이터; 대하다:: 다 기관 인력 현환 (대규 흉데이지 기준) 교직원 현환 구분 전임교원 비전임교원 직원 서물캠퍼스 525명 2,883명 1,1...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 정보시스템 소프트웨어 개발보만 가이드 {뱀정안전부} 주사업자는 프로직트관리 도구튼 선점하여 프로직트관리든 수행하고 모든 보고 및 검도 회의 등은 프로직트 관리도구의 데이터들 근거로 수행하여야 참 프로적트 수행 기간 중 사업관리 조직흩 구성하고 PMiProject Manager} PLProjcct Leader} QAQuality Assurance) AA(Applicatian Architecturel DA(Data Architecture) 디자인 공통개발 등의 업무름 운영하여 개발자 운염자 사용자 관리자 등 모든 이해당사자들 의사소통관...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 교육과점 개편 R점 심의 확점 교과국코드 부여 전 과점 시스템 화 교육과점 교과국 변경 이력 관리와 졸업사점 연계 도급" 신어요 고려대학교 ROa Mtfr cT 역량기반 교과욕 운영체계 정보화 개선 감의계학서 상 역량항묵 입력스 서움캠퍼스 역량으로만 구축하여 세증캠퍼스 적용 불가 2024년부터 문명되는 CQI보고서지 현재는 역량관리시스템 KUchive KUSEUM 에서 관리하고 있어 학사행정시스템으로 기능 이관 필요 학상들의 수감소감 및 그에 대한 사후조치튿 현재는 역실로 관리 "교마 비교로 #품 재광 마 | 싶물?-펴화 'n질a하...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 환경 설정 틈 관련 )밭 표준 및 가이드에 반명하여다 하머 개발프레임워국예 반험하기 어려운 녹립다 R소밑 경우; 빌도 추가 문서로 관리하여이 공놈 모분의 개발 및 직용 설계 단계 이전어 업무 거밭 및 시스템 구성은 위란 공통 기늄모늘) 음 도준하여 제시하여이 하다 개밭 단계 이전에 재사용 공중요 소(공놈 모물 및 컴포년트]큼 개발하여 잘용 가이드와 함께 제공하여야 합 개발험 표준 기속이 아년 경무 적용 불가 사유름 입중하고 추관기관의 사전 승인은 투안 후 적용 활 수 있음 산물정보 아키Y처 정의서 R구사함 문류 표준 R구사방 R구사...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 참여관 수 빗는 사업금말의 하한(과학기운정보농신부고 소프트웨어 품질인중의 세부기준 및 절차(과학기순정보봉신부고시) 소프트데어 사업 하도급계약의 적정성 판단기준(과-학기술정보 농신부고시) 용역계약일반조건(기회재정부계약예규) 험상에 의찬 계약체걷기준(기회재정부 계약예규) 하도급거래 긍정화지짐(공 정거래 뒤원 점보 오조치에 곤란 지침(과-학기술정보늄신부고시) 개인점보의 기술적-관리적 보소조치 기준(방송속신위원 리고시) 스6 회대7) 고려대학교 ROa UIVER SITY 서비스 접근 및 전달 분야 적용계회 / 겉과 부분적용/미 구 눈 해당...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 다문로드 다문로드 정보분 대학알리미 사이트에 업로드}학부 총관담당자)- > 최종 편제조사 곁과 저장(학부 총곧담당자) 전년도 자료복사 후 변경사람 수정 및 환정 기능 권반에 따른 차듭 고려대학교 ROa UIVER SITY 기능 제공 {학과부]빌 담당자) 곤련자료 업로드 기능 제공 수정데이터 교민관 수 및는 기능 제금 편제단뒤조사기간 학사력에 마른 놈제 기능 재공 계약학과 문담곤리 계막학과 산학협리창동 실태조사름 지원관 수 F는 계막학과 문영현화 함복 관리 기능 재공 계약학과 설치 운령 현랑(취누학뒤 계약학과 유험, 겨일 모처학과 명...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 숙독하신 주 서명하기 바합니다: 나는 고려대학교로부터 취,관 모든 정보름 관련 업무어 한해 이용관 것이며 개인적으로 사 용하거나 빌도 보곤하지 아니라다 나는 고려대학교로부터 제공받문 각종 정보자산은 무단 변조 복사 취손 눈실 슬으로부터 안전하게 곤리하켓다 나는 지원업무와 무관관 경무상대가 누구이건 간어 밑 필요가 업는 자에게 업무 중 취늑한 소유청보분 누설하지 사컷다 뜨히 암은 정보나 시설에 접근하지 많으다, 고려다학교 곤련 업무록 수행 # 때만 허가받온 처리시설(정보 시스템 정보 데이터; 전산자원 윗음 이용하다 나는 업무지원은 흰...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 제적자 조리 재입학자 조리 산출정보 프로그램 복록; 프로그럼명시서 퇴면정의서 사용자마 뉴얼 틈 요구사항 분류 기능 요구사방 요구사항 번호 SFR-학사-003 고려대학교 ROa UIVER SITY 요구사항 명칭 전과관리 학직 전과-관리 기능 정의 전과기준인원관리 전과관리어 필요단 더학원버학과 (부]전공번 전입/ 전훈 인원은 관리하는 기능 구런 학과빌로 입학정관의 및 조까지 전과분 수용관 것민지 곤리관 R도록 구런 (세속캠퍼스) 학과밭 입학모집점원 10055까지 전과 점원 적용 캠퍼스간 소속변경 정린문 관리하는 기능 구런 전과자 주기존...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 데미터 추출 교원 직원 세중검퍼스 학생 으로 서비스 대상 확다 1차 사업 결과 사용자 피드백 반명 고도화 GFT 적용 모델의 고도과 전체 기능 컴문 서비스 구축 경'늄계시스템과 원데이터 주촌 적재밤식 데이터마트 생성방식 밑원퇴 Fythan으로 구현간 모델의 연속실뱀 및 병렬실뱀 야키석처 고도 시신버 고도화 A신버 포라서비스 셋봇서비스든 농합하여 추전-눕계 데미터 기능 저설계 (전체 고려대학교 ROa Mtfr cT 나 개인정보 영향평가 시스템의 구속 문영 변경 등이 개인점보어 미치논 영향울 사전에 조사 예측 검토하여 개선밤안물 도출하...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 참 통합아이다 변경(재생섬) 처리 방안큼 반영하여 구축하야 함 외부의 민가되지 망은 사이트에서 무리 대학 무털 로그인 폐이지블 후출하여 고려대학교 ROa Mtfr cT 인증하는 '무회민증'의 방지 해제들 유면하게 밭 수 빗도록 구축해야 참 대학 정보화 인력과의 협업업무지원) 및 기순이전은 할 수 있는 방안음 제시하여야 합 구축되는 모든 시스템은 체계적인 분석 설계 구청으로 대학의 관련 시스템과 언계 및 지원이 가능하도록 구축하여야 감 신규시스템 구축 시 다양한 [T친경에서 원활히 구동되 수 뒷도록 기능음 제공하여야 참 최적의 개발방...

# %% [markdown]
# # Implement Semantic Chunking

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# While true semantic chunking often requires deeper document structure analysis
# or advanced models, we can use RecursiveCharacterTextSplitter with parameters
# tuned to try and respect some structural elements like paragraphs or headings
# by splitting on various characters including newlines.

# You could potentially add logic here to pre-process text based on HTML structure
# if using hwp5html, or analyze PDF layout for more semantic splits.
# For this step, we'll use RecursiveCharacterTextSplitter with more aggressive
# splitting characters to try and capture semantic breaks.

# Initialize a text splitter with additional separators that might indicate semantic breaks
# The order of separators matters: try splitting on larger semantic units first.
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,  # Adjust chunk size as needed
    chunk_overlap=100, # Adjust overlap as needed
    separators=["\n\n", "\n", " ", ""] # Try splitting on paragraphs, then lines, then spaces
)

# Split the processed documents into chunks
# Note: If using hwp5html, the page_content will be HTML, and this splitter
# might not optimally handle HTML tags as semantic separators.
# A dedicated HTML splitter or pre-processing might be needed for better results with HTML.
semantic_chunked_documents = text_splitter.split_documents(processed_documents)

print(f"Original documents: {len(processed_documents)}")
print(f"Semantic chunked documents: {len(semantic_chunked_documents)}")

# Display first few semantic chunked documents
if semantic_chunked_documents:
    print("\nFirst 3 semantic chunked documents example:")
    for i in range(min(3, len(semantic_chunked_documents))):
        print(f"--- Semantic Chunk {i+1} ---")
        print(f"Content snippet: {semantic_chunked_documents[i].page_content[:500]}...")
        print(f"Metadata: {semantic_chunked_documents[i].metadata}")
# Out:
# Original documents: 5
# Semantic chunked documents: 391
#
# First 3 semantic chunked documents example:
# --- Semantic Chunk 1 ---
# Content snippet: <표>
#
#
#
#
#
#
#
#
# 2024. 10.
#
#
#
#
# <그림>
#
#
#
# <표>
#
#
#
#
#
#
# <그림>
#
#
# <표>
#
#
#
# <표>
#
#
# □ 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 -
#              트랙운영 학사정보시스템 고도화
# □ 사업예산 : 130,000,000원 범위 내 (VAT 포함)
# □ 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)
#   * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음
# □ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)
#
#
#
# <표>
#
#
# 학사제도･제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대
# 트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화
# 산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화
# 기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성
#
#
#
# <표>
#
#
#  ◦ 트랙기반 교육과정의 운영 및 ...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# --- Semantic Chunk 2 ---
# Content snippet: <표>
#
#
# □ 트랙제 교육과정 운영프로그램 개발
#  ◦ 트랙제 기반 교육과정 운영
#      - 트랙제 기반 교육과정 운영 단계의 관리 절차에 대한 개선사항 도출 및 구현
#  ◦ 트랙제 기반 교육과정 평가 및 통계관리- 트랙 교육과정 운영에 대한 통계현황 조회 및 출력 기능 구현
#      - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현
#      - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현
#  ◦ 기타 사항
#      - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발
#
# □ 학사 정보시스템 고도화
#  ◦ 기 구축된 “학사운영시스템”에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현
#  ◦ 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현
#
# □ 정보기술 활용 전략
#  ◦ 향후 우리대학 학사정보시스템의 환경 변화에 대비하여 상용 DBMS(Oracle, MS SQL Server)를 적용할 수...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# --- Semantic Chunk 3 ---
# Content snippet: <표>
#
#
#
# <표>
#
#  ◦ 향후 변화하는 발주기관의 특성을 고려하여 능동적이고 효율적인 시스템으로 구성하여야 한다.
#  ◦ 시스템은 향후 확장성을 충분히 고려하여 설계·적용되어야 한다.
#  ◦ 안정적, 효율적, 확장 가능한 최적 시스템으로 구축하며 사용자의 다양한 요구에 부흥하도록 구성하여야 한다.
#  ◦ 수작업을 최소화하고, 가능한 전산으로 모든 업무를 처리할 수 있도록 시스템을 구성하여야 한다.
#  ◦ 사용자의 편의성을 고려한 Work Flow 중심의 트랙 교육과정 개발 및 운영이 이뤄질 수 있도록 구성하여야 한다.
#  ◦ 트랙기반 교육과정 운영체제 구축에 따른 한영대학교 종합정보시스템 기능을 연계하여야 한다.
#  ◦ 현재 구축되어 있는 한영대학교 종합정보시스템 구축 환경을 고려하여 시스템을 구현하여야 한다.
#  ◦ 개발대상 업무의 범위는 업무분석 결과 및 추가요청 등에 따라 변동 될 수 있음
#  ◦ 개인정보보호를 고려하여 시스템 설계를 하여야 한다.
#  ◦ 제안되는 모든 S/W는 기존 환경을 ...
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}

# %% [markdown]
# # Embedding Generation and Vector DB (FAISS) Creation (using Langchain)

# %%
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from google.colab import userdata

# Access your API key from Colab secrets
try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None # Set to None to prevent further errors


if OPENAI_API_KEY:
    # Initialize the OpenAI embeddings model
    embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key=OPENAI_API_KEY)

    # Create a FAISS vector store from the semantically chunked documents
    # This will generate embeddings and add them to the FAISS index
    vectorstore = FAISS.from_documents(semantic_chunked_documents, embeddings)

    print("FAISS vector store created with embeddings from semantic chunks.")
    print(f"Number of documents in vector store: {vectorstore.index.ntotal}")

    # You can optionally save the vector store to disk for later use
    # vectorstore.save_local("semantic_faiss_index")

else:
    print("Skipping vector store creation due to missing API key.")
    vectorstore = None # Set vectorstore to None if API key is missing
# Out:
# FAISS vector store created with embeddings from semantic chunks.
# Number of documents in vector store: 391

# %% [markdown]
# # Implement Advanced Retrieval (using Langchain)

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import DocumentCompressorPipeline
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_transformers import EmbeddingsRedundantFilter
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers import MultiQueryRetriever
from langchain.prompts import PromptTemplate # Import PromptTemplate
from google.colab import userdata

# Access your API key from Colab secrets
try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None # Set to None to prevent further errors

if OPENAI_API_KEY and vectorstore:
    # Initialize the ChatOpenAI model for generation (will also be used for Multi-Query)
    # Adjusting parameters for generation enhancement
    llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY, temperature=0.3, max_tokens=1500, top_p=0.8) # Adjusted temp, max_tokens, added top_p

    # Define a refined prompt template
    # This template guides the language model on how to use the retrieved context
    template = """다음 문서를 사용하여 질문에 답하세요.
    답변은 가능한 한 정확하고 간결하게 작성하세요.
    제공된 문서에 없는 내용은 언급하지 마세요.
    문서:
    {context}

    질문: {question}

    답변:"""
    QA_CHAIN_PROMPT = PromptTemplate.from_template(template)


    # Base Retriever with higher k and MMR
    base_retriever = vectorstore.as_retriever(
        search_type="mmr", # Use MMR search
        search_kwargs={"k": 10, "fetch_k": 20} # Increased k and fetch_k
    )

    # Implement Multi-Query Retriever
    multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever=base_retriever,
        llm=llm
    )

    # Using the multi-query retriever as the main retriever for now
    # Metadata filtering would be integrated here if implemented dynamically
    final_retriever = multiquery_retriever # Use the multi-query retriever

    # Create a RetrievalQA chain with the advanced retriever and refined prompt
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=final_retriever, # Use the advanced retriever
        return_source_documents=True,
        chain_type_kwargs={"prompt": QA_CHAIN_PROMPT} # Pass the refined prompt
    )

    print("Advanced RetrievalQA chain created with Multi-Query, MMR, and refined generation parameters/prompt.")

else:
    print("Skipping Advanced RAG chain creation due to missing API key or vector store.")
    qa_chain = None
# Out:
# Advanced RetrievalQA chain created with Multi-Query, MMR, and refined generation parameters/prompt.

# %% [markdown]
# # Example Queries Based on Extracted Text

# %%
# Example Query 1 based on extracted text
if qa_chain and processed_documents:
    # Look for content related to the first HWP file (한영대학)
    hwp1_doc = next((doc for doc in processed_documents if '한영대학' in doc.metadata.get('파일명', '')), None)
    if hwp1_doc:
        # Formulate a query based on likely content (e.g., project purpose, scope, or timeline)
        query = "한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query) # Use the timing function

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds") # Print the execution time
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...") # Print a snippet of the source chunk
    else:
        print("Could not find processed document for 한영대학 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?
#
# Generated Response:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 다음과 같습니다:
#
# 1. **교육 환경의 급격한 변화**: 인구 감소, 코로나19 팬데믹으로 인한 교육 환경 변화 및 인공지능의 활용 등으로 대학이 직면한 사회-기술 변화에 대응하기 위함입니다.
#
# 2. **분산된 시스템 및 데이터 통합 요구**: 노후화된 학사 시스템으로 인해 업무마다 분산된 정보가 존재하며, 시스템 통합에 대한 요구가 증가하고 있습니다.
#
# 3. **데이터 기반 대학 경영 지원 개선**: 정보 시스템 간의 연계 부족으로 경영 현황 파악 및 의사결정에 한계가 발생하고 있습니다.
#
# 4. **사용자 정보 서비스 접근성 개선**: 교내 구성원에게 제공되는 정보 서비스의 접근성과 유용성을 개선할 필요성이 커지고 있습니다.
#
# 5. **대학 경쟁력 강화**: 노후화된 시스템을 개선하여 정보 서비스의 품질을 높이고, 대학 교육 시스템의 경쟁력을 확보하기 위한 목적입니다.
#
# Query Time: 9.74 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
#
#
#
#
#
# 2024. 10.
#
#
#
#
# <그림>
#
#
#
# <표>
#
#
#
#
#
#
# <그림>
#
#
# <표>
#
#
#
# <표>
#
#
# □ 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 -
#              트랙운영 학사정보시스템 고도화
# □ 사업예산 : 130,000,000원 범위 내 (VAT 포함)
# □ 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)
#   * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음
# □ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)
#
#
#
# <표>
#
#
# 학사제도･제...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 플렉품 및 기반구조 분야 적용계회 /겉과 부분적용/미 적용시 사유 대체기술 기본 지침 정보시스템 운영어 사용되는 농신장비는 IPi와 IPy6가 통시에 원되는 장비름 채택하여야 안다. 하드웨어는   이기농간 연제가 가능하여이 하며 특정 기능문 수밤 하는 임버디드 장치 및 주변 장치는 해당 장치가 설치되는 정보시 팀과 소환성 및  화장점이 보장되어야 반다 서부 기술 지침 회상되의 밀티미디어 농신 H320~H324 H310 부가늄신: Val? 네트위크 H 323 Megac디(H.24리) 서내용(개방z...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 서식 9 ] 정량적 기술평가 요약표 사업 수행 실적 업제명 지분율 완구일 발주처 사업명 사업금액 점수 경영상태 업제명 지분율 구분 등급 점수 회사제또는 기업어음데 대단 신용경가등급 또는 기업신용평기 등급 260...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 위 청렴계약 서약은 상호 신뢰를 바탕으로 한 약속으로서 반드시 지킬 것이며, 낙찰자로 결정될 시 본 서약 내용을 그대로 계약특수조건으로 계약하여 이행하고, 입찰참가자격 제한, 계약해지 등 한영대학교의 조치와 관련하여 당사가 한영대학교를 상대로 손해배상을 청구하거나 당사를 배제하는 입찰에 관하여 민·형사상 어떠한 이의도 제기하지 않을 것을 서약합니다.
#
# 2024.    .     .
#
#
# 서약자 : 대표                (인)
#
# 한영대학교 총장  귀하
#
# [서식 제9호]
#
# <표>
#
# [서식 제10호]
#
#
# 정보 비공개동의서
#
#
#  ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 2 제안서 작성 유의사람 242 3. 제안서 국자 및 작성방법 242 248-297
# 고려대학교 KORKA UVER SITY 사업 개요 1. 사업개요 사업명: 고러대학교 차세대 포털 학사 정보시스템 구속 사업 나. 사업기간: 계약일로 부터 24개원 이내 다. 무상유지보수기간 : 사업종로 일로부터 12개월 라. 사업데산 : 11,270,000,000원 (VAT 포함 3년 분합  지급) 2024학년도 약 3096 지급 2025학년도 약 4096 지급 2026학년도 약 3096 지급 마 입찰 및 계약 방법:...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
# <표>
#
#  ◦ 향후 변화하는 발주기관의 특성을 고려하여 능동적이고 효율적인 시스템으로 구성하여야 한다.
#  ◦ 시스템은 향후 확장성을 충분히 고려하여 설계·적용되어야 한다.
#  ◦ 안정적, 효율적, 확장 가능한 최적 시스템으로 구축하며 사용자의 다양한 요구에 부흥하도록 구성하여야 한다.
#  ◦ 수작업을 최소화하고, 가능한 전산으로 모든 업무를 처리할 수 있도록 시스템을 구성하여야 한다.
#  ◦ 사용자의 편의성을 고려한 Work Flow 중심의 트랙 교육과정 개발 및 운영이 이뤄질 수 있도록 구성하여야 한다.
#  ◦ 트랙기반 교육...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# □ 일반사항
#   ○ 본 제안서는 「한영대학교 특성화 막춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화」사업에 한정하여 적용
#   ○ 제안사는 한영대학교의 트랙운영 학사정보시스템을 충분히 이해하고, 제안요청 사항을 기본적으로 반영하여 과업내용을 포함하여야 함
#   ○ 제안사는 본 제안요청서에 언급하지 않았으나, 본 과업수행 향상에 도움이 되는 사항이 있을 경우 이를 추가로 제시할 수 있음
#   ○ 과업수행 중 환경변화로 인하여 설계변경 되거나, 기타 예기치 않은 여건의 변화로 과업 대상 업무에 대한 일부의 변경 및 추가요구사항이 발생...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 설명 내용 구축민 셋옷의 고도회 셋못 서버 이중리 사용자 [상은 교환   직원까지 확대한  쨌봇 서비스 구축 구축단 셋봇의 사용자 피드백불만 {기선 의견 등)은 반영하여 구축 GPT불 직용한 생성험 음답 봇 기능 고도화 부서밭 자주하는 질의않답 리스트트 수합하여 전처 반영 차세다 시스템 구축으로 인단 연계기능의 경로 변경사람   데이터변경사람  API본경사람   검색엔진 변경사방 틈 반험 영문 못 고도회 구축 시기밭   자주하는 질문정보 제공 산출정보 프로그램 복록 프로그럼럼시서 회면정의서  사...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
# □ 트랙제 교육과정 운영프로그램 개발
#  ◦ 트랙제 기반 교육과정 운영
#      - 트랙제 기반 교육과정 운영 단계의 관리 절차에 대한 개선사항 도출 및 구현
#  ◦ 트랙제 기반 교육과정 평가 및 통계관리- 트랙 교육과정 운영에 대한 통계현황 조회 및 출력 기능 구현
#      - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현
#      - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현
#  ◦ 기타 사항
#      - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발
#
# □ 학사 정보시스템...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 설명 이뉴가 되는 업무의 재설계 및 정보화 밤만 제시{BPR 업무 프로서스 재설계 [상 업무는 ISP어서 탁사점점 전반어 걷쳐 도출권 업무 프로세스 재설계 대상문 기준으로 하머 주요 대상 업무는 아래와 같음 학과 흩업기준 R건과 정보화 정도 분석 및 차세대 정보화 개선 방안 대학원번 입시-학적생섬 시점에 따른 대학원생 정보시스템 사용 이수 및 개신 방만 도츠 {대학원 입시-학적 전반 프로세스 점검} 재설계) 장학금 곤리 체계 및 장학 주천신점-선발 놈계  전반의 점보화 현상 밤만 (한국장학재단 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024. 7. 07 aE 고려대학교 KOREA UNIVERSITY 본 자고; 게민내공의 신편움 취한 "포자고로 부거으로 '년부지 사용타;  형위: 구립-
# 고려대학교 ROa UIVER SITY 목   차 사업개요 1. 사업 개요 2 사업 배경 3. 사업 범위 :. 기대 증과 I. 현황 및 문제점 1. 일반 된참 . 2 점수화 된참 문제점 및 개선방방 I. 사업 추진방안 1. 추진 욕표  2 추진 밀정 3. 추진 체계 IV. 제안...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 작 성 항 목 작 성 방 법 사용자   관리자 등 시스템의  이용대삼자별로   구분하여   교국훈련 교육훈련 방법 내용; 교육일점, 교육훈련 조직 등름 삼세히 제시하여야 한다 유지관리 계획 조직 절차 범위 및 기간과 이와 관련된 기타의 유지관리 동등름 종합적으로 제시하여야 한다 기밀보만 체계 및 대책 저작권 존중여부 명시 시스템 보안성 확보 5. 기밀보만 방안과 개인점보보호 대책은 제시하이야 현다 안점적인 시스템 문영음 위하여 백업 복구 및 장애대용 대책든 제 비상대책 시하여야 한다. 7. 기타  지...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 나. 개인정보 영향평가 시스템의 구속 문영   변경 등이  개인점보어 미치논   영향울 사전에 조사   예측 검토하여   개선밤안물 도출하여야하다   이름 동해  개인정보   침해사고름 사전데 밤하고 정보주체의 권리름 보장하여야 함. 또한 개인정부 처리시스템 내의 개인점 보파일올 안전하게 보호하기  위해 필요한  기술적   관리적   물리적 안전조치가 적 절하게 적용되엇논지 확인하고 문제점이 있는 경무 개선밤안물 제시하여야 함 4. 기대 효과 가. 최신 정보기술 적용으로 급변하는 대학교육 한경에 신속...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY [서식 24] 보안서약서 (업체 대표자용) 년인온 년 _ 월 밀부로 관련 용역사업업무)은 수생삼에 있어 다음 사 방은 준수팔 것음  멈숙히 서약합니다 년인문 관련 업무 중 믿거 팀 밑체의 내흥이 직무상 기밑 사람림 문 민정단다 깎민문 이 기밀은 누설받이  고려대학교 이의과 보안에   위해가  팀 음지 민식하여 업무 수행 중 취꺼관 저반 기밑사함은 인처 누설하거나 공개하지 아니라다 년인이 기밀은 누설하거나 관계 규정은 위반만 따어는 관련 법i 계막어 따라 어떠한 처벌 및 붙이의도 감수란다 년인문 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# 당사는 「부패 없는 투명한 기업경영과 공정한 행정」이 사회발전과 국가 경쟁력에 중요한 관건이 됨을 깊이 인식하며, 국제적으로도 OECD뇌물방지 협약이 발효되었고 부패기업 및 국가에 대한 제재가 강화되는 추세에 맞추어 청렴계약 취지에 적극 호응하여 한영대학교에서 발주하는 모든 공사 · 물품 · 용역 등의 입찰에 참여함에 있어 당사 임직원과  대리인은,
# 1. 입찰가격의 유지나 특정인의 낙찰을 위한 담합을 하거나 다른 업체와 협정, 결의, 합의하여 입찰의 자유경쟁을 부당하게 저해하는 일체의 불공정한 행위를 않겠습니다.  이를 위반하여
# ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 첫봇 헌 햇봇 고도화 필요 0 i차 첫봇 사업들 통해 도출린 사용자 요구 반영 필요 교원 직원  세중캠퍼스 학생까지 대상블 확대한 햇봇 시스템 구축 필요 교수 사용자의 교육 연구 관련 다양한 문의에 대한 용답 규정과   연계하여 사용자의 문의 나용에  대한 용답 및 근거가 되는 관련 규정 자규 문서 등음 같이 제공찰 수 윗도록 구축 1차 햇봇 사업 범위 (상세 내용은 사업 착수 후 공유) 첫못시스템 구축(질의응답 GPT 기반 첫봇 구현) 질의용답 기반 GPT기반 규정학습 햇봇 오른 쨌못 시법오든...

# %%
# Example Query 2 based on extracted text
if qa_chain and processed_documents:
    # Look for content related to the second HWP file (한국연구재단)
    hwp2_doc = next((doc for doc in processed_documents if '한국연구재단' in doc.metadata.get('파일명', '')), None)
    if hwp2_doc:
         # Formulate a query based on likely content (e.g., system function, users, or timeline)
        query = "한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query) # Use the timing function

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds") # Print the execution time
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...") # Print a snippet of the source chunk
    else:
        print("Could not find processed document for 한국연구재단 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 무엇인가요?
#
# Generated Response:
# 한국연구재단의 대학산학협력활동 실태조사 시스템 기능개선 사업의 목표는 UICC 시스템의 효율적인 관리와 운영을 지원하고, 사용자 요구를 반영하여 사용자 편의성을 강화하며, 실태조사 항목 지침 변경사항에 신속하고 정확하게 대응하는 것입니다.
#
# Query Time: 6.69 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
# <그림>
#
# <표>
#
#
#
#
#
#
#
# 2024.  10.
#
#
# <표>
#
#
#
# <그림>
#
#
# <표>
#
#
# <그림>
#
#
#
# <표>
#
#
# <표>
#
# 1. 사업명: 2024년 대학 산학협력활동 실태조사 시스템(UICC) 기능개선
# 2. 추진배경 및 필요성
#  □ 한국연구재단법 제5조, 산업교육진흥 및 산학연협력촉진에 관한 법률 제39조의2 및 제43조에 따라 실시하는 대학 산학협력활동 실태조사를 안정적으로 운영 필요
#  □ 항목 지침 변경사항 등 변화에 신속하고 정확하게 대응하며, 기능개선에 대한 사용자 요구를 반영하여 사용자 편의성 강화 필요
#  □...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 설명 이뉴가 되는 업무의 재설계 및 정보화 밤만 제시{BPR 업무 프로서스 재설계 [상 업무는 ISP어서 탁사점점 전반어 걷쳐 도출권 업무 프로세스 재설계 대상문 기준으로 하머 주요 대상 업무는 아래와 같음 학과 흩업기준 R건과 정보화 정도 분석 및 차세대 정보화 개선 방안 대학원번 입시-학적생섬 시점에 따른 대학원생 정보시스템 사용 이수 및 개신 방만 도츠 {대학원 입시-학적 전반 프로세스 점검} 재설계) 장학금 곤리 체계 및 장학 주천신점-선발 놈계  전반의 점보화 현상 밤만 (한국장학재단 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 구분 요구사항 ID 요구사항 명칭 SFR-학사-024 교직기준관리 SFR-학사-025 교직선발 SFR-학사-026 교직 교직이수관리 SFR-학사-027 교직사정관리 SFR-학사-028 교원자격증관리 SFR-학사-029 등록기준관리 SFR-학사-030 등록대삼자관리 SFR-학사-031 등록금수퍼관리 SFR-학사-032 등록금결산 SFR-학사-033 계절학기 교된학생 SFR-학사-034 잠학 기분관리 SFR-학사-035 잠학금관리 SFR-학사-036 근로장학 잠학 SFR-학사-037 학자 금대출 SFR-...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 제공하여마 탑 데미터버이스 프로그램 다국어 곤련스 답재 여부 관리 점부 문서나 명상 등의 형태로 도는어 답재되는 곤련스는 허당 곤란스의 엉문 버전 답재여부튼 시스템어서 처리관리한 R도록 구런 산출정보 프로그램 부록 프로그램령세서   화면정의서 사용자대뉴벌 등 요구사항 문류 기늄 R구사람 요구사함 번호 SFR-구닐-009 요구사항 명칭 지능성 검색 정의 지능씨 검색 직용 밤식 정의 지능럼 검약 밤식 사용자 의도와 R구어 맞는 지능힘 검석 기능 도입 의미기반 검색 - 사용자가 입리만 키쨌드물 바당으...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 정보화 현황 가 주요 정보시스템 현황 및 사업 대상(롭페이지 제외) 서비스 구분 정보시스템 개발프로그램 대상 운영부서 학사정보시스템 {AlM5) Fr "PrPulder 정보가 밭팀 수감신청시스템 Jervlet도 JSP; Ajax 정보가밭번 모바일수감신청I 학부모 성적조회, Jervlet도 JSP; Ajax 정보가 밭팀 금학기 공시 성직주리 합격자 발표 Servlets 정보가밭번 학직시스템(구} 학시밥 교육정보노페이지 CMs 학사팀 입학전-기회팀 입학시스템 FDerBuilaer 입학전 형관리 학사 LM...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 성적경고 해저자 명부름 화민환 수 있도록 탑 학직부어 성직경고 이력 기재 수감신점 이전락기의 성직경고 녀떡 만녀 성적표훈력 업무 용도어 따른 각종 성적표름 춥력하는 기능 보관국   확인봉 틈 전처 학생의 성적표분 관리판 수 덧도록 합 열람봉  발씀용 틈 학생 개별로 섬적표늘 관리팔 수 맛도록 참 성적분포현함관리 학고-발써점 부어현화   과보발등급분포도  순위일감표 교수감좌분되점현화 틈 산출정보 프로그램 복록 프로그럼명시서 퇴면점의서 사남자다 뉴얼 틈 요구사항 분류 기능 요구사방 요구사항 번호 S...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 KORKA UVER SITY 사업 추진방안 1. 추진 목표 그 교육환경  변화름 반영한 시스템 구속으로 대학의 교육액량  강화름 위한 기반 제공 새로문 움부합  교류 환경에 맞는 학사정보 시스템 구축 입학에서 졸업까지 전 과점의 선발  학적정보 /변동 고육과점 등록 수업 이수성적  장화수혀 졸업진급 등의 데이터들 효과적으로 연계  조회 환용릎 위한 점보시스템 구죽으로 대사 역량 강화 0 국문 수준의 영문 서비스 제공으로 나국인과 통등히 외국인 구성원의 점보직득 기회 보장 및 국제  검공력 감화 대학의 중요 사만에  대한 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 요구 분휴기준 서 부 내 용 사랑수 프로적 트의 된찰한 수함은 위해 필요한 지원사람 및 방단어 프무직트지원 대한 요구사방은 기습함 R구사함 시스템 } 서비스 안정퇴 및 문명  교훈른련 및  기술지원 (PSR) 하자보수 또는 유지관리 R구사함 뉴음 기술합 160
# 고려대학교 ROa UIVER SITY 요구사항 목국표 구분 요구사항 ID 요구사항 명칭 STR-0D1 텔 호된성 및 접근심 준수 STR-UD2 S/W 가발 보안가이드 준수 표준요구사함 STR-0D3 개발표 준 수립 및 준수 (STR) STR-0...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 기능 제공 {학과부]빌 담당자) 곤련자료 업로드 기능 제공 수정데이터 교민관 수 및는 기능 제금 편제단뒤조사기간 학사력에 마른 놈제 기능 재공 계약학과 문담곤리 계막학과 산학협리창동 실태조사름 지원관 수 F는 계막학과 문영현화 함복 관리 기능 재공 계약학과 설치 운령 현랑(취누학뒤   계약학과 유험, 겨일 모처학과 명침 모제학과 입학정원 계약학과 명칭 신면답과-점 구준 계막학과 림' 입학생 재학생 수 ; 설치권덕   외부학습장 이용어부  계막럽다 , 청단 (신기습) 분야 여부, 경비부담변항, 채...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 장학금 수예충명서 : 훈력 산출정보 프로그램 복록, 프로그럼명세서  퇴면정의서  사용자다 뉴얼 틈 요구사항 분류 기능 요구사방 요구사항 번호 SFR 학사 036 요구사항   명칭 근로장학 정의 장학 근로장학 기능 정의 근로장학 수요조사 근로장락 학생 수무튼 조사하는 기능 각 부서어서 부서명과 요청하는 근로락생 수; 신청기간 눈문 입력 미망 근무 시간 입력 한국장학재단 국가근로장학금 수요조사늘 참고하여 구성 근로장학 신발 및 배치 차서다 포닫은 농반 근로장학 선밭 공지 기능 근로장학 신청 학상은 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 입학년도에 따른 필수과로 교망 필수과복 이수구분번 필수과복은 관리함 대학원 학과길 종합 시험과로 및 기준점수분 관리람 중복인정기준관리 다전공 이수어 마른 주전공어서 이수단 교과큼 중복인점 받문 수 및는 교과분 관리하는 기능 다전공 중부인점 교과 판정은 뒤산 중부인정기준 및 조기졸업 신청 및 습인 판정은 위한 기초 점의 조기은 업신청기존관리 조기끝업은 신청환 수 있는 학성의 이수학기 이수학점 틈 기준음 관리하는 기능 산출정보 프로그램 복록 프로그럼명시서 퇴면점의서 사남자다 뉴얼 요구사항 분류 기능...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 인증하는 '무회민증'의 방지 해제들 유면하게 밭 수 빗도록 구축해야 참 대학 정보화 인력과의 협업업무지원) 및 기순이전은 할 수 있는 방안음 제시하여야 합 구축되는 모든 시스템은 체계적인 분석 설계 구청으로 대학의 관련 시스템과 언계 및 지원이 가능하도록 구축하여야 감 신규시스템 구축 시 다양한 [T친경에서 원활히 구동되 수 뒷도록 기능음 제공하여야 참 최적의 개발방법근음 제시하여 각 단계벌에 적용해야 하여 요스기술 단위의 산춘분음 제공하여야 참 운영 및 유지보수가 용이해야 하머 항후 확잠성률 고려하...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
# <표>
#
#  ◦ 향후 변화하는 발주기관의 특성을 고려하여 능동적이고 효율적인 시스템으로 구성하여야 한다.
#  ◦ 시스템은 향후 확장성을 충분히 고려하여 설계·적용되어야 한다.
#  ◦ 안정적, 효율적, 확장 가능한 최적 시스템으로 구축하며 사용자의 다양한 요구에 부흥하도록 구성하여야 한다.
#  ◦ 수작업을 최소화하고, 가능한 전산으로 모든 업무를 처리할 수 있도록 시스템을 구성하여야 한다.
#  ◦ 사용자의 편의성을 고려한 Work Flow 중심의 트랙 교육과정 개발 및 운영이 이뤄질 수 있도록 구성하여야 한다.
#  ◦ 트랙기반 교육...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 차세대 학사생점시스템 밑반생정시스템, 면구포님 (2} 캠메밑시스 템(2 학습관리시스템(LMS) KUchive KUSEUM MRO시스템 (구매대뱀y(2) 컴상관리시스템 성과-관리시스템 모바밑 놈합자 그룹데어(전자악재 포함) 금간관-리늄합시스템 경령소계시스템 공작기기시스템 SK미래관  여막시스템 모바밀좌-석배정자(서울) 모바밀좌-석배정-(세쪽} 경려개밥시스템(서움) 경려개발시스템(세3{2} 도서관콤페이지(서움 중앙도서관} 도서관흉페이지 (서움 의학도서관} 도서관콤페이지(세총 학순정보원} 규정관리시스템 셋...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 나. 시스템 현황
#   ○ 시스템구성도
#
# <그림>
#
#    ○ H/W 운영 현황
#
# <표>
#
#
#  ○ 관련기반 소프트웨어 현황
#
# <표>
#
#
# <그림>
#   ○ 응용시스템 아키텍쳐
#
#   ○ 업무포털종합정보시스템
#     - 한국생산기술연구원 기간계 시스템으로, 인사, 급여, 재무, 예산, 연구관리, 기업지원, 출장, 총무 등 전사 자원 관리 및 운영 시스템
#
# <업무 메뉴 및 전자결재 운영 현황 (2022.12.31.기준)>
#
# <표>
#
#     * 연구관리, 기업지원, 재무, 인사, 급여, 구매조달, 지재권 등 19개 업무시스템 운영 中
#  ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 성능 요구사항(PER) 요구사항 분류 성승 R구사방 요구사항 번호 PER-UDI 요구사항 명칭 성승P건 정의 성승P건 밑반사람 성습요건 일반 기촌 인프라 장비  슬부선과의 보환성과 성능 보장 기 구축되어 서비스 중인 모든 음용 프로그램의 안정성과 성능은 보장해아 시스템어 대란 성능 눈석은 실시하고 결과 및 기신방만은 저시하여야 탑 시스템의 만정적 문명은 위하여 서비스 [고각 오른 전주와 안정회   기간어 뉴님 틈 시스템 환경은 최적화하고 운영 어끌리켜이선 및 각종 슬부선의 요구 업그레이드 및 시스템 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 시스템은 개발 연습하여 지원활 있어이 합 프로적트의 공플모습과 험상관리 슬투선이 묘율적으로 연습되어 바 포작업 속도에 문제가 없어이 합 신규 험상관리 시스템 도입 시 기촌 슬투선의 데이터  다이그러이선  작업이 도합되어이 합 기촌 시스템의 소스 변경녀먹 PMS 히스토리분 신규 시스템에서 파민관 있어이 합 배구 WAS의 재기둥 명령어가 없음 경우 자동배포금 뒤히  재기둥 스크럴트 개발 지속적 농합 바포(CCD) 기능음 포함하여  기발자 기발서버 환경 테스트 서나 환경  운험서버 환경 등음 구축하여...

# %%
# Example Query 3 based on extracted text
if qa_chain and processed_documents:
    # Look for content related to the third HWP file (한국생산기술연구원)
    hwp3_doc = next((doc for doc in processed_documents if '한국생산기술연구원' in doc.metadata.get('파일명', '')), None)
    if hwp3_doc:
        # Formulate a query based on likely content (e.g., system overview, purpose, or scope)
        query = "한국생산기술연구원의 EIP3.0 고압가스 안전관리 시스템 구축 용역의 사업 개요를 설명해 주세요."
        response, query_time = time_rag_query(qa_chain, query) # Use the timing function

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds") # Print the execution time
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...") # Print a snippet of the source chunk
    else:
        print("Could not find processed document for 한국생산기술연구원 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 한국생산기술연구원의 EIP3.0 고압가스 안전관리 시스템 구축 용역의 사업 개요를 설명해 주세요.
#
# Generated Response:
# EIP3.0 고압가스 안전관리 시스템 구축 용역은 다음과 같은 사업 개요를 가지고 있습니다.
#
# 1. **추진배경 및 필요성**:
#    - **안전사고 증가**: 고압가스 취급 부주의로 인한 연구실 사고가 빈번하게 발생하고 있으며, 이는 인명 피해와 연구 기기 손상을 초래하고 있습니다.
#    - **법적 요구사항**: 안전 관리에 대한 법적 요구사항과 규제가 강화되고 있어, 이를 준수하지 않을 경우 법적 책임과 벌금이 부과됩니다.
#    - **연구 환경 보호**: 연구원들의 건강과 안전을 보호하고, 안전한 연구 환경을 제공하기 위해 체계적인 관리 시스템 구축이 필요합니다.
#
# 2. **사업 범위**:
#    - 원내에서 관리하는 화학물질 운영현황의 통계 정보를 제공하는 시스템 구축.
#    - 고압가스 화학물질의 정보와 판매허가 업체를 관리하기 위한 시스템 구축.
#    - 고압가스 화학물질의 구매부터 안전성 검토 과정을 진행하기 위한 시스템 고도화.
#    - 연구실과 법적 준수 사항을 관리하기 위한 시스템 고도화.
#    - 화학제품 폐기·회수를 관리하기 위한 시스템 고도화.
#
# 3. **기대효과**:
#    - **연구실 안전 확보**: 고압가스의 안전한 관리를 통해 연구원들의 생명과 신체를 보호하고, 연구실 내 안전사고를 예방하는 것을 목표로 합니다.
#    - **법적 준수**: 정부 및 관련 기관의 규제와 법적 요구사항을 준수하여 법적 문제를 예방하고, 안전 관리 수준을 법적 기준 이상으로 유지합니다.
#    - **효율적 관리 시스템 도입**: 고압가스의 사용, 저장, 폐기 등을 체계적으로 관리할 수 있는 시스템을 도입하여 효율성을 높이고, 안전 관리를 용이하게 합니다.
#
# Query Time: 12.43 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
#
# 2024. 08.
#
#
#
# <표>
#
#
#
# <표>
#
#
#
# 목 차
#
#
# <표>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1. 사업 개요
#
# 가. 추진배경 및 필요성
#  ㅇ 안전사고 증가
#    - 고압가스 취급 부주의로 인한 연구실 사고가 빈번하게 발생하고 있으며, 이는 인명 피해와 연구 기기 손상을 초래함
#  ㅇ 법적 요구사항
#    - 안전 관리에 대한 법적 요구사항과 규제가 강화되고 있으며, 이를 준수하지 않을 경우 법적 책임과 벌금이 부과
#  ㅇ 연구 환경 보호
#    - 연구원들의 건강과 안전을 보호하고, 안전한 연구 환경을 제공하기...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 전자결재 연놈 규정관리 시스템   공간관리농합시스템   전자계약시스템   힘상관리 및 전산R청사람 관리 시스템 늑에서 생성하는 맘식의 전자결재 연놓이 가능하여이 합 탁사방 정시스템   일반행정시스템   연구시스템 틈 교내;외 시스템에서 기존에 전자결재 연놓이 되고 F는 내외온 모두 연놓이 되어이 합 전자결재 판결 주 거시관어   공지하는 업무 유험은 분투히고 자동되하여다 뱀정시스템어서 기존어 생성민 담식 연겨시 HTML면계 틈 기존로직은 재사용 감 수 F는 밤만문 제시 및 적용하여이 밥 전자렌재 현합...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# 라. 기타사항
#   ○ 상기 추가 제안내용 외에 이 사업에 반드시 필요하다고 판단되는 사항을 제시할 수 있다.
#   ○ EIP 업무포털 종합정보시스템 관련 산출물 및 기타 필요 산출물을 참고할 수 있으며, 신청자에 한하여 산출물 열람 가능
#    ▪ 열람시기 : 제안서 공고일부터 접수마감전일까지
#    ▪ 열람장소 : 우리 원 디지털행정추진실 또는 지정장소
#    ▪ 열람산출물 : EIP 관련 주요 산출물
#    ▪ 열람방법
#      - 열람일 전일까지 사전예약한 자에 한하여 열람
#      - 열람자는 소속사 신분증 제시
#      - 열람방법...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 5. 정보기술아키텍처 적용방안
#  ❑ 필수 사업산출물 등록·관리
#   ❍ 사업 수행업체는 사업수행과정에서 <별표>의 필수 사업산출물 등을 포함한 사업성과물을 사업종료 전까지 정보화사업관리시스템(http://eaitg.nrf.re.kr)에 등록하여야 함
#   ❍ 정보시스템이 유지보수 또는 기능개선 등으로 변경되었을 경우에는 해당 사항 발생 시 기 등록된 관련 산출물을 정보화사업관리시스템(http://eaitg.nrf.re.kr)을 통해 변경ㆍ등록하여야 함
#  ❑ 기본 원칙
#   ❍ 정보시스템에 적용되는 기술은 표준화된 개방형 기술을 사용하는 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 성능 요구사항(PER) 요구사항 분류 성승 R구사방 요구사항 번호 PER-UDI 요구사항 명칭 성승P건 정의 성승P건 밑반사람 성습요건 일반 기촌 인프라 장비  슬부선과의 보환성과 성능 보장 기 구축되어 서비스 중인 모든 음용 프로그램의 안정성과 성능은 보장해아 시스템어 대란 성능 눈석은 실시하고 결과 및 기신방만은 저시하여야 탑 시스템의 만정적 문명은 위하여 서비스 [고각 오른 전주와 안정회   기간어 뉴님 틈 시스템 환경은 최적화하고 운영 어끌리켜이선 및 각종 슬부선의 요구 업그레이드 및 시스템 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 산물정보 설치걷과서   기술지원 화약서 요구사함 분유 시스템장비 요구사방 요구사항 번호 ECR-DOg 요구사항 명칭 API 시스템 정의 API 시스템에 대한 R구사방 요구 일반 R건 사랑 본재 본고어서 사용중민 밤식보다 처계직민 AFI 기밭 표준단이 F는 경무 상세 세부 제시하여이 밥 설명 너용 API시스템어서 사용중인 더이터의 스키다가 변경되는 경무 변경사람문 적용하여이 밥 시스템간 데이터 연계가 필구단 경무 API름 주가람 산물정보 설치결과-서   기술지원   화약서 요구사합 문류 시스템장비 R구...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 KORKA UVER SITY 제안요청 내용 제안요청 개요 공통사항 본 너용은 본 사업과 관련된 모든 세부사업어 대하여 공통으로 적용감 0 본 제만요 점서의 요구사함 목록은 우리 대학이 필수로 R구하는 사함률 담고 있으며 본 사업의 무적튼 중실히 달성하기 위해 요구사람  국1에서 제시하는 각 기능 요구 외에도 편 점보시스템예서 문지되는 기능은 모두 구i되어야 살 0 분석 단계의 요구사람 분석 결과어 따라 개발 붙문은 조점팀 수 있몸 차세대 시스템 구축에 따라 기존 시스템 춤 어른리키이선 및 데이터 속먼어서 면계된 모든 시스...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 작 성 항 목 작 성 방 법 업무개발에   적용활 방법금 질차 및 기법의 활용방안분 제시하 여야 하머   적용밤법큰의 검험름 기순하다 개발밤법로 개발방법큰어 따른 제출할  산춘분의 종류 및 내역 제줄시기름 기순하다. I  기술 및 기능 시스템은 하드웨어부문 소프트웨어 부문 기티부문 등으로 구분 하여 각 구분별 구성장처의 사양 기능   민종내역 등록 제시하고 시스템장비 요구사람 도입장비의 설치 및 공급계획  도입 잠비의 하자보수 방만큼 순하여야 한다 방법금 및 분석 도구름 통하여 구체적인 내용으로 분석...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 공간관리시스템 (아키버스) radejs Thingwiarx 건독밥 정보 공시전합비교시스템 평기밥 경업습겨시스템 정보가밭번 고려대 처용시스템 정보가밭번 고려대 강사믿봉지원시스템 정보가밭번 고려대 교원조 범지원시스템 정보가밭번 수집기록관리시스템 바율관 대량머 일발습시스 템(EMS) 정보민프라팀 스크같다스터 키류니커디선팀 Javascrpt nade 5, express]s 연구실만전관리시스템 만전관리님 flurter vuejs 면구포님(RMS) spring 산학감염님 면구자네트 뭐크 KURN) 9구진공님 면...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 인증하는 '무회민증'의 방지 해제들 유면하게 밭 수 빗도록 구축해야 참 대학 정보화 인력과의 협업업무지원) 및 기순이전은 할 수 있는 방안음 제시하여야 합 구축되는 모든 시스템은 체계적인 분석 설계 구청으로 대학의 관련 시스템과 언계 및 지원이 가능하도록 구축하여야 감 신규시스템 구축 시 다양한 [T친경에서 원활히 구동되 수 뒷도록 기능음 제공하여야 참 최적의 개발방법근음 제시하여 각 단계벌에 적용해야 하여 요스기술 단위의 산춘분음 제공하여야 참 운영 및 유지보수가 용이해야 하머 항후 확잠성률 고려하...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 보안 분야 적용계회 / 겉과 부분적용 /미적 부분 해당없  몹시 사유 적용 적용 적용 대체기술 기본 지침 정보시스템의 보안은 뒤하여 뒤험분석은 놓반 보안 계회문 수입하고 이분 적용하여이 반다 이는 보시스템의 구족 문명과   관련철 "서비스 집리 전달 "근랫품 및   기반구조"  요소기술" "민터페 이스 및 농합' 분아큼 모두 포함하여야 안다 보안이 5요만 서비스 및 데이터의 집근에 곤련린 사용자 민혼은 공민전자서명 또는 셈정전자서명은 기반으로 하여마 한다 네트뭐크 장비 및 네트뭐크 보안장비어  맘의 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 요구사항 번호 SFR-공놈-UCG 요구사항   명칭 업무 승민 적용 및 전자결재 연계 정의 공용 업무 승인 적붕 및 전자걸재  면계 기능 정의 0 업무 승인 및 전자결재 연놈 사용자 편의성 및 시스템 정합 성문 손합 고려하여 셈정시스템 각 업무빌 적용되는 업무 승인 또는 전자렌재 연놈 기능 구런 승민 직늄 업무의 경무 결재권자 지점 및 권단 부어 회수가 가능하다 탑 전자걷재 시스템과 유사히게 겉재 요점 승인 곁재진생 6민 곁저내력 환민 공담 눕이 가능하도록 구족 담당자 및 겉재자가 업무걷재 맡림...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# <그림>
#
#
# <그림>
#
#
# <그림>
#
#  다. 추진체계
#   ○ 구성도
#
# <표>
#
#   ○ 역할
#
# <표>
#
#
#  라. 추진일정(사업기간: 계약체결일 ~ 2024.12.27.)
#
# <표>
#
# 4. 제안요청 내용
#  가. 제안요청 개요
#   1) 사업명 : EIP3.0 고압가스 안전관리 시스템 구축 용역
#   2) 사업기간 : 계약체결일 ~ 2024.12.27.(5.5M/M)
#   3) 사업금액 : 40,000천원(부가세 포함)
#   4) 계약방법 : *제한경쟁입찰 / 협상에 의한 계약     *(입찰자격) 직접생산 소프트웨어 중소기업 사업자 및 소상공인(...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 플렉품 및 기반구조 분야 적용계회 /겉과 부분적용/미 적용시 사유 대체기술 기본 지침 정보시스템 운영어 사용되는 농신장비는 IPi와 IPy6가 통시에 원되는 장비름 채택하여야 안다. 하드웨어는   이기농간 연제가 가능하여이 하며 특정 기능문 수밤 하는 임버디드 장치 및 주변 장치는 해당 장치가 설치되는 정보시 팀과 소환성 및  화장점이 보장되어야 반다 서부 기술 지침 회상되의 밀티미디어 농신 H320~H324 H310 부가늄신: Val? 네트위크 H 323 Megac디(H.24리) 서내용(개방z...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 사업수험 참여자의 비인가 휴머용 저장장차USB CDIDVD 태분릿 등는 사업 수밤 잠소 정보시스템어 연결되어 사용 보가 산출정보 보안관리 계회서 보안서약서 요구사항 분류 보만 요구사방 요구사항 번호 SER-002 R구사함 명칭 프로직트 산촌분 보안관리 정의 프로직트 작업수뱀 및 산근분 노안곤리 사업수#든 뒤해 제공단 우리대학 자료의 복사 및 외부반트 금지 지공단 내부자료는 매밑 퇴근시 반밥 R맘 다만 비밀문서금 지외한 밑반문서논 잠금장치가 된 서류함에 보관가능 사업 수밤 자료외 외부 미처 지장 금지 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT R구사함 문류 프로직트곤리 R구사람 요구사항 번호 PMR-CJg R구사함 명칭 간정화 잘놈 수험 정의 관정화 기간 중 안정화 잘중 수청은 정의 시스템 만정화 참놈 수뱀 안정되 기간 중 발생하는 기능 변경 요구사항어 더해 영합도 분석 및 반영 가능어부분 검토하고 반영어 부분 발주기관과 험의하여 가능단 기능 개선 수뱀 법 지도 년경 및 시험시책 틈 업무환경 변리어 따 기능년경 사용자 및 문멩자의 R청어 따스 정보시스템 기능기신 요구 정보시스 템의 사엇 편의성은 위란 지속직인 개신 참놈 수밤 사랑 사용자 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 그룹렉어(GW) 요구사항 분류 기능 R구사방 요구사항 번호 SFR-GW-UDi 요구사항 명칭 전자증재 정의 전자증재 기능 점의 전자결재 공놈 현재 방정시스템어서 생성하는 전처 담식의 전자결재 연놈 직문 차세대 시스템에서 주가다 담식 주가 Nari-ActiyexHTML5기반 많어디터 제공 뵙단글기단기 면계 뱀정단전부 전자문서 규격 공공기관  유습표준 및 기록관리 #준문 존수한 시스템 구족 국가# 준 KS X IsO 16175-31 문련정보 전자사무관경에서 기록어 더한 원 및 기능유건 제교부 법무시...

# %%
# Example Query 4 based on extracted text
if qa_chain and processed_documents:
    # Look for content related to the fourth HWP file (인천광역시)
    hwp4_doc = next((doc for doc in processed_documents if '인천광역시' in doc.metadata.get('파일명', '')), None)
    if hwp4_doc:
        # Formulate a query based on likely content (e.g., system purpose, users, or key features)
        query = "인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 무엇인가요?"
        response, query_time = time_rag_query(qa_chain, query) # Use the timing function

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds") # Print the execution time
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...") # Print a snippet of the source chunk
    else:
        print("Could not find processed document for 인천광역시 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 무엇인가요?
#
# Generated Response:
# 인천광역시 도시계획위원회 통합관리시스템 구축 용역의 용역 개요는 다음과 같습니다:
# - 용역명: 도시계획위원회 통합관리시스템 구축 용역
# - 기간: 착수일로부터 180일
# - 사업비: 금150,000,000원 (VAT 포함)
# - 계약방법: 제한경쟁입찰(협상에 의한 계약)
#
# Query Time: 5.98 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# <그림>
#
#
#
#
#
#
#
#
#
#
# <표>
#
#
#
# <표>
#
#
# <표>
#
#
# <표>
#
#
#  1. 과 업 명: 「도시계획위원회 통합관리시스템 구축 용역」
#
#  2. 용역개요
#   ○ 용 역 명: 도시계획위원회 통합관리시스템 구축 용역
#   ○ 기    간: 착수일로부터 180일
#   ○ 사 업 비: 금150,000,000원 (VAT 포함)
#   ○ 계약방법: 제한경쟁입찰(협상에 의한 계약)
#
# <표>
#
#
# <표>
#
#
# <표>
#
#
#  3. 과업배경 및 목적
#   ○ (수작업에 의한 업무의 복잡성) 여러 단계의 위원회 운영업무를 수작업으로 처리, 업무의 복잡성...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 역량기반 교과욕 운영체계 정보화 개선 감의계학서 상 역량항묵 입력스 서움캠퍼스 역량으로만 구축하여 세증캠퍼스 적용 불가 2024년부터 문명되는 CQI보고서지 현재는 역량관리시스템 KUchive KUSEUM 에서 관리하고 있어 학사행정시스템으로 기능 이관 필요 학상들의 수감소감 및 그에 대한 사후조치튿 현재는 역실로 관리 "교마 비교로 #품 재광 마 | 싶물?-펴화 'n질a하 팬급 교% 입 KMUzk cFa m콤화속 불대 여어꺼기 규;기철 기미 고민심기 터가 학기 요새 (col) 대학 부심여람 시사 전...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
# □ 트랙제 교육과정 운영프로그램 개발
#  ◦ 트랙제 기반 교육과정 운영
#      - 트랙제 기반 교육과정 운영 단계의 관리 절차에 대한 개선사항 도출 및 구현
#  ◦ 트랙제 기반 교육과정 평가 및 통계관리- 트랙 교육과정 운영에 대한 통계현황 조회 및 출력 기능 구현
#      - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현
#      - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현
#  ◦ 기타 사항
#      - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발
#
# □ 학사 정보시스템...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# ○ 사업 추진에 있어 계약서와 제안서, 제안요청서 등에 포함되지 않는 일반적 사항은 인천광역시와 협의하여 결정한다.
#   ○ 제안내용은 꼭 필요한 사항을 위주로 간단명료하게 작성하며 내용 중 “할 수도 있다”, “고려하고 있다” 등의 의지가 불투명한 표현이 사용된 경우에는 평가에서 불이익을 받을 수 있다.
#   ○ 제안서는 계약체결 시 계약서와 동일한 효력을 가지며 이를 유의하여 작성하여야 함
#   ④ 제안서 목차 및 작성 방법...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 그 기능 요구사항 공통 요구사항 분류 기능 요구사방 요구사항 번호 SFR-공놈-001 요구사항   명칭 기초정보관리 정의 공농 기준정 토관리 기능 정의 공습고드관리 대략 시스템 전반어서 사분되는 공습의 코드 등록/ 작제변경 관리 기능 구런 공플코드관리 고등교육소계코드관리 탁교코드관리 조직구드관리 무편번로 관리 공플코드 표준화 공플코드는 추가 변경이 용이하다 하다 생명주기분 관리하여 시점볕 조리가 가능하도록 설계 공플코드는 업무담당자 담당부 세가 해당 코드분 관리관 진도록 구족되어이 밥 공농코드는...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
#
#
#
# <표>
#
# <표>
#
#
#
#
# 【서식 제1호】
#
# 접    수    증
#
#
#   상기 업체는 인천광역시에서 시행하는 『도시계획위원회 통합관리시스템 구축 용역』입찰과 관련하여 붙임과 같이 서류를 제출하고 제안 공모에 참가할 것을 신청합니다.
#
# 2024년    월    일
#
# <표>
#
# 인천광역시장 귀하
# ------------------------------    (인)    ----------------------- 절 취 선
#
# 접    수    증
#
#
# <표>
#
# 「도시계획위원회 통합관리시스템 구축」용역 제안 공모 접수하였음을 확...
# --- Source: /content/drive/MyDrive/Data/files/한국연구재단_2024년 대학산학협력활동 실태조사 시스템(UICC) 기능개선.hwp (Chunk Index: N/A) ---
# 6. 기대 효과
#  □ UICC의 효율적 관리 체계를 구축하여 실태조사를 안정적으로 운영
#  □ 실태조사 항목 지침 변경사항을 반영하고 시스템 기능을 개선하여 사용자 편의성 도모
#
#
# <표>
#
#
# <표>
#
# 1. 추진목표
#  □ UICC 시스템 기능개선을 통해 이용 편의성 개선
#  □ UICC 시스템 운영 지원을 통해 안정적으로 실태조사 추진
# 2. 추진전략
#  □ 능력과 경험이 풍부한 전문사업자를 주관사업자로 선정
#   ㅇ 시스템 구축에 대한 경험이 풍부하고 인력관리, 품질관리 및 유지관리 능력이 우수한 업체를 주관사업자로 선정하여 사업 진행
#  ...
# --- Source: /content/drive/MyDrive/Data/files/한국생산기술연구원_EIP3.0 고압가스 안전관리 시스템 구축 용역.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
# <표>
#
#
#
# <표>
#
#
# <표>
#
#
#
# <표>
#
#
#
# <표>
#
#
#
# <표>
#
#
# 다. 정보기술아키텍쳐 적용방안
#   1) 필수 사업산출물 등록·관리
#   ○ 사업 수행업체는 사업수행과정에서 <별표>의 필수 사업산출물 등을 포함한 사업성과물을 사업종료 전까지 범정부EA포털 (https://www.geap.go.kr)에 등록하여야 한다.
#   ○ 정보시스템이 하자보수 또는 기능개선 등으로 변경되었을 경우에는 해당 사항 발생시기에 등록된 관련 산출물을 범정부EA포털 (https://www.geap.go.kr)을 통해 변경․등록하여야 한다....
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# <표>
#
#  1. 추진목표
#   ○ 각 실국 내 도시계획관련 위원회 통합관리·운영·지원 시스템 구축
#   ○ 위원회 관련 자료에 대한 관리 및 활용 체계 구축
#   ○ 위원회 아카이브 구축 및 연계를 통한 위원회 심의지원시스템 구축
#
# 2. 추진체계
#
# <표>
#
# 3. 추진일정
#
# <표>
#
#   ※ 추진일정은 “발주기관” 와 “계약상대자”의 상호협의를 통해 변경할 수 있음.
#
#  4. 추진방안
#   ○ 긴급발주에 관한 사항 : 해당없음
#   ○ 분리발주에 관한 사항 : 해당없음
#
#
# <표>
#
#  1. 일반사항
#   ○ 본 사업은 󰡔도시계획위원회 통합관리시스...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 인사 구마 , 공사 학사 틈 학내 계막건 전체 직용 전자계약 곤련 계약서 주서식}부서식}관련서뷰 관리 계약 유형밭 사전 정의터 계약 서식에 계약 정보 작성 계약} 서명 정보 전습 및 진행상태 곤리 계약업무  진험 시 각 단계마다  도달  전자걸지와   연놓하여   겉재 전자계막 시스템 진험상태 관리 계약체걷이 판료민 계막서 조리 및 출러 기능 계약만큼밑 전 자 동경신 대상 조리 및 맡림 거래 업체에서 거래업체 점보 및 계약담당자 정보 뒤원회 리의복 날인 비계약건 전자서명 곁재문서 기단 및   걷재신 ...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 2024년      월      일
#
#
#                           주  소 :
#                           상  호 :
#                           대표자 :                           (인)
#
#
#
#  인천광역시장 귀하
#
#
#  【서식 제6호】
# 청렴계약 이행서약서
#
#   당사는「부패없는 투명한 기업경영과 공정한 행정」이 사회발전과 국가경쟁력에 중요한 관건이 됨을 깊이 인식하며, 국제적으로 OECD 뇌물방지 협약이 발효되었고, 부패기업 및 국가에 대한 제재가 강화되는...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 관리자관리 포털 시스템 관리자 등록 및 변경 관리 기능 구런 관리자 농합계정관리(불합정보시스템 공창기능) 곤리자 승인 권반 곤리자 IP관리 곤리자 이력 곤리 틈 현재 포닐 관리자기늄 재구런 및 신규 관리 필요 사람 구런 산출정보 프로그램 복록; 프로그럼명시서   회면정의서   사용자매뉴벌 틈 요구사항 분류 기능 요구사방 요구사항 번호 SFR-포닐-007 요구사항   명칭 섬정시스템   면계 서비스 정의 섬정시스템   면계 서비스 정의 뱀정시스템 견계 서비스 제공 밤식 학사밤정시스템 회면 3 (학생 교...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# <표>
#
# 가. 도시계획기사 자격 보유율 점수 산정 방법은 다음과 같다.
#
# <표>
#
# 도시계획기사 자격증(한국산업인력공단 발급-사본 제출) 보유 인원수는 현재 대표사에 6개월 이상 재직한 자로 함.(입찰공고일 기준 4대 보험(「고용보험법」에 의한 고용보험, 「국민건강보험법」에 의한 국민건강보험, 「국민연금법」에 의한 국민연금, 「산업재해보상보험법」에 의한 산업재해보상보험에 가입한 증거서류 중 1개의 가입자 증명원 제출)
# 나. 계산결과의 소수점 처리는 다섯째자리에서 반올림을 한다.
# 다. 본 과업은 도시계획업무에 대한 전문성과 공인된 실...
# --- Source: /content/drive/MyDrive/Data/files/인천광역시_도시계획위원회 통합관리시스템 구축용역.hwp (Chunk Index: N/A) ---
# 4. 과업의 범위
#   ○ 시스템 구축 대상 위원회
#     - 대상(2개) : 도시계획위원회, 도시·건축공동위원회
#       ※ 위원회 운영확대 및 시스템 고도화 방안 제시
#   ○ 운영시스템 구조 설계 및 구축 부문
#     - 위원회 운영을 위한 사용자별 권한 및 기능 구축
#     - 위원회 개최 준비(개최 등록, 안건 등록, 회의소집, 자료 배포 등)를 위한 기능 구축
#     - 위원회 심의 운영(회의 진행, 안건 설명, 안건 심의 등) 지원을 위한 기능 구축
#     - 위원회 개최 후 결과보고 및 후속조치 등을 위한 기능 구축
#  ...

# %%
# Example Query 5 based on extracted text
if qa_chain and processed_documents:
    # Look for content related to the PDF file (고려대학교)
    pdf_doc = next((doc for doc in processed_documents if '고려대학교' in doc.metadata.get('파일명', '')), None)
    if pdf_doc:
        # Formulate a query based on likely content (e.g., project background, scope, or goals)
        query = "고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경을 설명해주세요."
        response, query_time = time_rag_query(qa_chain, query) # Use the timing function

        print("Query:")
        print(query)
        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds") # Print the execution time
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} (Chunk Index: {doc.metadata.get('chunk_index', 'N/A')}) ---")
            print(doc.page_content[:300] + "...") # Print a snippet of the source chunk
    else:
        print("Could not find processed document for 고려대학교 to generate query.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query:
# 고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경을 설명해주세요.
#
# Generated Response:
# 고려대학교 차세대 포털·학사 정보시스템 구축 사업의 추진 배경은 다음과 같습니다:
#
# 1. **교육 환경의 급격한 변화**: 인구 감소와 코로나19 팬데믹으로 인해 교육 환경이 변화하고 있으며, 인공지능의 활용 등으로 대학이 사회-기술 변화에 직면하고 있습니다.
#
# 2. **분산된 시스템 및 데이터 통합 요구**: 급변하는 교육 환경 속에서 정보화 요구가 증가하고 있으나, 기존의 노후화된 학사 시스템이 업무마다 분산되어 있어 시스템 통합에 대한 필요성이 커지고 있습니다.
#
# 3. **데이터 기반 대학 경영 지원 개선**: 분절된 부서 시스템 간 정보 연계 미비와 정보화 표준 부재로 인해 경영 현황 파악 및 의사결정에 한계가 발생하고 있습니다.
#
# 4. **사용자 정보 서비스 접근성 개선**: 교내 구성원에게 제공되는 포털 서비스의 정보 접근성과 유용성에 대한 개선 요구가 상당히 높습니다.
#
# 5. **대학 경쟁력 강화 및 전략 목표 달성 지원**: 노후화된 시스템의 차세대 구축을 통해 정보 서비스 품질을 강화하고, 대학의 교육 시스템 경쟁력을 확보하고자 하는 목표가 있습니다.
#
# Query Time: 9.73 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024. 7. 07 aE 고려대학교 KOREA UNIVERSITY 본 자고; 게민내공의 신편움 취한 "포자고로 부거으로 '년부지 사용타;  형위: 구립-
# 고려대학교 ROa UIVER SITY 목   차 사업개요 1. 사업 개요 2 사업 배경 3. 사업 범위 :. 기대 증과 I. 현황 및 문제점 1. 일반 된참 . 2 점수화 된참 문제점 및 개선방방 I. 사업 추진방안 1. 추진 욕표  2 추진 밀정 3. 추진 체계 IV. 제안...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
# □ 트랙제 교육과정 운영프로그램 개발
#  ◦ 트랙제 기반 교육과정 운영
#      - 트랙제 기반 교육과정 운영 단계의 관리 절차에 대한 개선사항 도출 및 구현
#  ◦ 트랙제 기반 교육과정 평가 및 통계관리- 트랙 교육과정 운영에 대한 통계현황 조회 및 출력 기능 구현
#      - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현
#      - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현
#  ◦ 기타 사항
#      - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발
#
# □ 학사 정보시스템...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 가  포털시스템 모털 화면 이중관리로 인한 유지보수 어려움 현재의 포털 서비스 구런 형태는 메뉴화면 수정 시 포털의 데뉴화면과 해당하는 학사행점 일반행점시스템의 메뉴 화면블 이중으로 관리해야 하는 구조 인쇄 그미느 CS고딩 서J녀더 서금히고 너o리 < FGY 기공년 코맙 나타다 '어어니 시리고리 V하보 7 압업 시스C} 기* 349 더료 믿어 j다 기하의 수없9 7살" 비미 - 만생 #고 입터 F예7 ' 새Epu 여시로: 어멘니드 피니다리 콤보는 포I다B여 일고 어부느 "@nP여 이어서 그 개터 DB...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 첫봇 헌 햇봇 고도화 필요 0 i차 첫봇 사업들 통해 도출린 사용자 요구 반영 필요 교원 직원  세중캠퍼스 학생까지 대상블 확대한 햇봇 시스템 구축 필요 교수 사용자의 교육 연구 관련 다양한 문의에 대한 용답 규정과   연계하여 사용자의 문의 나용에  대한 용답 및 근거가 되는 관련 규정 자규 문서 등음 같이 제공찰 수 윗도록 구축 1차 햇봇 사업 범위 (상세 내용은 사업 착수 후 공유) 첫못시스템 구축(질의응답 GPT 기반 첫봇 구현) 질의용답 기반 GPT기반 규정학습 햇봇 오른 쨌못 시법오든...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 정보화 현황 가 주요 정보시스템 현황 및 사업 대상(롭페이지 제외) 서비스 구분 정보시스템 개발프로그램 대상 운영부서 학사정보시스템 {AlM5) Fr "PrPulder 정보가 밭팀 수감신청시스템 Jervlet도 JSP; Ajax 정보가밭번 모바일수감신청I 학부모 성적조회, Jervlet도 JSP; Ajax 정보가 밭팀 금학기 공시 성직주리 합격자 발표 Servlets 정보가밭번 학직시스템(구} 학시밥 교육정보노페이지 CMs 학사팀 입학전-기회팀 입학시스템 FDerBuilaer 입학전 형관리 학사 LM...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 사업 범위 가. 음용SW개발 고려대학교 차세대 포털 학사 정보시스템 구축 사업 정보시스템 주요내용 비고 불합로그민 농합 지능림 검약 마이데이지 공지 알림 밑침관리 커유니티   거시관  사용자번 정보서비스 뒤짓   면계 서비스(입머밑 셋봇 전자걷재, 학사 향점 서비스) 틈 학생(은업생포밤) 교직원 , 면구런 틈 녀부 구성원 [상 구I 학생 교수 틈 신문번개 인밭 주요 정보 제공 학사) 챔점 연구 시스템의 주요 기능 직접 접근 개민화 포털시스템 뒤짓 개인화-SSO기즌 보유 활용} 간편민층 2차인중적...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 2 제안서 작성 유의사람 242 3. 제안서 국자 및 작성방법 242 248-297
# 고려대학교 KORKA UVER SITY 사업 개요 1. 사업개요 사업명: 고러대학교 차세대 포털 학사 정보시스템 구속 사업 나. 사업기간: 계약일로 부터 24개원 이내 다. 무상유지보수기간 : 사업종로 일로부터 12개월 라. 사업데산 : 11,270,000,000원 (VAT 포함 3년 분합  지급) 2024학년도 약 3096 지급 2025학년도 약 4096 지급 2026학년도 약 3096 지급 마 입찰 및 계약 방법:...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
#
#
#
#
#
# 2024. 10.
#
#
#
#
# <그림>
#
#
#
# <표>
#
#
#
#
#
#
# <그림>
#
#
# <표>
#
#
#
# <표>
#
#
# □ 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 -
#              트랙운영 학사정보시스템 고도화
# □ 사업예산 : 130,000,000원 범위 내 (VAT 포함)
# □ 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)
#   * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음
# □ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)
#
#
#
# <표>
#
#
# 학사제도･제...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 설명 이뉴가 되는 업무의 재설계 및 정보화 밤만 제시{BPR 업무 프로서스 재설계 [상 업무는 ISP어서 탁사점점 전반어 걷쳐 도출권 업무 프로세스 재설계 대상문 기준으로 하머 주요 대상 업무는 아래와 같음 학과 흩업기준 R건과 정보화 정도 분석 및 차세대 정보화 개선 방안 대학원번 입시-학적생섬 시점에 따른 대학원생 정보시스템 사용 이수 및 개신 방만 도츠 {대학원 입시-학적 전반 프로세스 점검} 재설계) 장학금 곤리 체계 및 장학 주천신점-선발 놈계  전반의 점보화 현상 밤만 (한국장학재단 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 플렉품 및 기반구조 분야 적용계회 /겉과 부분적용/미 적용시 사유 대체기술 기본 지침 정보시스템 운영어 사용되는 농신장비는 IPi와 IPy6가 통시에 원되는 장비름 채택하여야 안다. 하드웨어는   이기농간 연제가 가능하여이 하며 특정 기능문 수밤 하는 임버디드 장치 및 주변 장치는 해당 장치가 설치되는 정보시 팀과 소환성 및  화장점이 보장되어야 반다 서부 기술 지침 회상되의 밀티미디어 농신 H320~H324 H310 부가늄신: Val? 네트위크 H 323 Megac디(H.24리) 서내용(개방z...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 현재의 전자결재 시스템은 포털 내부에 개발 형태로 구죽 에디터 노후화 공문작성 및 발씀 시 오류 발씀 등으로 업무 불편블 초래 20여년간 데이터 축적으로 인한 전자결재   속도저하 문제 해결 필요 손구선 도입 형태의 전자결재 시스템 구축 크론 멋지 사파리 등 멀티스라무저들 지원하는 문서 편집 기능 기록분관리시스템과  면계 가능한   전자문서 관리 기능 구축 사용자 편의성 및 시스템 관리 #울성블  고려한   행정시스템   기만양식의 업무승 민 또는 전자결재   연계기능 구축 구성원 간 협업기능 고도화...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa UIVER SITY 내 외부시스템 면계 표준 데이터베이스 모델림 및 설계표준 오류 및 사용자 메시지 제공 표준 산출분 작성 개밭 방법률 표준포님 및 모바밑 문령은 뒤' 말림서비스(공유정보 및 연제서비스 메뉴 림크 틈 와 선무뱀 업무간 연계분 위한 업무결재 처리 표준 기늄 틈 프로그래망 스타일든 #준회하고 소스 코드의 품질은 제고관 진도록 개발영역번 특성에 맞는 실제 예제가 포함단 표준 개발 가이드분 제공하여이 밥 프로그램 표준 가이드가 개밭 과정어서 실제적으로 준수틱 수 및도록 개밭 가이드 농합 개발도구치다E)의 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp (Chunk Index: N/A) ---
# <표>
#
#
#
# <표>
#
#  ◦ 향후 변화하는 발주기관의 특성을 고려하여 능동적이고 효율적인 시스템으로 구성하여야 한다.
#  ◦ 시스템은 향후 확장성을 충분히 고려하여 설계·적용되어야 한다.
#  ◦ 안정적, 효율적, 확장 가능한 최적 시스템으로 구축하며 사용자의 다양한 요구에 부흥하도록 구성하여야 한다.
#  ◦ 수작업을 최소화하고, 가능한 전산으로 모든 업무를 처리할 수 있도록 시스템을 구성하여야 한다.
#  ◦ 사용자의 편의성을 고려한 Work Flow 중심의 트랙 교육과정 개발 및 운영이 이뤄질 수 있도록 구성하여야 한다.
#  ◦ 트랙기반 교육...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 관리자관리 포털 시스템 관리자 등록 및 변경 관리 기능 구런 관리자 농합계정관리(불합정보시스템 공창기능) 곤리자 승인 권반 곤리자 IP관리 곤리자 이력 곤리 틈 현재 포닐 관리자기늄 재구런 및 신규 관리 필요 사람 구런 산출정보 프로그램 복록; 프로그럼명시서   회면정의서   사용자매뉴벌 틈 요구사항 분류 기능 요구사방 요구사항 번호 SFR-포닐-007 요구사항   명칭 섬정시스템   면계 서비스 정의 섬정시스템   면계 서비스 정의 뱀정시스템 견계 서비스 제공 밤식 학사밤정시스템 회면 3 (학생 교...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf (Chunk Index: N/A) ---
# 고려대학교 ROa Mtfr cT 인증하는 '무회민증'의 방지 해제들 유면하게 밭 수 빗도록 구축해야 참 대학 정보화 인력과의 협업업무지원) 및 기순이전은 할 수 있는 방안음 제시하여야 합 구축되는 모든 시스템은 체계적인 분석 설계 구청으로 대학의 관련 시스템과 언계 및 지원이 가능하도록 구축하여야 감 신규시스템 구축 시 다양한 [T친경에서 원활히 구동되 수 뒷도록 기능음 제공하여야 참 최적의 개발방법근음 제시하여 각 단계벌에 적용해야 하여 요스기술 단위의 산춘분음 제공하여야 참 운영 및 유지보수가 용이해야 하머 항후 확잠성률 고려하...

# %% [markdown]
# # Task
# Build an advanced RAG system using Langchain to answer questions based on 4 HWP files and 1 PDF file from "/content/drive/MyDrive/Data/files". The system should:
# 1. Load and process the specified HWP (using pyhwp or hwp5txt/hwp5html) and PDF (using easyocr) files.
# 2. Integrate metadata from "data_list.csv" with the documents.
# 3. Implement semantic chunking.
# 4. Utilize metadata filtering, increased top-k, MMR, and multi-query for improved retrieval.
# 5. Employ prompt engineering, adjust generation parameters (top-p, max_tokens), control answering tone/style, and maintain conversational context for enhanced generation.
# 6. Evaluate the system's performance using new example queries derived from the content of the selected files.

# %% [markdown]
# # Task
# Implement metadata filtering and conversational memory in the RAG chain and update the example queries to demonstrate these features.

# %% [markdown]
# ## Implement metadata filtering
#
# ### Subtask:
# Modify the retrieval process to allow filtering documents based on metadata.

# %% [markdown]
# **Reasoning**:
# Update the RetrievalQA chain creation to include metadata filtering capabilities in the retriever.

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.retrievers import ContextualCompressionRetriever
from langchain.retrievers.document_compressors import DocumentCompressorPipeline
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_transformers import EmbeddingsRedundantFilter
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers import MultiQueryRetriever
from langchain.prompts import PromptTemplate
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None

if OPENAI_API_KEY and vectorstore:
    llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY, temperature=0.3, max_tokens=1500, top_p=0.8)

    template = """다음 문서를 사용하여 질문에 답하세요.
    답변은 가능한 한 정확하고 간결하게 작성하세요.
    제공된 문서에 없는 내용은 언급하지 마세요.
    문서:
    {context}

    질문: {question}

    답변:"""
    QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

    # Update the base retriever to accept filters
    # The filter structure will be determined dynamically based on the query in later steps.
    # For now, we just modify the retriever to potentially use a filter.
    # Langchain's FAISS retriever supports filtering by metadata.
    # The filter needs to be a dictionary specifying the key and value to filter on.
    # Example: {"발주 기관": "한영대학"}
    # We will demonstrate filtering in the example queries in the next step.

    # We will create a base retriever that accepts a filter parameter in its get_relevant_documents method
    # However, the standard .as_retriever() method from FAISS doesn't directly expose a filter parameter
    # in this way for simple use with RetrievalQA.
    # A more direct way to integrate filtering with RetrievalQA is to pass the filter
    # in the query to the chain. Let's revert the retriever creation back to how it was,
    # and the filtering logic will be applied when invoking the QA chain later.

    # Reverting to the multi-query retriever without explicit filter in the retriever definition
    base_retriever = vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={"k": 10, "fetch_k": 20}
    )

    multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever=base_retriever,
        llm=llm
    )

    final_retriever = multiquery_retriever

    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=final_retriever,
        return_source_documents=True,
        chain_type_kwargs={"prompt": QA_CHAIN_PROMPT}
    )

    print("RetrievalQA chain created, ready for metadata filtering in query invocation.")

else:
    print("Skipping RAG chain creation due to missing API key or vector store.")
    qa_chain = None
# Out:
# RetrievalQA chain created, ready for metadata filtering in query invocation.

# %%
import time

def time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter=None):
    """
    Times the execution of a RAG query with optional metadata filtering,
    correctly applying the filter to the retriever's search_kwargs.

    Args:
        qa_chain: The RAG chain object.
        query (str): The query string.
        metadata_filter (dict, optional): A dictionary specifying metadata filter criteria.
                                          Defaults to None.

    Returns:
        tuple: A tuple containing the response dictionary and the execution time in seconds.
    """
    start_time = time.time()

    # Access the retriever within the QA chain
    # The exact path might vary slightly depending on the chain type and retriever wrapping
    # If using MultiQueryRetriever wrapped around a base retriever, we need to access the base retriever
    if hasattr(qa_chain.retriever, 'retrievers') and isinstance(qa_chain.retriever.retrievers, list):
         # This case might apply if using something like EnsembleRetriever or similar multi-retriever setups
         # For MultiQueryRetriever, the base retriever is usually accessed differently
         base_retriever = qa_chain.retriever.retrievers[0] # Assuming the first retriever is the base one
    elif hasattr(qa_chain.retriever, 'retriever'):
         # This is the case for ContextualCompressionRetriever and likely MultiQueryRetriever
         base_retriever = qa_chain.retriever.retriever
    else:
         # Direct retriever instance
         base_retriever = qa_chain.retriever


    # Temporarily modify the retriever's search_kwargs to include the filter
    original_search_kwargs = base_retriever.search_kwargs
    if metadata_filter:
        # Create a copy of original search_kwargs and add the filter
        modified_search_kwargs = original_search_kwargs.copy()
        modified_search_kwargs["filter"] = metadata_filter
        base_retriever.search_kwargs = modified_search_kwargs
        print(f"Applying filter: {metadata_filter}")
    else:
        # Ensure no filter is applied if metadata_filter is None
        if "filter" in original_search_kwargs:
             modified_search_kwargs = original_search_kwargs.copy()
             del modified_search_kwargs["filter"]
             base_retriever.search_kwargs = modified_search_kwargs
        print("No filter applied.")


    # Invoke the chain with the query
    # The search_kwargs are now set on the retriever itself
    response = qa_chain.invoke({"query": query})

    # Restore the original search_kwargs on the retriever
    base_retriever.search_kwargs = original_search_kwargs

    end_time = time.time()
    execution_time = end_time - start_time
    return response, execution_time

# Example Query 1 with Metadata Filter (Filter by '발주 기관': '한영대학')
if qa_chain and processed_documents:
    query = "이 사업의 추진 배경 및 필요성은 무엇인가요?"
    metadata_filter = {"발주 기관": "한영대학"}
    print(f"Query: {query}")
    response, query_time = time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter)

    print("\nGenerated Response:")
    print(response['result'])
    print(f"\nQuery Time: {query_time:.2f} seconds")
    print("\nSource Documents:")
    for doc in response['source_documents']:
        print(f"--- Source: {doc.metadata.get('source', 'N/A')} ---")
        print(f"Metadata: {doc.metadata}")
        print(doc.page_content[:300] + "...")
else:
    print("RAG chain or processed documents not initialized.")

print("-" * 50)

# Example Query 2 with Metadata Filter (Filter by '파일형식': 'pdf')
if qa_chain and processed_documents:
    query = "이 사업의 추진 배경을 설명해주세요."
    metadata_filter = {"파일형식": "pdf"}
    print(f"Query: {query}")
    response, query_time = time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter)

    print("\nGenerated Response:")
    print(response['result'])
    print(f"\nQuery Time: {query_time:.2f} seconds")
    print("\nSource Documents:")
    for doc in response['source_documents']:
        print(f"--- Source: {doc.metadata.get('source', 'N/A')} ---")
        print(f"Metadata: {doc.metadata}")
        print(doc.page_content[:300] + "...")
else:
    print("RAG chain or processed documents not initialized.")

print("-" * 50)

# Example Query 3 with Metadata Filter (Filter by '사업명')
if qa_chain and processed_documents:
    # Find an example 사업명 from the processed documents
    example_doc = processed_documents[0] if processed_documents else None
    if example_doc and '사업명' in example_doc.metadata:
        example_사업명 = example_doc.metadata['사업명']
        query = f"'{example_사업명}' 사업의 개요는 무엇인가요?"
        metadata_filter = {"사업명": example_사업명}
        print(f"Query: {query}")
        response, query_time = time_rag_query_with_filter_corrected(qa_chain, query, metadata_filter)

        print("\nGenerated Response:")
        print(response['result'])
        print(f"\nQuery Time: {query_time:.2f} seconds")
        print("\nSource Documents:")
        for doc in response['source_documents']:
            print(f"--- Source: {doc.metadata.get('source', 'N/A')} ---")
            print(f"Metadata: {doc.metadata}")
            print(doc.page_content[:300] + "...")
    else:
         print("Could not find an example document with '사업명' metadata for Query 3.")
else:
    print("RAG chain or processed documents not initialized.")
# Out:
# Query: 이 사업의 추진 배경 및 필요성은 무엇인가요?
# Applying filter: {'발주 기관': '한영대학'}
#
# Generated Response:
# 이 사업의 추진 배경 및 필요성은 다음과 같습니다:
#
# - 학사제도 개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공하여 취업문을 확대하기 위함입니다.
# - 트랙제 교육과정의 도입 및 운영을 통해 산업현장의 경쟁력을 강화하고, 기업 수요에 맞춘 교육과정 운영 및 활성화를 통해 교육과정의 내실화를 도모하고자 합니다.
# - 산업체 및 지역사회와 연계하여 현장실무형 인재를 양성하기 위한 체계적인 지원이 필요합니다.
# - 트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원하고, 교수자·학습자 중심의 교육환경을 조성하여 대학 교육의 가치를 구현하기 위한 시스템이 요구됩니다.
#
# Query Time: 7.00 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 정보시스템개발서비스(세부품명번호: 8111159901)로 발행된 것으로 유효기간 내에 있어야 함]를 소지한 업체 ④ 최근 3년 이내에 ASPNET으로 대학관련 종합정보/학생이력/역량시스템 구축 개발 수주가 단일건으로 1억원 이상 실적이 있는 업체  Windows Server, MS-SQL기반 ASPNET 개발환경에 구축 실적이 있는 업체 ➅ NET기반의 Windows Server의 Application 생성 및 표준화된 표준프레임워크을보유하고 있는 업체(타대학교에 적용 및 검증된 프레임워크 활용) ➆ 공동수급(공동이행방식) 및 하...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 5) 데이터 요구사항(Data Requirement)    6) 테스트 요구사항(Test Requirement)   7) 보안 요구사항(Security Requirement)  8) 품질 요구사항(Quality Requirement)            9) 제약 사항(Constraint Requirement)       10) 프로젝트관리 요구사항(Project Management Requirement)        11) 프로젝트 지원 요구사항(Project Support Requirement)...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 사업계획 변경 등의 여건 변화가 있을 경우 양자 간의 협의에 의하여 결정 함 ○ 제안사는 담당부서가 제시하는 의견을 특별한 사유가 없는 한 최대한 반영하여야 하며 설계지침상의 내용을 벗어나지 않은 한 구축비는 증감하지 않음 ○ 제안사가 작성한 설계 자료가 관계법령 등에 위배될 경우 제안사는 이를 즉시 수정 보완하여야 하며, 이에 소요되는 비용은 제안사가 부담 ○ 제안사는 법령 등의 위배 이외의 사유로 담당부서로부터 자료의 수정․보완 요청이 있는 경우 이에 응하여야 하며, 이로 인한 비용의 발생은 입찰자가 부담 □ 보안 준수사항 ○ ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 용역직원에 경고 및 퇴출 조치 할 수 있다  ○ 제안서 작성시 본 제안요청서에 첨부되어 있는 서식을 참고하여 작성 ○ 각 서식의 규격에 대해 다음과 같은 경우를 제외하고 약간의 부분변경이 가능함 - 허위사실을 위해 변경한 경우 - 평가위원이 제안서를 평가하기 힘들 정도로 제공 서식과 상이한 경우 ○ 서식 제11호는 낙찰자에 한해서 계약 후 작성하여 제출한다 [서식 제1호] 일반현황 및 주요연혁  [서식 제2호] 자본금 및 매출액(최근3년) (단위 : 천원)  [서식 3호] 주요사업실적  ※ 연도순으로 기재하며, 제안과제와 유사하거나...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 명기하여야 함 - 단, 상용S/W, 패키지 등의 서비스 지원인력, 외부 자문인력 등 통상적인 개발인력이 아닌 경우는 제안서에 명기하지 말 것(핵심인력에서 제외)  □ 일반사항 ○ 본 제안서는 「한영대학교 특성화 막춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화」사업에 한정하여 적용 ○ 제안사는 한영대학교의 트랙운영 학사정보시스템을 충분히 이해하고, 제안요청 사항을 기본적으로 반영하여 과업내용을 포함하여야 함 ○ 제안사는 본 제안요청서에 언급하지 않았으나, 본 과업수행 향상에 도움이 되는 사항이 있을 경우 이를 추가로 제시할 수...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 고려하여 시스템 설계를 하여야 한다 ◦ 제안되는 모든 S/W는 기존 환경을 고려하여 개발 되어야하며, 기능상의 제한 등으로 인하여 불가피한 경우에는 그 사유 및 대안을 제시하여야 한다 ◦ Reporting 전용 툴을 사용하여 출력물을 설계하되, 기능면에서 제한사항이 있으면 이에 대한 사유를 명시하고 대안을 제시하여야 한다 ◦ 통계보고서의 정형화 및 대학 전체가 공통된 내용의 업무지표 사용과 조회자료의 편리한 Export 지원(Excel 등)이 되어야 한다 ◦ 구성원별(교수/직원/조교 등), 소속부서와 업무분장에 따라 체계적인 계정 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 2024 10      □ 사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화 □ 사업예산 : 130,000,000원 범위 내 (VAT 포함) □ 사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함) * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음 □ 입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)  학사제도제도개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 트랙제 교육과정의 도입 및 운영으로 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 수 없다 ○ 계약 후 제안서의 내용을 허위로 작성한 사실이 발견되거나, 제안내용을 충족시키지 못할 경우 제안업체(계약업체)는 일제의 손해배상 책임을 진다 ○ 사업결과에 따른 모든 산출물의 소유권은 발주기관에 있다  ○ 제출된 제안서는 미 선정된 업체의 경우 반환하지 않으며, 본 제안을 위하여 소요되는 일체의 비용은 제안사의 부담으로 합니다 ○ 본 사업은 「소프트웨어사업의 제안서 보상기준 등에 관한 운영규정(과학기술정보통신부고시 제2016-108호, 20161011」제2조에 의거, 제안서 보상대상 사업에 해당하지 않으므로 제안서 보상...
# --------------------------------------------------
# Query: 이 사업의 추진 배경을 설명해주세요.
# Applying filter: {'파일형식': 'pdf'}
#
# Generated Response:
# 이 사업의 추진 배경은 다음과 같습니다. 첫째, 교육 환경의 급격한 변화로 인해 대학이 직면한 사회-기술 변화에 대응하기 위해 필요합니다. 둘째, 인구 감소와 코로나 팬데믹으로 인한 교육 환경의 변화가 있으며, 이로 인해 정보화 요구가 증가하고 있습니다. 셋째, 현재 우리 대학의 학사 시스템이 노후화되어 업무가 분산된 상태로, 이를 통합하고 개선할 필요성이 대두되고 있습니다. 이러한 이유로 차세대 포털 학사 정보 시스템 구축이 필요합니다.
#
# Query Time: 7.01 seconds
#
# Source Documents:
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '공고 번호': nan, '공고 차수': nan, '사업명': '차세대 포털·학사 정보시스템 구축사업 ', '사업 금액': 11270000000.0, '발주 기관': '고려대학교', '공개 일자': '2024-07-01 00:00:00', '입찰 참여 시작일': '2024-07-05 11:00:00', '입찰 참여 마감일': '2024-08-12 11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 및 사용 밤법 명시 운명자 마뉴얼 검수 기준론 운명자들이 마뉴얼은 놈해 실제로 시스템 운명 업무분 원찬하게 수행관 있는지금 기능 단위로 점검합 산출정보 사용자 및 문범자 더뉴벌 고려대학교 ROa Mtfr cT 제안 일반 사랑 사업관리 사항 가 제안사는 과업지시서 제안요청내용 현장 상황울 충분히 확인 및 인지한 후 제 안하야 함 제출된 제안서 및 관련 자루는 반환하지 많으다 공개하지 많음 다 제안서의 내용이 허위 또는 이행 불가능한 내용으로 작성된 사실이 발견되없올 경우 제안사어서 일체의 책임올 저야 함 라 제안서 내용에 대한 증빛자...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '공고 번호': nan, '공고 차수': nan, '사업명': '차세대 포털·학사 정보시스템 구축사업 ', '사업 금액': 11270000000.0, '발주 기관': '고려대학교', '공개 일자': '2024-07-01 00:00:00', '입찰 참여 시작일': '2024-07-05 11:00:00', '입찰 참여 마감일': '2024-08-12 11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 시기 및 진행밤법은 무리대학과 험의하여 결정합 무리다 학과 험의하여 사업기간 중 관계자 뭐크습 및 설명회 틈 개쇠 가능합 중간 보고회 뭐크습 틈 개쇠 해당 보고서 제출 사업수행 계회서 제출 겨약체걷일로부터 10일 이내어 지만요청서, 지단서 계막서 등올 근거로 년 사업은 수행하기 뒤' 사업수뱀계회 서(작수보 고서)l 작성하여 제출하여야 삼 계막밀로부터 사업만큼일까지 착수일 기준 마주{마 월 사업수밤계회서어 제시터 사업수뱀 절차에 마른 본재의 구체적인 긍정 및 진행사람 법무추진 상 문제점 및 대응(개선)방안 눕에 대한 주 원간 및 중간...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '공고 번호': nan, '공고 차수': nan, '사업명': '차세대 포털·학사 정보시스템 구축사업 ', '사업 금액': 11270000000.0, '발주 기관': '고려대학교', '공개 일자': '2024-07-01 00:00:00', '입찰 참여 시작일': '2024-07-05 11:00:00', '입찰 참여 마감일': '2024-08-12 11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 규정어 의한 자격올 구비한 업체 3) 국가름 당사자로 하는 계약에 관한 법률 제27조 및 동법시행령 제27조 및 동 법시합팀 제76조메 의한 부정담업자로 제재름 반지 압는 업체 4) 소프트웨어산업진음법 제48조 제스함에 따라 삼호술 자제한기업집단데 속하는 회사는 입찰에 참여할 수 없음 5) 입찰공고일 현재 국세 및 지방세 체날 사실이 없어야 하고 청산 합병, 매각 등 정리절차 줍이거나 계획 중인 사업자나 법원에 화의 또는 법정관리름 청 중인 사업자는 입찰데 참여[ 수 없음 6) 본 사업온 공동수급(공동이합방식)이 가능함 공동수급체 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '공고 번호': nan, '공고 차수': nan, '사업명': '차세대 포털·학사 정보시스템 구축사업 ', '사업 금액': 11270000000.0, '발주 기관': '고려대학교', '공개 일자': '2024-07-01 00:00:00', '입찰 참여 시작일': '2024-07-05 11:00:00', '입찰 참여 마감일': '2024-08-12 11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 고려대학교 ROa UIVER SITY 제 안 요 청 서 고려대학교 차세대 포털 학사 정보시스템 구축 사업 2024 7 07 aE 고려대학교 KOREA UNIVERSITY 본 자고; 게민내공의 신편움 취한 "포자고로 부거으로 '년부지 사용타; 형위: 구립- 고려대학교 ROa UIVER SITY 목 차 사업개요 1 사업 개요 2 사업 배경 3 사업 범위 : 기대 증과 I 현황 및 문제점 1 일반 된참  2 점수화 된참 문제점 및 개선방방 I 사업 추진방안 1 추진 욕표 2 추진 밀정 3 추진 체계 IV 제안요청 내용 1 제안요섬 개요 ...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '공고 번호': nan, '공고 차수': nan, '사업명': '차세대 포털·학사 정보시스템 구축사업 ', '사업 금액': 11270000000.0, '발주 기관': '고려대학교', '공개 일자': '2024-07-01 00:00:00', '입찰 참여 시작일': '2024-07-05 11:00:00', '입찰 참여 마감일': '2024-08-12 11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 잘 곰 고 입 살 일 자 {지명) 번로 밑 잘 건 명 본 입찰에 관한 밀체의 권한블 다음의 본 입살어 사용할 인감블 다음과 같이 자에게 워임합니다- 신고합니다- 사용인감 생 년 월 밑 본인은 위의 번주로 공고히 귀 대학교의 경쟁입실에 잠가하고자 고려대학교어서 정히 입찰공고 사함음 모두 승낙하고 별점서유들 점부하여 입찰참가신청은 합니다 섬 부 : 입찰공고에서 정한 입찰등록 구비서유 신성민 (법민민감 날인) 고려대학교 총장 귀하 2덕- 고려대학교 ROa Mtfr cT 서식 2 ] 일반현황 및 주요연력 티사명 다표 자 사업문야 사업자 번...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '공고 번호': nan, '공고 차수': nan, '사업명': '차세대 포털·학사 정보시스템 구축사업 ', '사업 금액': 11270000000.0, '발주 기관': '고려대학교', '공개 일자': '2024-07-01 00:00:00', '입찰 참여 시작일': '2024-07-05 11:00:00', '입찰 참여 마감일': '2024-08-12 11:00:00', '사업 요약': '- 사업개요: 고려대학교 차세대 포털·학사 정보시스템 구축 사업\n- 추진배경: 학령인구 감소, 교육환경 변화 등으로 대학은 급격한 사회·기술변화에 직면하고 있음\n- 사업범위: 분산된 시스템 및 데이터의 통합, 데이터 기반 대학경영 지원 개선, 사용자 정보서비스 접근성 개선\n- 기대효과: 교육 환경 대응, 시스템 통합, 대학경영 개선, 정보서비스 접근성 개선, 대학 경쟁력 강화\n- 추진목표: 차세대 구축을 통해 정보서비스 품질 강화 및 대학 교육 시스템 경쟁력 확보', '파일형식': 'pdf', '파일명': '고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf', '텍스트': '제  안  요  청  서 \n\n고려대학교   \n차세대  포털·학사  정보시스템  구축  사업 \n\n2024. 7. 01 \n\n※  본  자료는  제안내용의  설명을  위한  배포자료로,  이외  목적으로  무단복제,  전달  및  사용하는  행위를  금함. \n\n-1- \n\n                                                                                                                     \n \n \n \n \n \n   \n \n \n \n \n           \n           \n \n \n   \n목      차     \n\nⅠ.  사업개요 ··················································································································   4 \n\n1.  사업  개요 ··············································································································   4 \n\n2.  사업  배경 ··············································································································   4 \n\n3.  사업  범위 ··············································································································   5 \n\n4.  기대효과 ···············································································································   7 \n\nⅡ.  현황  및  문제점 ········································································································   8 \n\n1.  일반  현황 ··············································································································   8 \n\n2.  정보화  현황 ········································································································   11 \n\n3.  문제점  및  개선방향 ·····························································································   15 \n\nⅢ.  사업  추진방안 ········································································································   33 \n\n1.  추진  목표 ············································································································   33 \n\n2.  추진  일정 ············································································································   35 \n\n3.  추진  체계 ············································································································   36 \n\n.  제안요청  내용 ········································································································   38 \n\n  Ⅳ\n\n1.  제안요청  개요 ·····································································································   38 \n\n2.  상세  요구사항 ·····································································································   43 \n\n.  제안  일반  사항 ····················································································'}
# 다-1) 참조) 10) 소프트웨어사업자 등록증 사본 11) 기업 분류 확인 자료(중소기업 중권기업, 대기업 등) 12) 지방세 및 국세 남세 증명서 다 유의사함 1) 제안사는 입찰보증금올 납부하여야 함 경우 입찰보증금의 금액 남부방법 등어 관하여는 국가들 당사자루 계약에 법률 시형령 제37조제t향 및 제2함의 규정물 준용함 2) 본 제안R청서의 전체 및 일부가 제안서 제출 이외의 다른 목적으로 사용되 어서논 안 팀 3) 제출기한율 엄수해야 하여 , 현장접수만 가능함 4) 제안서 작성 소요 비용온 제안사데서 부담하다 제술된 서류는 반...
# --- Source: /content/drive/MyDrive/Data/files/고려대학교_차세대 포털·학사 정보시스템 구축사업.pdf ---
# ...
# 대한 통계현황 조회 및 출력 기능 구현 - 통계현황 및 출력물은 권한에 따라 사용할 수 있도록 구현 - 현행 종합정보시스템과의 교과목 및 강의, 성적 정보를 연계할 수 있도록 구현 ◦ 기타 사항 - 트랙제 기반 교과목에 대한 출석점수 부여 기능 개발 □ 학사 정보시스템 고도화 ◦ 기 구축된 “학사운영시스템”에서 서비스 중인 교육과정, WEB 수강신청 모듈, 수강신청 관리모듈에 대한 고도화 구현 ◦ 다양한 사용자(교수, 직원, 학생)에게 제공하는 서비스 기능 고도화 구현 □ 정보기술 활용 전략 ◦ 향후 우리대학 학사정보시스템의 환경 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 또는 해지하여도 감수하겠으며 손해배상 청구 등 일체의 민․형사상 이의를 제기하지 않겠습니다 4 회사 임․직원이 관계 교직원에게 금품, 향응 등 부당한 이익을 제공하거나 담합 등 불공정 행위를 하지 않도록 하는회사윤리강령과 내부비리 제보자에 대해서도 일체의 불이익처분을 하지 않는 사규를 제정토록 노력하겠습니다 위 청렴계약 서약은 상호 신뢰를 바탕으로 한 약속으로서 반드시 지킬 것이며, 낙찰자로 결정될 시 본 서약 내용을 그대로 계약특수조건으로 계약하여 이행하고, 입찰참가자격 제한, 계약해지 등 한영대학교의 조치와 관련하여 당사가 한영...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 신고절차 등)에 근거하여 근무 경력확인서 및 기술 경력확인서를 사용자(대표자) 또는 소프트웨어 사업 발주자 확인을 받아 제출(소프트웨어기술자 경력관리기관의 소프트웨어 기술경력증명서) ※ 자격증, 경력 및 수행업무와 관련된 사항을 증명할 수 있는 자료를 붙임으로 첨부하여야 하며, 첨부되지 않은 자료에 대하여는 인정하지 않음 ※ 소속회사에 대한 재직증명서와 국민연금 가입자 가입증명(국민연금 : wwwnpsorkr) 또는 건강보험자격득실확인서(국민건강보험공단, wwwnhicorkr) 자료 제시 [서식 제6호]  [서식 제7호]  [서식 ...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 서면통지 후 14일내에 요구사항이 시정되지 아니할 시 본 계약을 해지할 수 있다  ○ 구축완료 시스템에 대하여 최종 인수결과 한영대학교가 제시한 IT 인프라 환경과 맞지 않는 등 계약조건을 이행하지 못하는 것으로 판단될 시 계약상대자는 한영대학교의 요구에 의해 구축 완료한 모든 시스템을 회수해야 하며 그 비용은 계약상대자의 부담으로 한다 ○ 다음 각 항의 사유로 인하여 발생한 장애에 대하여 계약상대자는 책임을 지지 않으나, 본교가 계약상대자에게 수리를 요청할 경우 계약상대자는 원가에 준하는 대가로 유지보수하고, 그 비용은 본교가 부...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 정보시스템개발서비스(세부품명번호: 8111159901)로 발행된 것으로 유효기간 내에 있어야 함]를 소지한 업체 ④ 최근 3년 이내에 ASPNET으로 대학관련 종합정보/학생이력/역량시스템 구축 개발 수주가 단일건으로 1억원 이상 실적이 있는 업체  Windows Server, MS-SQL기반 ASPNET 개발환경에 구축 실적이 있는 업체 ➅ NET기반의 Windows Server의 Application 생성 및 표준화된 표준프레임워크을보유하고 있는 업체(타대학교에 적용 및 검증된 프레임워크 활용) ➆ 공동수급(공동이행방식) 및 하...
# --- Source: /content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp ---
# Metadata: {'source': '/content/drive/MyDrive/Data/files/한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '공고 번호': '20241001798', '공고 차수': 0.0, '사업명': '한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보시스템 고도화', '사업 금액': 130000000.0, '발주 기관': '한영대학', '공개 일자': '2024-10-04 13:51:23', '입찰 참여 시작일': nan, '입찰 참여 마감일': '2024-10-15 17:00:00', '사업 요약': '- 한영대학교 특성화 맞춤형 교육환경 구축을 위해 트랙운영 학사정보시스템을 고도화한다.\n- 트랙제도를 도입하여 다양한 진로 선택 기회를 제공하고 산업현장의 경쟁력을 강화한다.\n- 효과적인 교육과정 지원 및 대학 체제 개편에 대한 대응체계를 확립한다.\n- 트랙기반 교육과정 운영 및 관리 체계를 개선하고 교수자-학습자 중심의 교육환경을 조성한다.\n- 학사운영 시스템을 고도화하여 대학 체제 개편에 대한 대응체계를 갖출 수 있다.', '파일형식': 'hwp', '파일명': '한영대학_한영대학교 특성화 맞춤형 교육환경 구축 - 트랙운영 학사정보.hwp', '텍스트': '    \n \n2024년 특성화 맞춤형 교육환경 구축 – 트랙운영 학사정보시스템 고도화\n  제안요청서\n\n2024. 10.\n   \n \n   \n목   차\nⅠ. 사업 안내          -            1\n 1. 사업개요          -            1\n 2. 추진배경 및 필요성           -            1\n 3. 기대효과           -            1\n  Ⅱ. 구축 방안          -            2\n 1. 구축목표          -            2\n 2. 구축일정           -            2\n 3. 구축범위           -            3\n  Ⅲ. 제안 요청 내용          -            4\n 1. 제안 요청 개요          -            4\n  Ⅳ. 제안안내 사항          -            5\n 1. 입찰 및 계약방법          -            5\n 2. 제안서 평가방법          -            6\n 3. 제안서 작성          -            8\n 4. 제안서 평가          -            12\n 5. 제출서류          -            17\n 6. 제안서 제출일정 및 방법          -            17\n 7. 제안요청 질의 및 설명회          -            17\n  Ⅴ. 기타사항          -            19\n  Ⅵ. 참조자료          -            22\n  Ⅶ. 붙임 서식          -            25\n    \n \nⅠ \n 사업 안내\n \n1 \n 사업개요\n  사 업 명 : 한영대학교 특성화 맞춤형 교육환경 구축 - \n   트랙운영 학사정보시스템 고도화\n  사업예산 : 130,000,000원 범위 내 (VAT 포함)\n  사업기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n  * 기간 및 일정은 학교 사정과 용역대상자와의 협의에 따라 조정될 수 있음\n  입찰방법 : 제한경쟁입찰(협상에 의한 계약 체결)\n \n2 \n 추진배경 및 필요성\n학사제도 제도개편과 연계하   여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공 및 취업문 확대 \n트랙제 교육과정의 도입 및 운영으로 산업현장의 경쟁력 강화\n산업체 수요 맞춤 교육과정 운영 및 활성화로 교육과정 내실화 \n기업수요 연계 확대로 산업체 및 지역사회 현장실무형 인재 양성 \n \n3\n 기대효과\n   트랙기반 교육과정의 운영 및 관리 체계를 효과적으로 지원\n   교수자-학습자 중심의 교육환경 조성을 통한 대학 교육의 가치 구현\n   학사운영 시스템을 통해 대학 체제 개편에 대한 대응체계 확립\n \nⅡ \n 구축 방안\n \n1 \n 구축목표\n    트랙제도 교과과정 개편 및 표준운영관리를 위한 시스템 구현\n    (교과과정 개발에서 성적 이수까지)\n    트랙제도 기반 교육과정과 현행 종합정보시스템 연계 가능하도록 고도화\n    (교육과정 / 수강신청 / 성적 / 학적관리 외)\n    확장성과 유연성을 고려한 환경 조성 및 유지보수가 용이 하도록 해야 함.\n    다양한 사용자(교수, 직원, 학생)의 정보 접근성 및 사용 편의성 고려\n \n \n2\n 구축일정\n    구축기간 : 계약일로부터 3개월 (안정화기간 1개월 포함)\n        \n   일 정\n  내 용\n진 행 일 정\n비고\n구축\n안정화\nw1\nw2\nw3\nw4\nw5\nw6\nw7\nw8\nw9\nw10\nw11\nw12\n사업발주 및 착수\n※ 사업수행 이전\n분석\n -업무 분석\n구현'}
# 수 없다 ○ 계약 후 제안서의 내용을 허위로 작성한 사실이 발견되거나, 제안내용을 충족시키지 못할 경우 제안업체(계약업체)는 일제의 손해배상 책임을 진다 ○ 사업결과에 따른 모든 산출물의 소유권은 발주기관에 있다  ○ 제출된 제안서는 미 선정된 업체의 경우 반환하지 않으며, 본 제안을 위하여 소요되는 일체의 비용은 제안사의 부담으로 합니다 ○ 본 사업은 「소프트웨어사업의 제안서 보상기준 등에 관한 운영규정(과학기술정보통신부고시 제2016-108호, 20161011」제2조에 의거, 제안서 보상대상 사업에 해당하지 않으므로 제안서 보상...

# %% [markdown]
# ## Add conversational memory
#
# ### Subtask:
# Integrate conversational memory into the RAG chain to maintain context across turns.

# %% [markdown]
# **Reasoning**:
# Integrate conversational memory into the RAG chain to maintain context across turns.

# %%
from langchain.chains import RetrievalQA
# Import the necessary components for conversational memory
from langchain.memory import ConversationBufferMemory
from langchain_openai import ChatOpenAI
from langchain.retrievers import MultiQueryRetriever
from langchain.prompts import PromptTemplate
from google.colab import userdata

try:
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
except userdata.SecretNotFoundError:
    print("Error: OPENAI_API_KEY not found in Colab secrets.")
    print("Please add your OpenAI API key to the Colab secrets manager (🔑 icon on the left) with the name 'OPENAI_API_KEY'.")
    OPENAI_API_KEY = None # Set to None to prevent further errors

if OPENAI_API_KEY and vectorstore:
    # Initialize the ChatOpenAI model for generation (will also be used for Multi-Query)
    llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY, temperature=0.3, max_tokens=1500, top_p=0.8)

    # Define a refined prompt template that includes chat history
    # This template guides the language model on how to use the retrieved context and the conversation history
    template = """다음 채팅 기록과 문서를 사용하여 질문에 답하세요.
    채팅 기록:
    {chat_history}

    문서:
    {context}

    질문: {question}

    답변:"""
    QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

    # Base Retriever with higher k and MMR
    base_retriever = vectorstore.as_retriever(
        search_type="mmr", # Use MMR search
        search_kwargs={"k": 10, "fetch_k": 20} # Increased k and fetch_k
    )

    # Implement Multi-Query Retriever
    # The multi-query retriever itself does not inherently handle conversational context
    # It generates multiple queries based on the *current* query.
    # Conversational memory needs to be integrated at the chain level.
    multiquery_retriever = MultiQueryRetriever.from_llm(
        retriever=base_retriever,
        llm=llm
    )

    final_retriever = multiquery_retriever

    # Initialize ConversationBufferMemory to store chat history
    # memory_key='chat_history' corresponds to the chat history variable in the prompt template
    # input_key='question' corresponds to the variable in the chain that will receive the user's query
    memory = ConversationBufferMemory(memory_key="chat_history", input_key="question")


    # Create a RetrievalQA chain with the advanced retriever and refined prompt
    # Add the memory parameter to the chain
    qa_chain_with_memory = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff", # 'stuff' chain type is suitable for including context in the prompt
        retriever=final_retriever, # Use the advanced retriever
        return_source_documents=True,
        chain_type_kwargs={"prompt": QA_CHAIN_PROMPT, "memory": memory} # Pass the refined prompt and memory
    )

    # Update the qa_chain variable
    qa_chain = qa_chain_with_memory

    print("Advanced RetrievalQA chain created with Multi-Query, MMR, refined generation parameters/prompt, and conversational memory.")

else:
    print("Skipping RAG chain creation due to missing API key or vector store.")
    qa_chain = None # Set qa_chain to None if creation failed
# Out:
# Advanced RetrievalQA chain created with Multi-Query, MMR, refined generation parameters/prompt, and conversational memory.

# %% [markdown]
# **Reasoning**:
# Demonstrate the conversational memory by asking follow-up questions that rely on the previous turn's context.

# %%
# Function to time RAG query (re-using the previous definition for consistency)
import time

def time_rag_query(qa_chain, query):
    """
    Times the execution of a RAG query.

    Args:
        qa_chain: The RAG chain object.
        query (str): The query string.

    Returns:
        tuple: A tuple containing the response dictionary and the execution time in seconds.
    """
    start_time = time.time()
    response = qa_chain.invoke({"query": query})
    end_time = time.time()
    execution_time = end_time - start_time
    return response, execution_time

# Example Conversation with Conversational Memory
if qa_chain and processed_documents:
    print("--- Starting Conversation with Memory ---")

    # First turn: Ask about a specific project's background (similar to previous examples)
    query1 = "한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?"
    print(f"\nUser Query 1: {query1}")
    response1, time1 = time_rag_query(qa_chain, query1)
    print("\nGenerated Response 1:")
    print(response1['result'])
    print(f"Query 1 Time: {time1:.2f} seconds")
    # Source documents are returned but not explicitly printed here for brevity,
    # as the focus is on the conversational flow.

    print("-" * 30)

    # Second turn: Ask a follow-up question that relies on the previous turn's context
    # This query doesn't mention "한영대학교" or the full project name,
    # relying on the memory to understand "이 사업" (this project).
    query2 = "그 사업의 사업 기간은 얼마나 되나요?"
    print(f"\nUser Query 2: {query2}")
    response2, time2 = time_rag_query(qa_chain, query2)
    print("\nGenerated Response 2:")
    print(response2['result'])
    print(f"Query 2 Time: {time2:.2f} seconds")

    print("-" * 30)

    # Third turn: Another follow-up question
    query3 = "사업 금액은 얼마인가요?"
    print(f"\nUser Query 3: {query3}")
    response3, time3 = time_rag_query(qa_chain, query3)
    print("\nGenerated Response 3:")
    print(response3['result'])
    print(f"Query 3 Time: {time3:.2f} seconds")

    print("--- Conversation with Memory Ended ---")

else:
    print("RAG chain with memory or processed documents not initialized.")
# Out:
# --- Starting Conversation with Memory ---
#
# User Query 1: 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 무엇인가요?
#
# Generated Response 1:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 추진 배경 및 필요성은 다음과 같습니다:
#
# 1. **학사제도 개편**: 학사제도 개편과 연계하여 전공교과목 선택폭을 넓히고, 트랙제 교육과정 참여자에게 다양한 진로선택의 기회를 제공하여 취업문을 확대할 필요성이 있습니다.
#
# 2. **산업체 수요 맞춤 교육**: 산업체의 수요에 맞춘 교육과정 운영 및 활성화를 통해 교육과정의 내실화를 도모하고, 산업현장의 경쟁력을 강화해야 합니다.
#
# 3. **정보화 요구 증가**: 급변하는 교육환경 속에서 정보화 요구가 증가하고 있으며, 기존의 노후화된 학사 시스템으로 인해 업무가 분산되어 있어 시스템 통합에 대한 요구가 커지고 있습니다.
#
# 4. **데이터 기반 의사결정 지원**: 분절된 시스템 간 정보 연계 및 정보화 표준 부재로 인해 경영현황 파악 및 의사결정 시 한계가 발생하고 있습니다. 따라서, 데이터 기반의 경영정보 제공이 필요합니다.
#
# 5. **사용자 정보 서비스 접근성 개선**: 교내 구성원의 정보 접근성을 높이기 위한 포털 서비스의 제공이 필요하며, 이를 통해 사용자 편의성을 향상시킬 수 있습니다.
#
# 6. **대학 경쟁력 강화**: 노후화된 시스템의 차세대 구축을 통해 정보 서비스의 품질을 강화하고, 대학의 교육 시스템 경쟁력을 확보해야 합니다.
#
# 이러한 배경과 필요성에 따라 한영대학교는 트랙운영 학사정보시스템의 고도화를 추진하고 있습니다.
# Query 1 Time: 11.31 seconds
# ------------------------------
#
# User Query 2: 그 사업의 사업 기간은 얼마나 되나요?
#
# Generated Response 2:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 사업 기간은 계약일로부터 24개월 이내입니다.
# Query 2 Time: 6.30 seconds
# ------------------------------
#
# User Query 3: 사업 금액은 얼마인가요?
#
# Generated Response 3:
# 한영대학교 트랙운영 학사정보시스템 고도화 사업의 사업 금액은 11,270,000,000원 (부가가치세 포함)입니다.
# Query 3 Time: 5.02 seconds
# --- Conversation with Memory Ended ---
